# %% [markdown]
# # Capstone Project - Datrition  <a href="https://ibb.co/KLpy34P"><img src="https://i.ibb.co/KLpy34P/Datrition-1-23.png" align="right" alt="Datrition-1-23" border="0" /></a>
#    ###### Team:  Omar Alharbi - Mansour Aljuaid  - Sumaiah Alsadhan

# %% [markdown]
# # Problem Statement

# %% [markdown]
# ---

# %% [markdown]
# # Model

# %% [markdown]
# ## Importing Libraries¶

# %%
import cv2
import os
from skimage import color, data, io, measure
from skimage.filters import threshold_otsu
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
from tqdm import tqdm
import glob
import matplotlib.image as mpimg
# %matplotlib inline
mpl.rcParams['image.cmap'] = 'gray'
plt.rcParams['figure.dpi']= 300 #UPDATED
plt.rc("savefig", dpi=300) #UPDATED

# %%
def sort_contours(cnts, method="left-to-right"):
    # initialize the reverse flag and sort index
    reverse = False
    i = 0

    # handle if we need to sort in reverse
    if method == "right-to-left" or method == "bottom-to-top":
        reverse = False

    # handle if we are sorting against the y-coordinate rather than
    # the x-coordinate of the bounding box
    if method == "top-to-bottom" or method == "right-to-left":
        i = 1

    # construct the list of bounding boxes and sort them from top to
    # bottom
    boundingBoxes = [cv2.boundingRect(c) for c in cnts]
    (cnts, boundingBoxes) = zip(*sorted(zip(cnts, boundingBoxes),
        key=lambda b:b[1][i], reverse=reverse))

    # return the list of sorted contours and bounding boxes
    return (cnts, boundingBoxes)

# %%
def f(y):
    # Defining a kernel length
    global horizontal_lines_img, verticle_lines_img, kernel
    kernel_length = np.array(img).shape[1]//y

    # A verticle kernel of (1 X kernel_length), which will detect all the verticle lines from the image.
    verticle_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (1, kernel_length))
    # A horizontal kernel of (kernel_length X 1), which will help to detect all the horizontal line from the image.
    hori_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (kernel_length, 1))
    # A kernel of (3 X 3) ones.
    ###kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3, 3))
    # Morphological operation to detect vertical lines from an image
    img_temp1 = cv2.erode(img_bin, verticle_kernel, iterations=1)
    verticle_lines_img = cv2.dilate(img_temp1, verticle_kernel, iterations=1)
    cv2.imwrite("verticle_lines.jpg",verticle_lines_img)
    # Morphological operation to detect horizontal lines from an image
    img_temp2 = cv2.erode(img_bin, hori_kernel, iterations=1)
    horizontal_lines_img = cv2.dilate(img_temp2, hori_kernel, iterations=1)
    ###plt.subplot(1, 2, 1)  # 2 rows, 2 columns, 1st subplot = top left
    ###plt.imshow(verticle_lines_img);
    ###plt.axis('off')

    ###plt.subplot(1, 2, 2)  # 2 rows, 2 columns, 2nd subplot = top right
    plt.imshow(horizontal_lines_img);
    plt.axis('off')

# %%
#  images.append(mpimg.imread(img_path))
#     print("Processing Image", len(images))

# %% [markdown]
# ---

# %% [markdown]
# ## Images Pre-Processing
# ### Processing from img Folder, then saving them in another folder named : 'img_result'

# %%
images = []
counter = 1
for img_path in tqdm(glob.glob('img/*.jpg')):
    
    img = cv2.imread(img_path,0)
    (thresh, img_bin) = cv2.threshold(img, 240, 255,cv2.THRESH_OTSU| cv2.ADAPTIVE_THRESH_GAUSSIAN_C) # UPDATE
    img_bin = 255-img_bin
    f(255)
    alpha = 1.0
    beta =  0.9 - alpha #UPDATE
    # This function helps to add two image with specific weight parameter to get a third image as summation of two image.
    img_final_bin = cv2.addWeighted(verticle_lines_img, alpha, horizontal_lines_img, beta, 0.5)
    #img_final_bin = cv2.erode(~img_final_bin, kernel, iterations=2)
    (thresh, img_final_bin) = cv2.threshold(img_final_bin, 230,255, cv2.THRESH_OTSU| cv2.ADAPTIVE_THRESH_GAUSSIAN_C) # UPDATE
    plt.axis('off')
    plt.imshow(img_final_bin)
#     images.append(mpimg.imread(img_path))
    # Find contours for image, which will detect all the boxes
    contours, hierarchy = cv2.findContours(img_final_bin, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE) #UPDATE

    # Sort all the contours by top to bottom.
    (contours, boundingBoxes) = sort_contours(contours, method="top-to-bottom")
    idx = 1
    
    for c in (contours):
        # Returns the location and width,height for every contour
        x, y, w, h = cv2.boundingRect(c)
        
# If the box height is greater then 20, widht is >80, then only save it as a box in "cropped/" folder.
        if (w > 160 and h > 80) and w < 2.5 *h:
            idx += 3
            new_img = img[y:y+h, x:x+w]
            #plt.subplot(2,3, idx)
            plt.imshow(new_img)
            plt.axis('off')
            #cv2.imwrite('./th/')
            #path = './th/'
            #plt.savefig(f'./img_result/label{counter}.jpg',dpi=300)
            #cv2.imwrite(os.path.join(path , 'label'+str(num)+'.jpg'), new_img)
            #cv2.imwrite(os.path.join(path , 'f', new_img))
            file_n = img_path.split('_')[-1].split('.')[0]
            plt.savefig(f'./img_result/{file_n}_Nutritions_{counter}.jpg',dpi=300) #UPDATED
            counter+=1
            #cv2.waitKey(0)
    #break
# Out:
#   0%|          | 0/24 [00:00<?, ?it/s]
#   4%|▍         | 1/24 [00:01<00:40,  1.76s/it]
#   8%|▊         | 2/24 [00:10<01:22,  3.74s/it]
#  12%|█▎        | 3/24 [00:18<01:48,  5.15s/it]
#  17%|█▋        | 4/24 [00:25<01:51,  5.58s/it]
#  21%|██        | 5/24 [00:44<03:04,  9.69s/it]
#  25%|██▌       | 6/24 [00:59<03:22, 11.27s/it]
#  29%|██▉       | 7/24 [01:09<03:06, 10.98s/it]
#  33%|███▎      | 8/24 [01:33<03:59, 14.96s/it]
#  38%|███▊      | 9/24 [02:16<05:48, 23.22s/it]
#  42%|████▏     | 10/24 [02:52<06:17, 26.99s/it]
#  46%|████▌     | 11/24 [03:36<06:57, 32.12s/it]
#  50%|█████     | 12/24 [04:23<07:20, 36.70s/it]
#  54%|█████▍    | 13/24 [04:49<06:07, 33.39s/it]
#  58%|█████▊    | 14/24 [05:28<05:51, 35.15s/it]
#  62%|██████▎   | 15/24 [06:49<07:20, 48.96s/it]
#  67%|██████▋   | 16/24 [07:48<06:54, 51.87s/it]
#  71%|███████   | 17/24 [08:41<06:05, 52.15s/it]
#  75%|███████▌  | 18/24 [09:13<04:36, 46.03s/it]
#  79%|███████▉  | 19/24 [09:40<03:22, 40.55s/it]
#  83%|████████▎ | 20/24 [09:56<02:12, 33.21s/it]
#  88%|████████▊ | 21/24 [10:32<01:42, 34.03s/it]
#  92%|█████████▏| 22/24 [12:37<02:02, 61.27s/it]
#  96%|█████████▌| 23/24 [14:22<01:14, 74.33s/it]
# 100%|██████████| 24/24 [15:04<00:00, 64.71s/it]

# %%
new_img
# Out:
# array([[139, 139, 139, ..., 139, 139, 139],
#        [140, 140, 140, ..., 140, 140, 140],
#        [140, 140, 140, ..., 140, 140, 140],
#        ...,
#        [156, 156, 156, ..., 145, 155, 154],
#        [156, 156, 156, ..., 140, 155, 156],
#        [157, 157, 157, ..., 136, 150, 152]], dtype=uint8)

# %% [markdown]
# ---

# %% [markdown]
# ## Extracting text from Nutrition lables
#     OCR (pytesseract) and Open CV

# %% [markdown]
# ### Importing Packages & Libraries:

# %%
import pytesseract
from PIL import Image, ImageEnhance, ImageFilter
import os
import glob
import re
import sys
import cv2
import post_process

# %% [markdown]
# ### Applicatopn of OCR on images saved at 'img_result'

# %%
def label_Recognizer(path):
    import re
    import os
    from matplotlib import pyplot 
    files = []
    for  r,d, f in os.walk(path):
        print(f)
        print(d)
        print(r)
        for file in f:
            files.append(os.path.join(file))
    p = re.compile('[0-9]+.jpg')
    all_result = []
    for f in files:
        #print(f)
     #   out_dict = end_to_end.end_to_end(f'{path}\{f}')
        #-----------------

        for file in glob.glob('img_result/*.jpg'):
            bw = cv2.imread(file, 0)

        # Apply adaptive thresholding to images | @Suma Not Required already applied in image processing.
#             thresh = cv2.adaptiveThreshold(bw, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,\
#                 cv2.THRESH_BINARY, 11, 2)

        # Get text recognition from thresholded images
            output = pytesseract.image_to_string(Image.fromarray(bw))

            fileName = p.findall(file)[0]
            print ("Proccessing " + fileName)
            #outFileName = fileName[0:len(fileName)-4]
            # Get default text recognition 
            #output = pytesseract.image_to_string(Image.open(file))
            x = post_process.post_process(output)
            print("\n Completed Labels for:", '\n', fileName, '\n', output)
            all_result.append(x)
            x['product_id']=file
        result = []
        for i in all_result:
            if len(i) == 0:
                pass
            else:
                result.append(i)
        return result

# %%
n = label_Recognizer('img_result/')
# Out:
# ['74_Nutritions_1.918.jpg', '11_Nutritions_1.995.jpg', '7_Nutritions_1.949.jpg', '76_Nutritions_1.91.jpg', '82_Nutritions_1.9137.jpg', '4_Nutritions_1.987.jpg', '12_Nutritions_1.967.jpg', '78_Nutritions_1.9152.jpg', '78_Nutritions_1.9153.jpg', '12_Nutritions_1.966.jpg', '4_Nutritions_1.986.jpg', '9_Nutritions_1.9126.jpg', '7_Nutritions_1.948.jpg', '11_Nutritions_1.994.jpg', '74_Nutritions_1.919.jpg', '11_Nutritions_1.996.jpg', '80_Nutritions_1.9127.jpg', '76_Nutritions_1.92.jpg', '9_Nutritions_1.9124.jpg', '4_Nutritions_1.984.jpg', '12_Nutritions_1.970.jpg', '12_Nutritions_1.971.jpg', '4_Nutritions_1.985.jpg', '9_Nutritions_1.9119.jpg', '9_Nutritions_1.9125.jpg', '76_Nutritions_1.93.jpg', '11_Nutritions_1.997.jpg', '74_Nutritions_1.922.jpg', '11_Nutritions_1.993.jpg', '9_Nutritions_1.9121.jpg', '4_Nutritions_1.981.jpg', '.DS_Store', '78_Nutritions_1.9154.jpg', '78_Nutritions_1.9155.jpg', '4_Nutritions_1.980.jpg', '9_Nutritions_1.9120.jpg', '76_Nutritions_1.96.jpg', '11_Nutritions_1.992.jpg', '74_Nutritions_1.921.jpg', '76_Nutritions_1.94.jpg', '9_Nutritions_1.9122.jpg', '4_Nutritions_1.982.jpg', '78_Nutritions_1.9157.jpg', '78_Nutritions_1.9156.jpg', '4_Nutritions_1.983.jpg', '9_Nutritions_1.9123.jpg', '76_Nutritions_1.95.jpg', '75_Nutritions_1.97.jpg', '74_Nutritions_1.920.jpg', '1_Nutritions_1.932.jpg', '8_Nutritions_1.9111.jpg', '13_Nutritions_1.964.jpg', '13_Nutritions_1.958.jpg', '82_Nutritions_1.9140.jpg', '6_Nutritions_1.976.jpg', '6_Nutritions_1.977.jpg', '13_Nutritions_1.959.jpg', '13_Nutritions_1.965.jpg', '1_Nutritions_1.933.jpg', '1_Nutritions_1.931.jpg', '8_Nutritions_1.9112.jpg', '6_Nutritions_1.975.jpg', '6_Nutritions_1.974.jpg', '8_Nutritions_1.9113.jpg', '1_Nutritions_1.930.jpg', '5_Nutritions_1.9109.jpg', '8_Nutritions_1.9117.jpg', '1_Nutritions_1.934.jpg', '13_Nutritions_1.962.jpg', '2_Nutritions_1.939.jpg', '10_Nutritions_1.990.jpg', '10_Nutritions_1.991.jpg', '2_Nutritions_1.938.jpg', '13_Nutritions_1.963.jpg', '1_Nutritions_1.935.jpg', '5_Nutritions_1.9108.jpg', '8_Nutritions_1.9116.jpg', '8_Nutritions_1.9114.jpg', '1_Nutritions_1.937.jpg', '13_Nutritions_1.961.jpg', '79_Nutritions_1.9149.jpg', '6_Nutritions_1.973.jpg', '6_Nutritions_1.972.jpg', '79_Nutritions_1.9148.jpg', '13_Nutritions_1.960.jpg', '1_Nutritions_1.936.jpg', '8_Nutritions_1.9115.jpg', '8_Nutritions_1.9118.jpg', '5_Nutritions_1.9106.jpg', '5_Nutritions_1.999.jpg', '79_Nutritions_1.9145.jpg', '79_Nutritions_1.9151.jpg', '81_Nutritions_1.9133.jpg', '75_Nutritions_1.912.jpg', '75_Nutritions_1.913.jpg', '81_Nutritions_1.9132.jpg', '73_Nutritions_1.923.jpg', '79_Nutritions_1.9150.jpg', '79_Nutritions_1.9144.jpg', '83_Nutritions_1.9135.jpg', '5_Nutritions_1.9107.jpg', '5_Nutritions_1.9105.jpg', '79_Nutritions_1.9146.jpg', '81_Nutritions_1.9130.jpg', '10_Nutritions_1.988.jpg', '75_Nutritions_1.911.jpg', '10_Nutritions_1.989.jpg', '75_Nutritions_1.910.jpg', '81_Nutritions_1.9131.jpg', '79_Nutritions_1.9147.jpg', '83_Nutritions_1.9136.jpg', '5_Nutritions_1.9110.jpg', '5_Nutritions_1.9104.jpg', '1_Nutritions_1.929.jpg', '5_Nutritions_1.9100.jpg', '13_Nutritions_1.957.jpg', '3_Nutritions_1.944.jpg', '79_Nutritions_1.9143.jpg', '73_Nutritions_1.924.jpg', '6_Nutritions_1.979.jpg', '75_Nutritions_1.914.jpg', '81_Nutritions_1.9134.jpg', '75_Nutritions_1.915.jpg', '6_Nutritions_1.978.jpg', '73_Nutritions_1.925.jpg', '79_Nutritions_1.9142.jpg', '3_Nutritions_1.945.jpg', '5_Nutritions_1.9101.jpg', '1_Nutritions_1.928.jpg', '5_Nutritions_1.9103.jpg', '3_Nutritions_1.947.jpg', '73_Nutritions_1.927.jpg', '75_Nutritions_1.916.jpg', '73_Nutritions_1.926.jpg', '79_Nutritions_1.9141.jpg', '3_Nutritions_1.946.jpg', '5_Nutritions_1.9102.jpg', '84_Nutritions_1.9165.jpg', '7_Nutritions_1.954.jpg', '2_Nutritions_1.941.jpg', '2_Nutritions_1.940.jpg', '7_Nutritions_1.955.jpg', '84_Nutritions_1.9164.jpg', '84_Nutritions_1.9166.jpg', '75_Nutritions_1.99.jpg', '2_Nutritions_1.942.jpg', '78_Nutritions_1.9158.jpg', '78_Nutritions_1.9159.jpg', '2_Nutritions_1.943.jpg', '7_Nutr ...
# ['.ipynb_checkpoints']
# img_result/
# []
# []
# img_result/.ipynb_checkpoints
# Proccessing 918.jpg
# [('br8te eae? rfp:', 'eae? rfp:', 0), ('lewetaycs reemertp:', '0 gu?) or6h 6 ET', 1), ('len jo mtg oro tent ', '013 180 GMA rromgN GALL) 6 FB HSE oeTRP TEA', 2), ('freerte rag) CHEN ', '81e EER [ers MGS (Fy yr eyes te ap reyes STE (ee yp rege presi [oor pret (FS yy Ye o', 3), ('(eon) cep emis om <P" Ten', '0 prema! ope se mere TeHTER ) Serr [Ine? &mpt eet eo TEED', 4), ('ey sence coi ype rege ep He SEED PP gC rm rae (', '6P eS! ee Fleee [pines ETE IS oy HGEweICRe— CHES', 5), ('Sipe ot', '6pp prrorev icee6o ipot|ore jperie', 6), ('- e+ oy oo - en - en eo ene en ene en eo eee ee eo eo pee ---', 'e+ oy oo - en - en eo ene en ene en eo eee ee eo eo pee ---', 7), ('WIL ONDIVE LY ', '0P LM LIN DNICIACYd OL GALLIWW OD $1SHaNvO', 8)]
#
#
#
# [('len jo mtg oro tent ', '013 180 GMA rromgN GALL) 6 FB HSE oeTRP TEA', 2)]
#
#
#
# [('len jo mtg oro tent ', '013 180 GMA rromgN GALL) 6 FB HSE oeTRP TEA', 2)]
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  918.jpg
#  tere IEE: rope A op hfe Ber
#
# Fen? ertge sip tf ech Oh de oft yy yygt ote? ch groerroy (rere rete chy Spe Fey iD Ire Ae ETE
# br8te eae? rfp: 3
#
# lewetaycs reemertp: 0 gu?) or6h 6 ETA
#
# len jo mtg oro tent (013 180 GMA rromgN GALL) 6 FB HSE oeTRP TEAR
#
# freerte rag) CHEN o81e EER [ers MGS (Fy yr eyes te ap reyes STE (ee yp rege presi [oor pret (FS yy Ye oT
# (eon) cep emis om <P" Ten 0 prema! ope se mere TeHTER ) Serr [Ine? &mpt eet eo TEED |
# ey sence coi ype rege ep He SEED PP gC rm rae (w6P eS! ee Fleee [pines ETE IS oy HGEweICRe— CHES |
#
# Sipe ot 6pp prrorev icee6o ipot|ore jperie:
#
#
#
#
#
#
#
#
#
# - e+ oy oo - en - en eo ene en ene en eo eee ee eo eo pee ----4
# ! '
# WOD'SdOOd SuaNVD SYAWOLSND SLI OLSIONCGOUd AUIAVE ALITT¥NO:
# WIL ONDIVE LY S0P LM LIN DNICIACYd OL GALLIWW OD $1SHaNvO!
#
# CAKERS
# Proccessing 995.jpg
# [('Honey', '125', 0), ('F125 Sue ae Jobs Gules Ce dine yd uals', 'Sue ae Jobs Gules Ce dine yd uals', 1), ('Gabe Y', '1Z Suse «(jobs Guile Cpa) Adae 1OsLi gSal', 2), ('/€14 CGR Agi wa Gail ga Cla) gus ALS Stk', 'CGR Agi wa Gail ga Cla) gus ALS Stk', 3)]
#
#
#
# [('F125 Sue ae Jobs Gules Ce dine yd uals', 'Sue ae Jobs Gules Ce dine yd uals', 1)]
#
#
#
# [('F125 Sue ae Jobs Gules Ce dine yd uals', 'Sue ae Jobs Gules Ce dine yd uals', 1)]
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  995.jpg
#  Delamere Dairy Goats Cheese With
# Honey 125g
# F125 Sue ae Jobs Gules Ce dine yd uals
#
# Gabe Yo1Z Suse «(jobs Guile Cpa) Adae 1OsLi gSall
#
# /€14 CGR Agi wa Gail ga Cla) gus ALS Stk
# £100
#
#
#
# Jail ga @ Lu)
# Proccessing 949.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  949.jpg
#
# Proccessing 91.jpg
# [('BIpuy “Bley “/G', '89-UIY90', 0), ('‘gg :XOg “Od ', '294J0 ayesods0', 1), ('"3O1Md VLAN XUN ey', 'VLAN XUN ey', 2), ('3e/\\24', '6L02/P0 “Aula Jo 31v', 3), ('3/V\\\\', '8102/70 “54 40 Siva', 4), ('BOSE :', '1UGIeM 19', 5)]
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  91.jpg
#  BIpuy “Bley “/GE89-UIY909
# ‘AyeweBuy “ur \Sey ‘anuaAy SUP|OOIA,
# ‘gg :XOg “Od :294J0 ayesods05
# “GIT WLAd SASIUdaa.LNA
#
# SNVTOOW
#
# :Aq payodxy yp paysed
#
#
#
# cS
# %
# "3O1Md VLAN XUN ey
# oF? inch: WR
# 3e/\24 6L02/P0 “Aula Jo 31va
#
#
#
# a
# EB
# Hi
#
# a? jam?
#
# 3/V\\ 8102/70 “54 40 Siva
# Oe im
#
# vOSO -on Hola
#
# HIP IOS EOS pe
#
# BOSE : 1UGIeM 19N
# Proccessing 9137.jpg
# [('EAS Spl pe be pL agal', '34', 0), ('(Godley sad he Bosla! Mae Saad fe', 'sad he Bosla! Mae Saad fe', 1), ('MYTATEEASS', '30 yopiS!"\\ ink', 2), ('www.4matrade.com', '', 3), ('WSLS pol laa yaad AS ', '21 daw', 4), ('Serving Size', '3-5 olivesi165', 5), ('‘Servings per container About:', '2', 6), ('Calories', '30 Calories from fat 2', 7), ('“Daly Valve', '6', 8), ('Monounsaturated Fat', '15', 9), ('Dia ree Than ig', '0', 10), ('22000 lene', 'lene', 11), ('ae¥ee', '700gm', 12), ('aetde', '350gm', 13)]
#
#
#
# [('Serving Size', '3-5 olivesi165', 5), ('‘Servings per container About:', '2', 6), ('Calories', '30 Calories from fat 2', 7), ('Monounsaturated Fat', '15', 9)]
#
#
#
# [('Serving Size', '3-5 olivesi165', 5), ('‘Servings per container About:', '2', 6), ('Calories', '30 Calories from fat 2', 7), ('Monounsaturated Fat', '15', 9)]
#
#
#
# [('Serving Size', '3-5 olivesi165', 1), ('Calories', '30 Calories from fat 2', 3), ('Monounsaturated Fat', '15', 4)]
#
#
#
# [('Serving Size', '3-5 olivesi165', 1), ('Calories', '30 Calories from fat 2', 3)]
#
#
#
#
#  Completed Labels for:
#  9137.jpg
#  plat Vads tall gle
# pst
# EAS Spl pe be pL agal 345
#
# SAISON pack sppgetLS cLpgS Sobtadt
#
# (Seay ol te All gang wd
# stg] dh taptnall pad Ja
# (Godley sad he Bosla! Mae Saad fes1
#
# edn ele
#
# abt Stan ia
# ayaa NI
# sb Le Mah elle
# MYTATEEASS 30 yopiS!"\ inks
#
# www.4matrade.com
#
# WSLS pol laa yaad AS p21 dawg
#
# (pas Aaaas gb Ta
# ‘yal nay
#
# Patan aieai yay |
#
# ee
#
# aera f
#
# ven Tit fla
#
# : iN Win
#
# 2400902
#
# Pitted
#
# Black Olives
#
# lo sowi
#
# re
#
# PLTTED BLACK OLIVES
#
# Spanish Style
# Nutrition Facts
# Serving Size 3-5 olivesi165)
# ‘Servings per container About: 22
# Amount per seriving:
# Calories 30 Calories from fat 25
# “Daly Valve 6)
# Tomiratzsg
# Monounsaturated Fat 15g
# Polyunsaturated Fat OB
# Tansfatomg
# Cholesterol Om, OE
#
# a
#
# Dia ree Than ig 0%
#
# Nota Significant sowree- of
# Saturated at, Cholasteral, Dietary ber
# ‘Sugars, Vitamin A, Vitamin C, Calcium
# and icon,
#
# Treaster bert on
# 22000 lene
#
# Go ecedrecs
# vata Net We
# ae¥ee 700gme
# snail gis —_Drained Wi.
# aetde 350gme
# seed gio Product of Egypt
# Proccessing 987.jpg
# [('en @.', '6', 0)]
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  987.jpg
#  en @. 6
# pro.date
#
# olga! fy
# ExP date
# Proccessing 967.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  967.jpg
#
# Proccessing 9152.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  9152.jpg
#
# Proccessing 9153.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  9153.jpg
#
# Proccessing 966.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  966.jpg
#
# Proccessing 986.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  986.jpg
#
# Proccessing 9126.jpg
# [('CholesterolOmg =', '0', 0), ('Sodium', '0m 0', 1), ('Total Carbohydrat', '7g = 8', 2), ('sap RIO GO on rte ert peed', '0', 3), ('_fotalSugar', '7', 4), ('__Includes', '0gAdded Sugars 0', 5), ('Protein', '09 0', 6), ('VitaminAQmg  VitaminC Omg', '0', 7), ('CNC NIN OST no', '0', 8), ('lronOmg ee', '0', 9), ('Potassium Omg', '0', 10)]
#
#
#
# [('CholesterolOmg =', '0', 0), ('Sodium', '0m 0', 1), ('Total Carbohydrat', '7g = 8', 2), ('_fotalSugar', '7', 4), ('Protein', '09 0', 6), ('Potassium Omg', '0', 10)]
#
#
#
# [('CholesterolOmg =', '0', 0), ('Sodium', '0m 0', 1), ('Total Carbohydrat', '7g = 8', 2), ('_fotalSugar', '7', 4), ('Protein', '09 0', 6), ('Potassium Omg', '0', 10)]
#
#
#
# [('Cholesterol', '0', 1), ('Sodium', '0m 0', 2), ('Potassium', '0', 6), ('Total Carbohydrate', '7g = 8', 3), ('Protein', '09 0', 5)]
#
#
#
# [('Cholesterol', '0', 1), ('Sodium', '0m 0', 2), ('Total Carbohydrate', '7g = 8', 3), ('Protein', '09 0', 5)]
#
#
#
#
#  Completed Labels for:
#  9126.jpg
#  Ifans Fat uy
#
# CholesterolOmg = 0%
# Sodium 0m 0%
# Total Carbohydrate7g = 8%
# sap RIO GO on rte ert peed 0%
# _fotalSugars7g
# __Includes 0gAdded Sugars 0%
# Protein 09 0%
# VitaminAQmg  VitaminC Omg 0%
# CNC NIN OST no 0%
# lronOmg ee 0%
#
# Potassium Omg 0%
# Proccessing 948.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  948.jpg
#
# Proccessing 994.jpg
# [('typical values', '100g (17.9g', 0), ('energy kJ/kcal', '1212/291| 217/5', 1), ('fat', '19.19 [3.49', 2), ('of which saturates ', '14g_ = |2.5', 3), ('carbohydrate', '2.2', 4), ('of whichsugars ', '12.3g |2.2', 5), ('protein', '3.1', 6), ('salt', '0.8g 0.1', 7), ('ference intake (RI) (Adult): Enerav', '8400kJ/200', 8)]
#
#
#
# [('energy kJ/kcal', '1212/291| 217/5', 1), ('carbohydrate', '2.2', 4), ('of whichsugars ', '12.3g |2.2', 5), ('protein', '3.1', 6), ('ference intake (RI) (Adult): Enerav', '8400kJ/200', 8)]
#
#
#
# [('energy kJ/kcal', '1212/291| 217/5', 1), ('carbohydrate', '2.2', 4), ('Sugars', '12.3g |2.2', 5), ('protein', '3.1', 6), ('ference intake (RI) (Adult): Enerav', '8400kJ/200', 8)]
#
#
#
# [('Total Carbohydrate', '2.2', 2), ('Sugars', '12.3g |2.2', 3), ('Protein', '3.1', 4)]
#
#
#
# [('Total Carbohydrate', '2.2', 2), ('Sugars', '12.3g |2.2', 3)]
#
#
#
#
#  Completed Labels for:
#  994.jpg
#  serves / per per slice
# typical values 100g (17.9g)
#
# energy kJ/kcal 1212/291| 217/52
#
# fat 19.19 [3.49
#
# of which saturates |14g_ = |2.5g
#
# carbohydrate 2.2g
#
# of whichsugars |12.3g |2.2g
# protein 3.1g
# salt 0.8g 0.1g
#
# ference intake (RI) (Adult): Enerav 8400kJ/2001
# Proccessing 919.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  919.jpg
#
# Proccessing 996.jpg
# [('Honey', '125', 0), ('F125 Sue ee jobs cule Gye Absa og ud peas', 'Sue ee jobs cule Gye Absa og ud peas', 1), ('cobs', '6% 12 Sane «(Jobs Guile Cpa) Adsa :Cili gal', 2), ('/€14 SC g', '3 Aga wa gant gg CL) gus AL GLS 5.4L', 3)]
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  996.jpg
#  Ma Delamere Dairy Goats Cheese With
# Honey 125g
# F125 Sue ee jobs cule Gye Absa og ud peas
#
# cobs 6% 12 Sane «(Jobs Guile Cpa) Adsa :Cili gall
#
# /€14 SC gb3 Aga wa gant gg CL) gus AL GLS 5.4L,
# £100
#
# Ne lalge ett) /
# Proccessing 9127.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  9127.jpg
#  o ll iM
# Proccessing 92.jpg
# [('eIpUl ‘BIeJay ', '7/2 GE99-UIYO', 0), ('‘OG :XOg ‘Od :', '9IJO ayes0d10', 1), (':Aq Ppal', '0dxq p payde', 2), ('SIPs', '807', 3), ('"301d TVLIW XV', 'TVLIW XV', 4), ('3e/v\\e\\', '6 LOZ/ 0:Auldxa 40 div', 5), ('& gs alslgla/aiale - of', '2 (Ge', 6), ('*', '3y/V\\A 8102/70 “as 40 a1v', 7), ('b0S0 -onHoLva', '-onHoLva', 8), ('60S) :', '1ybien Jan', 9), ('\\ Dells |', '7NNN | Sh', 10)]
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  92.jpg
#  eIpUl ‘BIeJay ‘7/2 GE99-UIYOQ
# ‘freweBuy “ur ise ‘anuaay suejoo
#
# ‘OG :XOg ‘Od :a9IJO ayes0d104
#
# “GIT “LAd SHSTadua.LNA
#
# :Aq Ppals0dxq p paydeq
#
#
#
# im? i VIGNI SO LONGOYd v
# Arr RG ESTE (XE
#
# SIPs 807 9
# "301d TVLIW XV
# ACR (Reh?
# 3e/v\e\ 6 LOZ/r0:Auldxa 40 diva
# & gs alslgla/aiale - of 2 (Ge?
# * 3y/V\A 8102/70 “as 40 a1va
# Cr ir
# b0S0 -onHoLva
# HYP AOL FCO ome
# 60S) : 1ybien Jan
#
# — | es
# \ Dells |T7NNN | Shh
# SC (rr OSPeMiigiu
#
#
#
# Es
# ie
# a8
# 33
# Proccessing 9124.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  9124.jpg
#
# Proccessing 984.jpg
# [('6 Ml Il', '1', 0)]
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  984.jpg
#  6 Ml Il 1 |
# Proccessing 970.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  970.jpg
#  Amount Per Serving
# Proccessing 971.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  971.jpg
#
# Proccessing 985.jpg
# [('(132keal)', '', 0)]
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  985.jpg
#  NUTRITION INFORMATION
#
# 554k]
#
# (132keal)
# Proccessing 9119.jpg
# [('12 cm x', '12 cm', 0)]
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  9119.jpg
#  12 cm x 12 cm
# Proccessing 9125.jpg
# [('Serving Size', '1 Piece (8g', 0), ('Calories', '3', 1), ('seg', '0 ciate astnee Neate ie tis en ons a', 2), ('Total FatOg', '0 0', 3), ('_.. Saturated Fa', '09 0', 4), ('CholesterolOmg', '0', 5), ('Sodium', '0mg 0', 6), ('Protein', '09 0', 7), ('Vitamin AQmg __ VitaminC Omg ______', '0', 8), ('GCalCM ONG a pagegecees gece', '0', 9), ('ron Omg eee ee eee eee e eee', '0', 10), ('Potassium Omg', '0', 11), ('serving of food contributes to a daily diet.', '2.000 calories', 12)]
#
#
#
# [('Serving Size', '1 Piece (8g', 0), ('Calories', '3', 1), ('Total FatOg', '0 0', 3), ('_.. Saturated Fa', '09 0', 4), ('CholesterolOmg', '0', 5), ('Sodium', '0mg 0', 6), ('Protein', '09 0', 7), ('Potassium Omg', '0', 11), ('serving of food contributes to a daily diet.', '2.000 calories', 12)]
#
#
#
# [('Serving Size', '1 Piece (8g', 0), ('Calories', '3', 1), ('Total FatOg', '0 0', 3), ('_.. Saturated Fa', '09 0', 4), ('CholesterolOmg', '0', 5), ('Sodium', '0mg 0', 6), ('Protein', '09 0', 7), ('Potassium Omg', '0', 11), ('serving of food contributes to a daily diet.', '2.000 calories', 12)]
#
#
#
# [('Serving Size', '1 Piece (8g', 1), ('Calories', '3', 2), ('Total Fat', '0 0', 3), ('Saturated Fat', '09 0', 4), ('Cholesterol', '0', 5), ('Sodium', '0mg 0', 6), ('Potassium', '0', 8), ('Protein', '09 0', 7)]
#
#
#
# [('Serving Size', '1 Piece (8g', 1), ('Calories', '3', 2), ('Total Fat', '0 0', 3), ('Saturated Fat', '09 0', 4), ('Cholesterol', '0', 5), ('Sodium', '0mg 0', 6), ('Potassium', '0', 8), ('Protein', '09 0', 7)]
#
#
#
#
#  Completed Labels for:
#  9125.jpg
#  Nutrition Facts
#
# Serving Size 1 Piece (8g)
# LEH SSE ae Se en
# Amount Per Serving
#
# Calories 30
# seg 0 ciate astnee Neate ie tis en ons a
# Total FatOg 0 0%
# _.. Saturated Fat09 0%
# a I a
# CholesterolOmg 0%
# Sodium 0mg 0%
#
#
#
# Protein 09 0%
# es
# Vitamin AQmg __ VitaminC Omg ______ 0%
# GCalCM ONG a pagegecees gece 0%
# ron Omg eee ee eee eee e eee 0%
# Potassium Omg 0%
#
# The % Daily Value (DV) Tells you how much am nutrient ina
# serving of food contributes to a daily diet. 2.000 calories a
# day is used for general nutrition advice.
# Proccessing 93.jpg
# [('Serve Size', '5 tsp. 2gm (072 oz', 0), ('Serving per container', '20', 1), ('Calories', '67 Fat Cal 5.', 2), ('Sodium', '48', 3), ('Total Carbohydrates', '11 3.6', 4), ('Dietary', '1.39 4.5', 5), ('Calcium', '2.5', 6), ('Iron', '4', 7), ('Sugar', '', 8), ('Protein ', '4', 9), ('Vitamin A Lass than', '1', 10), ('Vitamin G Less than', '1', 11), ('“Percent values are based on a', '2,000 calorie', 12)]
#
#
#
# [('Serve Size', '5 tsp. 2gm (072 oz', 0), ('Serving per container', '20', 1), ('Calories', '67 Fat Cal 5.', 2), ('Sodium', '48', 3), ('Total Carbohydrates', '11 3.6', 4), ('Dietary', '1.39 4.5', 5), ('Calcium', '2.5', 6), ('Sugar', '', 8), ('Protein ', '4', 9)]
#
#
#
# [('Serve Size', '5 tsp. 2gm (072 oz', 0), ('Serving per container', '20', 1), ('Calories', '67 Fat Cal 5.', 2), ('Sodium', '48', 3), ('Total Carbohydrates', '11 3.6', 4), ('Dietary', '1.39 4.5', 5), ('Calcium', '2.5', 6), ('Sugars', '', 8), ('Protein ', '4', 9)]
#
#
#
# [('Serving Size', '5 tsp. 2gm (072 oz', 1), ('Calories', '67 Fat Cal 5.', 3), ('Sodium', '48', 4), ('Total Carbohydrate', '11 3.6', 5), ('Sugars', '', 8), ('Protein', '4', 9)]
#
#
#
# [('Serving Size', '5 tsp. 2gm (072 oz', 1), ('Calories', '67 Fat Cal 5.', 3), ('Sodium', '48', 4), ('Total Carbohydrate', '11 3.6', 5)]
#
#
#
#
#  Completed Labels for:
#  93.jpg
#  eH GS
#
# Serve Size 5 tsp. 2gm (072 oz)
# Serving per container 200
#
# Amount per serving DV
# Calories 67 Fat Cal 5.5
# Total Fat ig
#
# Saturated Fat Og
#
# Cholestral Omg
#
# Sodium 480
#
# Total Carbohydrates 11 3.6%
# Dietary 1.39 4.5%
# Calcium 2.5%
# Iron 4%
# Sugar 1
#
# Protein .49
#
# Vitamin A Lass than 1%
# Vitamin G Less than 1%
# “Percent values are based on a 2,000 calories
#
# let, Your daily values may be higher or lower
# dapending on your calorie neads,
# Proccessing 997.jpg
# [('31S CUS', 'CUS', 0)]
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  997.jpg
#  31S CUS
# +h honey
# Proccessing 922.jpg
# [('Total Fat', '1.639 2.50', 0), ('Saturated Fat', '0.24q 1.2', 1), ('Trans Fat Og', '0', 2), ('Cholesterol', '10mg ae V', 3), ('Sodium', '190mg 7.91', 4), ('Total Carbohydrate', '25.129 37', 5), ('Dietary Fiber', '0', 6), ('Sugars', '117.51', 7), ('Protein', '1.2', 8), ('*Percent Daly Valued are basedon', '32000 calode die', 9)]
#
#
#
# [('Total Fat', '1.639 2.50', 0), ('Saturated Fat', '0.24q 1.2', 1), ('Trans Fat Og', '0', 2), ('Cholesterol', '10mg ae V', 3), ('Sodium', '190mg 7.91', 4), ('Total Carbohydrate', '25.129 37', 5), ('Dietary Fiber', '0', 6), ('Sugars', '117.51', 7), ('Protein', '1.2', 8)]
#
#
#
# [('Total Fat', '1.639 2.50', 0), ('Saturated Fat', '0.24q 1.2', 1), ('Trans Fat Og', '0', 2), ('Cholesterol', '10mg ae V', 3), ('Sodium', '190mg 7.91', 4), ('Total Carbohydrate', '25.129 37', 5), ('Dietary Fiber', '0', 6), ('Sugars', '117.51', 7), ('Protein', '1.2', 8)]
#
#
#
# [('Total Fat', '1.639 2.50', 1), ('Saturated Fat', '0.24q 1.2', 2), ('Trans Fat', '0', 3), ('Cholesterol', '10mg ae V', 4), ('Sodium', '190mg 7.91', 5), ('Total Carbohydrate', '25.129 37', 6), ('Dietary Fiber', '0', 7), ('Sugars', '117.51', 8), ('Protein', '1.2', 9)]
#
#
#
# [('Total Fat', '1.639 2.50', 1), ('Saturated Fat', '0.24q 1.2', 2), ('Trans Fat', '0', 3), ('Cholesterol', '10mg ae V', 4), ('Sodium', '190mg 7.91', 5), ('Total Carbohydrate', '25.129 37', 6), ('Dietary Fiber', '0', 7), ('Sugars', '117.51', 8), ('Protein', '1.2', 9)]
#
#
#
#
#  Completed Labels for:
#  922.jpg
#  vo Daily Values”
#
# Total Fat 1.639 2.50%
# Saturated Fat 0.24q 1.2%
# Trans Fat Og 0%
#
# Cholesterol 10mg ae Vo
#
# Sodium 190mg 7.91%
#
# Total Carbohydrate 25.129 37%
# Dietary Fiber 0g
# Sugars 117.519
#
# Protein 1.23
#
# *Percent Daly Valued are basedon 32000 calode diet
# Proccessing 993.jpg
# [('““YISIA SUOHS@B Bing', '5 eisai au', 0), ('ep yoy *SHUD! Oy Uy ', '2npoid TaYJO 40} 4No AC', 1), ('7 Slices Per Pack', 'Slices Per Pack', 2)]
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  993.jpg
#  (- anouddy
# Ea Lj cA)
#
# ““YISIA SUOHS@B Bing 5 eisai aus
# ep yoy *SHUD! Oy Uy S2npoid TaYJO 40} 4No ACO
#
# Se
# aelamere, te
#
# ats cheese
# BO ee
#
# a lial
#
#
#
#
#
#
#
#
#
#
#
# Viste
#
# 7 Slices Per Pack
# Proccessing 9121.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  9121.jpg
#  Pay daca Arf Acts,
# Proccessing 981.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  981.jpg
#
# Proccessing 9154.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  9154.jpg
#  ATHE€NOS
#
#
#
#
#
#
#
#
#
# 2
#
# | 8
#
# cs CHEESE
#
# SUGGESTION SEE NUTRITION INFORMATION f
#
# FOR SATURATED FAT AND f aI ve
#
# . SODIUM CONTENT
#
#
#
# fd
# Proccessing 9155.jpg
# [('Serv Size', '1 oz (28g / about 1" cube', 0), ('Servings about', 'about', 1), ('Calories', '70 Fat Cal 5', 2), ('Total Fat', '69 9', 3), ('Sat Fat', '3.59 18% | W', 4), ('Trans Fat', '0', 5), ('Cholest', '20mg 71', 6), ('Sodium', '340mg 14', 7), ('Total Carb ', '1g 0', 8), ('Fiber', '0g 0', 9), ('ugars', '0', 10), ('Protein', '5', 11), ('Vitamin A', '4% * Vitamin C 0', 12), ('Calcium', '6% = lron0%', 13), ('Perceol Dally Valnes are based on a', '2,000 calorie diel. | F', 14), ('oo"', '70277', 15)]
#
#
#
# [('Serv Size', '1 oz (28g / about 1" cube', 0), ('Servings about', 'about', 1), ('Calories', '70 Fat Cal 5', 2), ('Total Fat', '69 9', 3), ('Sat Fat', '3.59 18% | W', 4), ('Trans Fat', '0', 5), ('Cholest', '20mg 71', 6), ('Sodium', '340mg 14', 7), ('Total Carb ', '1g 0', 8), ('ugars', '0', 10), ('Protein', '5', 11), ('Calcium', '6% = lron0%', 13)]
#
#
#
# [('Serv Size', '1 oz (28g / about 1" cube', 0), ('Servings about', 'about', 1), ('Calories', '70 Fat Cal 5', 2), ('Total Fat', '69 9', 3), ('Sat Fat', '3.59 18% | W', 4), ('Trans Fat', '0', 5), ('Cholest', '20mg 71', 6), ('Sodium', '340mg 14', 7), ('Total Carb ', '1g 0', 8), ('Sugars', '0', 10), ('Protein', '5', 11), ('Calcium', '6% = lron0%', 13)]
#
#
#
# [('Serving Size', 'about', 2), ('Calories', '70 Fat Cal 5', 3), ('Total Fat', '69 9', 4), ('Saturated Fat', '3.59 18% | W', 5), ('Trans Fat', '0', 6), ('Cholesterol', '20mg 71', 7), ('Sodium', '340mg 14', 8), ('Total Carbohydrate', '1g 0', 9), ('Sugars', '0', 10), ('Protein', '5', 11)]
#
#
#
# [('Serving Size', 'about', 2), ('Calories', '70 Fat Cal 5', 3), ('Total Fat', '69 9', 4), ('Saturated Fat', '3.59 18% | W', 5), ('Trans Fat', '0', 6), ('Cholesterol', '20mg 71', 7), ('Sodium', '340mg 14', 8), ('Total Carbohydrate', '1g 0', 9), ('Sugars', '0', 10)]
#
#
#
#
#  Completed Labels for:
#  9155.jpg
#  Nutrition Facts
# Serv Size 1 oz (28g / about 1" cube)
# Servings about 8
#
# Amount / Serving
#
# Calories 70 Fat Cal 50
# % Daily Value*
#
# Total Fat 69 9%
#
#
#
#
#
# Sat Fat 3.59 18% | WI
# Trans Fat 0g
#
#
#
# Cholest 20mg 71%
# Sodium 340mg 14%
# Total Carb <1g 0%
# Fiber 0g 0%
# ugars 0g
# Protein 59
#
# a ei)
# Vitamin A 4% * Vitamin C 0%
# Calcium 6% = lron0% _
#
# Perceol Dally Valnes are based on a 2,000 calorie diel. | F”
#
# MINN
#
# oo" 70277
# Proccessing 980.jpg
# [('=', '4 Serving Size 30 S', 0)]
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  980.jpg
#  | | \ tee ee
# = 4 Serving Size 30 Ss
#
# abt | i)
#
# 5
#
# 253501°30418
# Proccessing 9120.jpg
# [('12cm x', '12cm', 0)]
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  9120.jpg
#  12cm x 12cm
# Proccessing 96.jpg
# [('Calories', '67 Fat Cal 5.', 0), ('Total Fat', '19 2', 1), ('Saturated Fat Og', '0', 2), ('Cholestrol mg', '0', 3), ('sodium', '480mg 20', 4), ('Total Carbohydrates "Wg', '3.6', 5), ('Dietary', '1.39 4.8', 6), ('Calcium', '25', 7), ('Iron', '4', 8), ('sugar', '12', 9), ('Protein', '4', 10), ('Vitamin A Lass than', '1', 11), ('Vitamin © Less than', '1', 12), ('*Percent values are based on a', '2,00) calorie', 13)]
#
#
#
# [('Calories', '67 Fat Cal 5.', 0), ('Total Fat', '19 2', 1), ('Saturated Fat Og', '0', 2), ('Cholestrol mg', '0', 3), ('sodium', '480mg 20', 4), ('Total Carbohydrates "Wg', '3.6', 5), ('Dietary', '1.39 4.8', 6), ('Calcium', '25', 7), ('sugar', '12', 9), ('Protein', '4', 10)]
#
#
#
# [('Calories', '67 Fat Cal 5.', 0), ('Total Fat', '19 2', 1), ('Saturated Fat Og', '0', 2), ('Cholestrol mg', '0', 3), ('sodium', '480mg 20', 4), ('Total Carbohydrates "Wg', '3.6', 5), ('Dietary', '1.39 4.8', 6), ('Calcium', '25', 7), ('Sugars', '12', 9), ('Protein', '4', 10)]
#
#
#
# [('Calories', '67 Fat Cal 5.', 1), ('Total Fat', '19 2', 2), ('Saturated Fat', '0', 3), ('Cholesterol', '0', 4), ('Sodium', '480mg 20', 5), ('Total Carbohydrate', '3.6', 6), ('Sugars', '12', 9), ('Protein', '4', 10)]
#
#
#
# [('Calories', '67 Fat Cal 5.', 1), ('Total Fat', '19 2', 2), ('Saturated Fat', '0', 3), ('Cholesterol', '0', 4), ('Sodium', '480mg 20', 5), ('Total Carbohydrate', '3.6', 6)]
#
#
#
#
#  Completed Labels for:
#  96.jpg
#  Calories 67 Fat Cal 5.5
#
# Total Fat 19 2%
# Saturated Fat Og 0%
# Cholestrol mg 0%
# sodium 480mg 20%
# Total Carbohydrates "Wg 3.6%
# Dietary 1.39 4.8%
# Calcium 25%
# Iron 4%
# sugar 129
#
# Protein 49
#
# Vitamin A Lass than 1%
# Vitamin © Less than 1%
#
# *Percent values are based on a 2,00) calories
# Get, Your daily values may be higher or lower
# @apending on your calorie needs,
# Proccessing 992.jpg
# [("qn'07 MIDPSuaU pap: MMM", 'MIDPSuaU pap: MMM', 0), ('“YSIA SUOHS®BE yg', '5', 1), (':', '391 pup', 2), ('joys', '104 CUS Uy $2npoid saujo 10} 4no AOC', 3), ('7 Slices Per Pack:', 'Slices Per Pack:', 4), ('Ber Acasa eels Per', '125', 5)]
#
#
#
# [("qn'07 MIDPSuaU pap: MMM", 'MIDPSuaU pap: MMM', 0)]
#
#
#
# [("qn'07 MIDPSuaU pap: MMM", 'MIDPSuaU pap: MMM', 0)]
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  992.jpg
#  Ea Lys Ew
#
# qn'07 MIDPSuaU pap: MMM
#
# “YSIA SUOHS®BE yg 5,
# : 391 pup
# joys 104 CUS Uy $2npoid saujo 10} 4no AOCT
#
# + :
# delamere ™
#
# ats cneese
# One
#
#
#
#
#
#
# sysPi>
#
#
#
#
#
#
#
#
# A
#
#
#
# 125g
#
# 7 Slices Per Pack:
#
#
#
# Ber Acasa eels Per 125g
#
# er
# eae L PAM tn i
# Proccessing 921.jpg
# [('Serving Size', '1 (40g', 0), ('Calories', '170 Calories fram Fat 1', 1), ('Total Fat', '1.639 2.50%', 2), ('Saturated Fat', '0. 24g 1.2', 3), ('Trans Fat Og', '0%', 4), ('Cholesterol', '10mg 2.32%', 5), ('Sodium', '190mg 7.91%', 6), ('Total Carbohydrate', '25.129 8.37', 7), ('Sugars', '11.51', 8), ('Protein', '1.2', 9), ('*Percent Dally Valued are basedon a', '2,000 calorie die', 10)]
#
#
#
# [('Serving Size', '1 (40g', 0), ('Calories', '170 Calories fram Fat 1', 1), ('Total Fat', '1.639 2.50%', 2), ('Saturated Fat', '0. 24g 1.2', 3), ('Trans Fat Og', '0%', 4), ('Cholesterol', '10mg 2.32%', 5), ('Sodium', '190mg 7.91%', 6), ('Total Carbohydrate', '25.129 8.37', 7), ('Sugars', '11.51', 8), ('Protein', '1.2', 9)]
#
#
#
# [('Serving Size', '1 (40g', 0), ('Calories', '170 Calories fram Fat 1', 1), ('Total Fat', '1.639 2.50%', 2), ('Saturated Fat', '0. 24g 1.2', 3), ('Trans Fat Og', '0%', 4), ('Cholesterol', '10mg 2.32%', 5), ('Sodium', '190mg 7.91%', 6), ('Total Carbohydrate', '25.129 8.37', 7), ('Sugars', '11.51', 8), ('Protein', '1.2', 9)]
#
#
#
# [('Serving Size', '1 (40g', 1), ('Calories', '170 Calories fram Fat 1', 2), ('Total Fat', '1.639 2.50%', 3), ('Saturated Fat', '0. 24g 1.2', 4), ('Trans Fat', '0%', 5), ('Cholesterol', '10mg 2.32%', 6), ('Sodium', '190mg 7.91%', 7), ('Total Carbohydrate', '25.129 8.37', 8), ('Sugars', '11.51', 9), ('Protein', '1.2', 10)]
#
#
#
# [('Serving Size', '1 (40g', 1), ('Calories', '170 Calories fram Fat 1', 2), ('Total Fat', '1.639 2.50%', 3), ('Saturated Fat', '0. 24g 1.2', 4), ('Trans Fat', '0%', 5), ('Cholesterol', '10mg 2.32%', 6), ('Sodium', '190mg 7.91%', 7), ('Total Carbohydrate', '25.129 8.37', 8), ('Sugars', '11.51', 9), ('Protein', '1.2', 10)]
#
#
#
#
#  Completed Labels for:
#  921.jpg
#  Nutrition Facts
# Serving Size 1 (40g)
#
# Amount Per Serving
# Calories 170 Calories fram Fat 15
#
# % Daily Values*
# Total Fat 1.639 2.50%.
# Saturated Fat 0. 24g 1.2%
# Trans Fat Og 0%.
# Cholesterol 10mg 2.32%.
# Sodium 190mg 7.91%.
# Total Carbohydrate 25.129 8.37%
# Dietary Fiber Og
# Sugars 11.519
# Protein 1.23
# *Percent Dally Valued are basedon a 2,000 calorie diet
# Proccessing 94.jpg
# [('Serve Size', '5 tsp. 2gm (.072 oz', 0), ('Serving per container', '20', 1), ('Calories', '67 Fat Cal 5.', 2), ('Sodium', '48', 3), ('Total Carbohydrates', '11 3.6', 4), ('Dietary', '1.39 4.8', 5), ('Calcium', '25', 6), ('Iron', '4', 7), ('Sugar', '', 8), ('Protein ', '4', 9), ('Vitamin A Lass than', '1', 10), ('Vitamin G Less than', '1', 11), ('*Percent values are based on a', '2,000 calorie', 12)]
#
#
#
# [('Serve Size', '5 tsp. 2gm (.072 oz', 0), ('Serving per container', '20', 1), ('Calories', '67 Fat Cal 5.', 2), ('Sodium', '48', 3), ('Total Carbohydrates', '11 3.6', 4), ('Dietary', '1.39 4.8', 5), ('Calcium', '25', 6), ('Sugar', '', 8), ('Protein ', '4', 9)]
#
#
#
# [('Serve Size', '5 tsp. 2gm (.072 oz', 0), ('Serving per container', '20', 1), ('Calories', '67 Fat Cal 5.', 2), ('Sodium', '48', 3), ('Total Carbohydrates', '11 3.6', 4), ('Dietary', '1.39 4.8', 5), ('Calcium', '25', 6), ('Sugars', '', 8), ('Protein ', '4', 9)]
#
#
#
# [('Serving Size', '5 tsp. 2gm (.072 oz', 1), ('Calories', '67 Fat Cal 5.', 3), ('Sodium', '48', 4), ('Total Carbohydrate', '11 3.6', 5), ('Sugars', '', 8), ('Protein', '4', 9)]
#
#
#
# [('Serving Size', '5 tsp. 2gm (.072 oz', 1), ('Calories', '67 Fat Cal 5.', 3), ('Sodium', '48', 4), ('Total Carbohydrate', '11 3.6', 5)]
#
#
#
#
#  Completed Labels for:
#  94.jpg
#  Serve Size 5 tsp. 2gm (.072 oz)
# Serving per container 200
#
# Amount per serving % DV
# Calories 67 Fat Cal 5.5
# Total Fat ig
#
# Salurated Fai Og
#
# Cholestral Omg
#
# Sodium 480
#
# Total Carbohydrates 11 3.6%
# Dietary 1.39 4.8%
# Calcium 25%
# Iron 45
# Sugar 1
#
# Protein .49
#
# Vitamin A Lass than 1%
# Vitamin G Less than 1%
#
# *Percent values are based on a 2,000 calories
# diet. Your daily values. may be higher or lower
# dapanding on your calorie needs.
# Proccessing 9122.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  9122.jpg
#
# Proccessing 982.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  982.jpg
#
# Proccessing 9157.jpg
# [('(28g / about', '1" cube', 0), ('pout', '', 1), ('4% « Vitamin C', '0', 2), ('Yo _* tron', '0% _', 3), ('sare based on a', '2,000 calorie diet', 4)]
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  9157.jpg
#  ion Facts
# (28g / about 1" cube)
# pout 8
#
#
#
#
# 4% « Vitamin C 0%
# Yo _* tron 0% __
# sare based on a 2,000 calorie diet.
# Proccessing 9156.jpg
# [('ne uae', '1 0z (28g / about 1" cube) | PASTEURIZED PART-SKI', 0), ('Paiclum', '622 = tron Ce |B 02 Pe UA AED EA', 1)]
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  9156.jpg
#  trition Facts
#
# INGREDIENTS:
#
# ne uae 1 0z (28g / about 1" cube) | PASTEURIZED PART-SKIM
#
#
#
# MILK, CHEESE CULTURE,
# SALT, ENZYMES,
#
# Paiclum 622 = tron Ce |B 02 Pe UA AED EAS
#
# UN,
# Proccessing 983.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  983.jpg
#
# Proccessing 9123.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  9123.jpg
#
# Proccessing 95.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  95.jpg
#
# Proccessing 97.jpg
# [('and keeps in the cupboard serves', '4 See aCe aC', 0), ('5 Reference Intake (RI) (adult)', 'Reference Intake (RI) (adult)', 1), ('Store in a cool dry place.', '20g, bil ee', 2), ('pe ol ite rel)', '120mg (15%) per 100ml/300mg pe', 3), ('TT al Rolo ban portion ', '250ml). 300mg is 37.5% of an adults 5 "', 4)]
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  97.jpg
#  Delamere Dairy
#
# RR ec Mca milk For recipes, information and
#
# where to buy, contact us.
# Our milk is carefully heat
# treated to give you a long-life
# cows’ milk that’s extra delicious.
# It’s as nutritious as fresh milk Nutritional information:
# and keeps in the cupboard serves 4 See aCe aCe
#
# ei Ake ato ML typical values
# kJ/kcal Take a look at our lovely website...
#
# Send us an email
#
# Did you know Delamere milk has
#
# Q brilliant flavour and it's fat Raa e i follow us On # Ff
#
# free! It's ideal for cooking and
# baking. Plus it’s also great in your
# tea or coffee. Visit our website
# for delicious recipe tdeas.
#
# carbohydrate
# of which sugars
#
# 5 Reference Intake (RI) (adult)
# torage:
# Sarees Een ain selec Toh
# Store in a cool dry place. 20g, bil ee)
# pe ol ite rel) 120mg (15%) per 100ml/300mg per
#
# TT al Rolo ban portion (250ml). 300mg is 37.5% of an adults 5 "9
# Best before see bottle neck. Nutrient Reference Intake (NRI)
# Proccessing 920.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  920.jpg
#
# Proccessing 932.jpg
# [('ecarhell', '55m 8 eck a', 0), ('ub bose', '5 lel dis « Ji', 1), ('Eel) te psa (al pull)', '6 al p', 2)]
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  932.jpg
#  Allergen Warning: May Contain Tree
# Nuts, Wheat Gluten and Mustard
#
# Ingredients: Cumin Seed, Black
# Pepper, Cinnamon, Cardamom,
# Mace, Cloves, Bay Leaves &
# Nutmeg
#
# Ingrédients: graines de cumin,
# paivre noir, cannelle, cardamome,
# mace, clous de girofle, feuilles de
# laurier et noix de muscade
#
# gad Salh ecy gS Tye rub Sal
#
# ecarhell 55m 8 eck aS
# ub bose 5 lel dis « Jie
# Net Wt, MFG Date, Bast Before, Batch No &
# MRP (Incl. of all taxes) Coded on the jar/label
# AD gy oelgs Garb egal Gal alla wis
# Eel) te psa (al pull) 6 al pe
#
# Store in a cool and dry place
# Proccessing 9111.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  9111.jpg
#
# Proccessing 964.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  964.jpg
#
# Proccessing 958.jpg
# [('FH? VO SUED Perper FU ITEC A IFIP wie maety TIER ', '602LS1¥25526)', 0), ('rst om sty rr', '2H (ih KR) IO omsty ro 2 COST', 1)]
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  958.jpg
#  oy Bh (pert? ~ (EOD igor” OT SI
#
# FH? VO SUED Perper FU ITEC A IFIP wie maety TIER E602LS1¥25526) 9
# DET HO ory cel cD OE eh -
#
# rst om sty rr 2H (ih KR) IO omsty ro 2 COSTA
#
# PSEA eg I Teg RIC MEY (MECH iPr )
#
# warp eof ery ( see? per ip - ee? mip )
#
# ISPD: mest ly [pee soe
#
# STEM TSP STR (ROIS
# Proccessing 9140.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  9140.jpg
#
# Proccessing 976.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  976.jpg
#  Pe
# Proccessing 977.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  977.jpg
#
# Proccessing 959.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  959.jpg
#
# Proccessing 965.jpg
# [('Serving Size', '40', 0), ('serving Per Container:', '2', 1), ('itamin AO% Vitamin C', '0', 2), ('Calcium', '0% j|lron 0', 3)]
#
#
#
# [('Serving Size', '40', 0), ('serving Per Container:', '2', 1), ('Calcium', '0% j|lron 0', 3)]
#
#
#
# [('Serving Size', '40', 0), ('Sugars', '2', 1), ('Calcium', '0% j|lron 0', 3)]
#
#
#
# [('Serving Size', '40', 1), ('Calories', '0% j|lron 0', 3), ('Sugars', '2', 2)]
#
#
#
# [('Serving Size', '40', 1), ('Calories', '0% j|lron 0', 3), ('Sugars', '2', 2)]
#
#
#
#
#  Completed Labels for:
#  965.jpg
#  NUTRITION FACTS
# Serving Size:409
# serving Per Container: 24
#
#
#
# itamin AO% Vitamin C 0%
# Calcium 0% j|lron 0%
# Proccessing 933.jpg
# [('Serving Size:', '8 g (1itbsp', 0), ('Servings per package:', '1', 1), ('adult dint of AF', '0KJ, Your daily intakes ma', 2)]
#
#
#
# [('Serving Size:', '8 g (1itbsp', 0), ('Servings per package:', '1', 1)]
#
#
#
# [('Serving Size:', '8 g (1itbsp', 0), ('Servings per package:', '1', 1)]
#
#
#
# [('Serving Size', '8 g (1itbsp', 1)]
#
#
#
# [('Serving Size', '8 g (1itbsp', 1)]
#
#
#
#
#  Completed Labels for:
#  933.jpg
#  NUTRITION INFORMATION
# Serving Size: 8 g (1itbsp)
# Servings per package: 12
#
# “% Daily Intakes are based on an average
# adult dint of AFO0KJ, Your daily intakes may
# bo higher or lower depending on your
# Proccessing 931.jpg
# [('Serving Size:', '8g (1tbsp', 0)]
#
#
#
# [('Serving Size:', '8g (1tbsp', 0)]
#
#
#
# [('Serving Size:', '8g (1tbsp', 0)]
#
#
#
# [('Serving Size', '8g (1tbsp', 1)]
#
#
#
# [('Serving Size', '8g (1tbsp', 1)]
#
#
#
#
#  Completed Labels for:
#  931.jpg
#  NUTRITION INFORMAI
# Serving Size: 8g (1tbsp)
# Serving
#
#
#
#
#
# Ory
# etry
#
# Roar
#
# 13009
# Proccessing 9112.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  9112.jpg
#
# Proccessing 975.jpg
# [('6', '"253501 Il', 0)]
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  975.jpg
#  6 "253501 Il
# Proccessing 974.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  974.jpg
#
# Proccessing 9113.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  9113.jpg
#
# Proccessing 930.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  930.jpg
#
# Proccessing 9109.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  9109.jpg
#  ee
#
# TPE i vat
#
# —_ 2
# Proccessing 9117.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  9117.jpg
#
# Proccessing 934.jpg
# [('Serving Size:', '8g (1tbsp', 0), ('Servings per package:', '1', 1), ('“9S Dally Intakes are based on an averige', 'Dally Intakes are based on an averige', 2)]
#
#
#
# [('Serving Size:', '8g (1tbsp', 0), ('Servings per package:', '1', 1)]
#
#
#
# [('Serving Size:', '8g (1tbsp', 0), ('Servings per package:', '1', 1)]
#
#
#
# [('Serving Size', '8g (1tbsp', 1)]
#
#
#
# [('Serving Size', '8g (1tbsp', 1)]
#
#
#
#
#  Completed Labels for:
#  934.jpg
#  NUTRITION INFORMATION
# Serving Size: 8g (1tbsp)
# Servings per package: 12
#
# Protein
#
# Fat — Total
#
# = Saturated
# — Trans
# Carbohydrate
# — Sugars
#
# Sodium
# Dietary Fiber
# Vitamin A
# Vitamin C.
# Calcium
#
# lran
# “9S Dally Intakes are based on an averige
# adult dimt of BPOOKJ. ‘Your daily intakes may
#
# be higher or lower depending on your
# energy needs.
#
# Nliiclecseest
# Proccessing 962.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  962.jpg
#
# Proccessing 939.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  939.jpg
#
# Proccessing 990.jpg
# [('Serv. Size', '1/4 Cup (30g', 0), ('Chalories', '', 1), ('Total Fat', '0g t', 2), ('on', '2.000 Calorie diet', 3), ('Pep) eet ren eevee -v ey) vere', '0', 4), ('Gross Wt :', '14 K', 5), ('Netwt ', '12K', 6), ('Liquid Wt :', '8 K', 7)]
#
#
#
# [('Serv. Size', '1/4 Cup (30g', 0), ('Chalories', '', 1), ('Total Fat', '0g t', 2)]
#
#
#
# [('Serv. Size', '1/4 Cup (30g', 0), ('Chalories', '', 1), ('Total Fat', '0g t', 2)]
#
#
#
# [('Serving Size', '1/4 Cup (30g', 1), ('Calories', '', 2), ('Total Fat', '0g t', 3)]
#
#
#
# [('Serving Size', '1/4 Cup (30g', 1), ('Calories', '', 2), ('Total Fat', '0g t', 3)]
#
#
#
#
#  Completed Labels for:
#  990.jpg
#  Onions
#
# NUTRITION FACTS
#
# Serv. Size 1/4 Cup (30g)
# Serving about :
#
# Amount per serving
# Chalories 0
#
# ym?" hes
# Total Fat 0g tt
# Tele ue Mile) oA
# Bele er emetic)
#
# Percent Daily Values are based
# on 2.000 Calorie diet
#
# yell oe
#
# MINN
#
# 772504490918
#
# Deets Frey
# Beare Ra creel: aoe RO) ona alt ee
# Rett reyes ee et per ere
# Pep) eet ren eevee -v ey) vere 0)
# Fly | Peer Rene Fey Ce Payer Ces]
# 012 69 89 500 - 05018 12 538
# Se ev ere Ne Dee Tee aay
# PTR LL Pence
#
# Cyr) Fee eee SAY ere we Cow
#
# Amey Ey ete ee ee eee |
#
# ere eee her are radi
#
# ~ sla -J- ay : LigSall
# Fan EGR | ae pt Gt | YOO ES
# Ne aera mel Cal eet le ood
#
# See LOS SL
# Ing.: Onions - water - Salt - sugar cane solution
# err ome cc eee el cme
#
# Gross Wt : 14 Kg
#
# Netwt :12Kg
#
# Liquid Wt : 8 Kg
#
# Product by :Al Badawy Factory for
# CCR Meee em aD eee g
#
# Storage and handling in a cool dry place
# Refrigerate Afteropening
#
# Valid for one year from production date
# Proccessing 991.jpg
# [('772504 mM ls |', 'mM ls |', 0)]
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  991.jpg
#  772504 mM ls |
# Proccessing 938.jpg
# [('Sensing Size', '21Dsp. (30g', 0), ('‘Serving Pet Container about', '1', 1)]
#
#
#
# [('Sensing Size', '21Dsp. (30g', 0), ('‘Serving Pet Container about', '1', 1)]
#
#
#
# [('Sensing Size', '21Dsp. (30g', 0), ('‘Serving Pet Container about', '1', 1)]
#
#
#
# [('Serving Size', '21Dsp. (30g', 1)]
#
#
#
# [('Serving Size', '21Dsp. (30g', 1)]
#
#
#
#
#  Completed Labels for:
#  938.jpg
#  Nutrition Facts
# Sensing Size 21Dsp. (30g)
# ‘Serving Pet Container about 12
#
# |
#
# 2830
#
# 12
#
# 20417
# Proccessing 963.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  963.jpg
#
# Proccessing 935.jpg
# [('(hl sll aja) Vuule alla Gyaue |(@o AMIE! O', '19S', 0)]
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  935.jpg
#  GARAM MASALA POWDER
# Epices chaudes Poudre
# (hl sll aja) Vuule alla Gyaue |(@o AMIE! On19S)
# Proccessing 9108.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  9108.jpg
#
# Proccessing 9116.jpg
# [('Sodium', '7iomg', 0), ('Tat! Carbohydrate', "16q A'", 1), ('Protein', '2', 2)]
#
#
#
# [('Sodium', '7iomg', 0), ('Tat! Carbohydrate', "16q A'", 1), ('Protein', '2', 2)]
#
#
#
# [('Sodium', '7iomg', 0), ('Sugars', "16q A'", 1), ('Protein', '2', 2)]
#
#
#
# [('Sodium', '7iomg', 1), ('Sugars', "16q A'", 2), ('Protein', '2', 3)]
#
#
#
# [('Sodium', '7iomg', 1), ('Sugars', "16q A'", 2), ('Protein', '2', 3)]
#
#
#
#
#  Completed Labels for:
#  9116.jpg
#  VPM Sete ving Ue
#
#
#
# Sodium 7iomg a
# Tat! Carbohydrate 16q A's
# Gletary Fiber ig Er
# Blgars Oy
#
# Protein 29
# Proccessing 9114.jpg
# [('Serving Size ', '28g', 0), ('Serving per container ', '1', 1), ('Calories', '15', 2), ('Saturated Fal', '1', 3), ('Sodium', '210m', 4), ('Tota! Carbohydrate', '16', 5), ('Vitamin A', '4% Vitamin C 0', 6), ('Calcium', '4% - Iron 2', 7), ('“Percent Daily Values are based on a', '2,00', 8), ('Calories:', '2,060 2,50', 9), ('‘Total Fit Leeethan', '68g Bo', 10), ('Fat', '9. Carbohydrate 4. Protein', 11)]
#
#
#
# [('Serving Size ', '28g', 0), ('Serving per container ', '1', 1), ('Calories', '15', 2), ('Saturated Fal', '1', 3), ('Sodium', '210m', 4), ('Tota! Carbohydrate', '16', 5), ('Calcium', '4% - Iron 2', 7), ('Calories:', '2,060 2,50', 9), ('‘Total Fit Leeethan', '68g Bo', 10)]
#
#
#
# [('Serving Size ', '28g', 0), ('Serving per container ', '1', 1), ('Calories', '15', 2), ('Saturated Fal', '1', 3), ('Sodium', '210m', 4), ('Tota! Carbohydrate', '16', 5), ('Calcium', '4% - Iron 2', 7), ('Calories:', '2,060 2,50', 9), ('‘Total Fit Leeethan', '68g Bo', 10)]
#
#
#
# [('Serving Size', '28g', 1), ('Calories', '15', 3), ('Saturated Fat', '1', 4), ('Sodium', '210m', 5), ('Total Carbohydrate', '16', 6)]
#
#
#
# [('Serving Size', '28g', 1), ('Calories', '15', 3), ('Saturated Fat', '1', 4), ('Sodium', '210m', 5)]
#
#
#
#
#  Completed Labels for:
#  9114.jpg
#  Nutrition Facts
#
# Serving Size (28g)
# Serving per container (1)
#
# Amount Per Serving
# Calories 150
#
# i
# 2
#
# Total Fat og
# Saturated Fal 1g
#
# Cholesterol om
#
# Sodium 210m,
# Tota! Carbohydrate 169
# Dietary Fiber ig
#
# | Sugars Og
#
# Protein zg
#
# #135
#
# 21212
#
# Vitamin A 4% Vitamin C 0%
#
# Calcium 4% - Iron 2%
#
# “Percent Daily Values are based on a 2,000
# calorie diet Your daily valees may be higher
# or lower depending on your calorie needs.
#
# Calories: 2,060 2,500
#
# ‘Total Fit Leeethan 68g Bog
# Saturated Fat. Loss than
#
# ‘Cholesterol Lesa than
#
# ‘Sedium Lesa than
#
# Total Carbohydrate
# Dietary Fiber Ba
#
# Calories par gram;
# Fat 9. Carbohydrate 4. Protein 4
# Proccessing 937.jpg
# [('Phone :', '8809613/3/7/1T', 0), ('Toll Free: ', '88080077777 i', 1)]
#
#
#
# [('Toll Free: ', '88080077777 i', 1)]
#
#
#
# [('Toll Free: ', '88080077777 i', 1)]
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  937.jpg
#  Customer Relations Dept
# Phone :+8809613/3/7/1T?
#
# Toll Free: +88080077777 i?
# E-mail: erdi@m@e !
#
# Product of Bangladesh
#
# Produit de Bangladesh
# ale ll
# Proccessing 961.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  961.jpg
#
# Proccessing 9149.jpg
# [('OFS', '792259 - OF S89017SR : all', 0)]
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  9149.jpg
#  : aliil
#
# | ERA
# INTELLIGENCE
# FOUNDATION
#
# ae ns.
#
#
#
#
# dufliéll slgall gijgig dylall
# boned = plo
# OFSG792259 - OF S89017SR : alls
# Proccessing 973.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  973.jpg
#
# Proccessing 972.jpg
# [('Sie', '305 E', 0), ('6°253501°304', '168) ; seni', 1)]
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  972.jpg
#  4h
#
# | | y Uiitneo ee Col
# Sie 305 E
#
# 6°253501°304 168) ; seni
# Proccessing 9148.jpg
# [('Cholesterol oma', '0', 0), ('Sodium', '2509 10%', 1), ('Total Carb drate ', '3g 4', 2), ('Dietray Fiberlessthanig', '2', 3)]
#
#
#
# [('Cholesterol oma', '0', 0), ('Sodium', '2509 10%', 1), ('Total Carb drate ', '3g 4', 2), ('Dietray Fiberlessthanig', '2', 3)]
#
#
#
# [('Cholesterol oma', '0', 0), ('Sodium', '2509 10%', 1), ('Total Carb drate ', '3g 4', 2), ('Dietray Fiberlessthanig', '2', 3)]
#
#
#
# [('Cholesterol', '0', 1), ('Sodium', '2509 10%', 2), ('Total Carbohydrate', '3g 4', 3)]
#
#
#
# [('Cholesterol', '0', 1), ('Sodium', '2509 10%', 2), ('Total Carbohydrate', '3g 4', 3)]
#
#
#
#
#  Completed Labels for:
#  9148.jpg
#  Trans Fat og
# Cholesterol oma 0%
# Sodium 2509 10%.
# Total Carb drate i3g 4%
#
# Dietray Fiberlessthanig 2%
#
# sugars Og
# Proccessing 960.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  960.jpg
#
# Proccessing 936.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  936.jpg
#
# Proccessing 9115.jpg
# [('Serving Size ', '28g', 0), ('Serving per container ', '1', 1), ('Vitamin Ad | Vitaminc', '0', 2), ('Calcium', '4% _- Iron 2', 3), ('“Parcent Dally Values are based on a', '2,00', 4), ('Calories:', '2,000 2,50', 5), ('‘Tatal Fat Leeethan', '85g Ad', 6), ('Saturated Fat Lessthan', '20g i', 7), ('‘Cholesterol Lesathan', '200mg 30m', 8), ('Sodium Lesathan za', '0mg  z.400m', 9), ('Total Carbohydrate', '00g avti', 10), ('Dietary Fiber', '2 ao', 11), ('Fat ®. Garbohyerate', '4. Protein', 12)]
#
#
#
# [('Serving Size ', '28g', 0), ('Serving per container ', '1', 1), ('Calcium', '4% _- Iron 2', 3), ('Calories:', '2,000 2,50', 5), ('‘Tatal Fat Leeethan', '85g Ad', 6), ('Saturated Fat Lessthan', '20g i', 7), ('‘Cholesterol Lesathan', '200mg 30m', 8), ('Sodium Lesathan za', '0mg  z.400m', 9), ('Total Carbohydrate', '00g avti', 10), ('Dietary Fiber', '2 ao', 11), ('Fat ®. Garbohyerate', '4. Protein', 12)]
#
#
#
# [('Serving Size ', '28g', 0), ('Serving per container ', '1', 1), ('Calcium', '4% _- Iron 2', 3), ('Calories:', '2,000 2,50', 5), ('‘Tatal Fat Leeethan', '85g Ad', 6), ('Saturated Fat Lessthan', '20g i', 7), ('‘Cholesterol Lesathan', '200mg 30m', 8), ('Sodium Lesathan za', '0mg  z.400m', 9), ('Total Carbohydrate', '00g avti', 10), ('Dietary Fiber', '2 ao', 11), ('Fat ®. Garbohyerate', '4. Protein', 12)]
#
#
#
# [('Serving Size', '28g', 1), ('Calories', '2,000 2,50', 4), ('Total Carbohydrate', '00g avti', 9), ('Dietary Fiber', '2 ao', 10)]
#
#
#
# [('Serving Size', '28g', 1), ('Calories', '2,000 2,50', 4), ('Total Carbohydrate', '4. Protein', 11)]
#
#
#
#
#  Completed Labels for:
#  9115.jpg
#  Nutrition Facts
#
# Serving Size (28g)
# Serving per container (1)
#
# Vitamin Ad | Vitaminc 0%
#
# Calcium 4% _- Iron 2%
#
# “Parcent Dally Values are based on a 2,000
# ealorie diet Your daily values may be higher
# or lower depending on your caloria mands.
#
# Calories: 2,000 2,500
#
# ‘Tatal Fat Leeethan 85g Ady
# Saturated Fat Lessthan 20g iq
# ‘Cholesterol Lesathan 200mg 30mg
# Sodium Lesathan zac0mg  z.400mg
# Total Carbohydrate 00g avtig
# Dietary Fiber 2 aoa
# ‘Calorins por gram:
# Fat ®. Garbohyerate 4. Protein 4
# Proccessing 9118.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  9118.jpg
#
# Proccessing 9106.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  9106.jpg
#
# Proccessing 999.jpg
# [('Energy kal Tkeal ', '36 koa', 0), ('Fat', '9 a', 1), ('87 Moo', '1;Tumbol Nongklangna', 2), (', ETs', '0— Epdewo T', 3), ('Graphic |', '2¥< | A grcode [Situ', 4), ('PURE COCONUT WATER', '30 i 11) | E-Mail: #1 / JUNE 05, 201', 5), ('2H', '09 wm =) Goo Paper |', 6), ('(209)', '206) 22] atonal) eset Cin sam | ua Cr pin pth ny esi ofr erea', 7), ('Asef', '1 (V1). TUM 05/06/18 : Ally Wording Hawa 7M File Mail anf (CANNED COCONUT WATER SIZE 330 ML.ai', 8)]
#
#
#
# [('Energy kal Tkeal ', '36 koa', 0)]
#
#
#
# [('Energy kal Tkeal ', '36 koa', 0)]
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  999.jpg
#  CRAFTED
#
# WITH HEART
#
# Meticulousness is our most vital
# ingredient. We put our heart and
# soul in every step taken,
# assuring the finest quality
# and true satisfaction.
#
# Our coconut water comes from
# Green Coconuts which are
# grown in Thailand with delicately
# hand-picked selection for
# highest quality to deliver
#
# its natural taste and
# fresh scent in every sip
# that keep you coming for more.
#
#
#
# Best Served Chilled
#
# 8 | 4,06 |
#
# 0227 "022
#
#
#
#
#
#
#
#
# RE
#
#
#
#
#
#
#
#
#
#
# cnt
#
# [Energy kl
#
# Energy kal Tkeal ‘36 koal
#
# Fat 9 a
# of which :
#
# ...
#
#
#
#
#  Completed Labels for:
#  9142.jpg
#
# Proccessing 945.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  945.jpg
#
# Proccessing 9101.jpg
# [('Nutrition per', '100 mL per servin', 0), ('Toilette', '1 Can (330 mL', 1), ('Energy —', '71 kJ 235 k', 2), ('Enera v =', '6 c', 3), ('Carbohydrate', '43', 4), ('- Sugars', '2.7', 5)]
#
#
#
# [('Energy —', '71 kJ 235 k', 2), ('Enera v =', '6 c', 3), ('Carbohydrate', '43', 4), ('- Sugars', '2.7', 5)]
#
#
#
# [('Energy —', '71 kJ 235 k', 2), ('Enera v =', '6 c', 3), ('Carbohydrate', '43', 4), ('Sugars', '2.7', 5)]
#
#
#
# [('Energy', '71 kJ 235 k', 1), ('Total Carbohydrate', '43', 3), ('Sugars', '2.7', 4)]
#
#
#
# [('Energy', '71 kJ 235 k', 1), ('Total Carbohydrate', '43', 3)]
#
#
#
#
#  Completed Labels for:
#  9101.jpg
#  Nutrition per 100 mL per serving
# Toilette 1 Can (330 mL)
#
# Energy — 71 kJ 235 kJ
#
# Enera v = 6 ca
#
# Carbohydrate 43g
# of which :
# - Sugars 2.79
# Proccessing 928.jpg
# [('‘Serving Size:', '8 g (1tbsp', 0), ('m2 GARAM MASALA POWDER [Mm =. | ©', 'GARAM MASALA POWDER [Mm =. | ©', 1), ('sgh Bhi Petia (dul sl guj) Vsbe al lo Grae [Oo MIA! ', '198', 2), ('ecuslell Sym', '3S che', 3), ('abl Sse', '5 lal) By « d', 4), ('Gost ', '8 hal B', 5), ('AAW * YO SAAN VAY', '2 iL', 6), ('RAS YOAA FV ENE', '2 iSh', 7), ('DL) -oby S- zs', '5', 8), ('Dallbyegiss ae', '2 : ;', 9), ('Net wt.:', '80', 10)]
#
#
#
# [('‘Serving Size:', '8 g (1tbsp', 0)]
#
#
#
# [('‘Serving Size:', '8 g (1tbsp', 0)]
#
#
#
# [('Serving Size', '8 g (1tbsp', 1)]
#
#
#
# [('Serving Size', '8 g (1tbsp', 1)]
#
#
#
#
#  Completed Labels for:
#  928.jpg
#  Allergen Warning: May Contain Tree
#
#
#
#
#
# Nuts, Wheat Gluten and Mustard
#
#
#
# NUTRITION INFORMATION
# ‘Serving Size: 8 g (1tbsp)
#
#
#
# Ingredients: Cumin Seed, Black Sends per pncrage.
# Pepper, Cinnamon, Cardamom,
#
# m2 GARAM MASALA POWDER [Mm =. | ©
#
# Fat - Total
# Ingrédients: graines de cumin,
# Poivre noir, cannelle, cardamome,
#
# mace, clous de girofle, feulles de Epices chaudes Poudre
#
# laurier et noix de muscade
#
# sgh Bhi Petia (dul sl guj) Vsbe al lo Grae [Oo MIA! A198)
# ecuslell Sym 3S che A
#
# abl Sse 5 lal) By « dS
#
#
#
# Eidelaseses
#
#
#
#
#
#
#
#
#
# Not Wt, MEG Date, Bost Before, Batch No &
# MRP (Inc. ofall taxes) Coded on the jaf
#
# Gost G8 hal BP
# bd le pe alga)
#
# Store in a cool and dry place
#
#
#
#
#
#
#
# er nue
#
# Fogel of Paine
# fo Bangladesh
# sSlen clit
#
#
#
# Ge Dia ONY Sa
# AAW * YO SAAN VAY 2 iLa
# RAS YOAA FV ENE 2 iShS
#
# DL) -oby S- zs 5 -
# Dallbyegiss ae 2 : ; ’
# 116541300
#
# 4
#
# Net wt.: 80g
# ey Sarees eee)
# Proccessing 9103.jpg
# [('LAI! Ligll jg> clo', '1 GbgSal', 0)]
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  9103.jpg
#  Al Vigll jg> elo
# LAI! Ligll jg> clo 1 GbgSall
# Uo YY: Slall wg!
# wb slice)! ob
# v\e\er slg day
#
# produced by thai coconut pcl
# Proccessing 947.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  947.jpg
#
# Proccessing 927.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  927.jpg
#
# Proccessing 916.jpg
# [('Milk', '1I', 0), ('JT (reid oS) penal &', '9 Fhe 5 cle get Spe', 1), ('assall €', '9 jhe plime iy Gul :cLi Sa', 2)]
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  916.jpg
#  Delamere Dairy Sterilized Skimmed Cow's
# Milk 1It
#
# JT (reid oS) penal & 9 Fhe 5 cle get Spel
#
# assall €.9 jhe plime iy Gul :cLi Sal
#
#
#
#
#
# Saal eG)
#
# K /
# Proccessing 926.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  926.jpg
#
# Proccessing 9141.jpg
# [('[Calories', '160 Calories irom fat 100', 0), ('‘TmuratedFattog _____—', '8', 1), ('\\ = Sodtum', '= Sodtum', 2), ('INTELLIGENCE Dlotray Fiber less than tg', '2%', 3), ('0796782259', '-0796901798 ain', 4), ('No Afi Colrs', '1008 Fee', 5)]
#
#
#
# [('[Calories', '160 Calories irom fat 100', 0), ('‘TmuratedFattog _____—', '8', 1), ('\\ = Sodtum', '= Sodtum', 2), ('INTELLIGENCE Dlotray Fiber less than tg', '2%', 3)]
#
#
#
# [('[Calories', '160 Calories irom fat 100', 0), ('‘TmuratedFattog _____—', '8', 1), ('\\ = Sodtum', '= Sodtum', 2), ('INTELLIGENCE Dlotray Fiber less than tg', '2%', 3)]
#
#
#
# [('Calories', '160 Calories irom fat 100', 1)]
#
#
#
# [('Calories', '160 Calories irom fat 100', 1)]
#
#
#
#
#  Completed Labels for:
#  9141.jpg
#  nt per serving
# [Calories 160 Calories irom fat 100%
# ~~ ___‘epally value"
# To
# ‘TmuratedFattog _____— 8%
# Trans Fat
# Cholesterol Omg
#
# \ = Sodtum 2
# ERA ) Total Carbohyd
# INTELLIGENCE Dlotray Fiber less than tg 2%,
# eg OUNDATION ‘ i |
# AI poe duds y ;
# ull algal gugi jbl F YJ Protein io
# shan - gles
#
# 0796782259 -0796901798 ain
#
# igh ality ingecgnts ap Le liye
#
# eer erry eee
# No Afi Colrs 1008 Fee)
#
# pS abit gto Wyabe
# Keep Your Country Ty
# Proccessing 946.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  946.jpg
#
# Proccessing 9102.jpg
# [('w\\s\\er: clay ga', 'clay ga', 0)]
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  9102.jpg
#  AI] sigll jg> cle : GbgKoll
#
# Us Vt: Glall Ujgil
# bt :Lédall ab
# w\s\er: clay gay6
# m\r\re s algal day
#
# produced by thai coconut pcl
# Proccessing 9165.jpg
# [('(agai gb jar', '0+ » )ppcigen Cit gla ~ 7 Tee', 0), ('acid', '2% and Sodium Benz(S00po', 1), ('Nel Weight:', '900g appron', 2), ('Drained Weight:', '454 g/approm', 3)]
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  9165.jpg
#  ok pes ls le piled ake yg) GL
# (agai gb jar 0+ » )ppcigen Cit gla ~ 7 Teel
# Ingredients: iin oe
# acid 2% and Sodium Benz(S00pom
# ( bal) pe Ae aaa
# Nel Weight: 900g appron)
# Ch pale DS dell Oy yl
# Drained Weight: 454 g/approm]
# Store it cool place, Syl Sa ob lang
# te es | Ly ple
# PRE ak lanes AY ell coh he lia le ype
# RN py eT Hig ce lt J pe
# Bis recomenended lo bed the naa
# belone shufing for toraiecress & Exeet Color
#
# cy at oe ppt VA Leta
# VolA had pe! CLOT! A
# Proccessing 954.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  954.jpg
#
# Proccessing 941.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  941.jpg
#
# Proccessing 940.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  940.jpg
#
# Proccessing 955.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  955.jpg
#
# Proccessing 9164.jpg
# [('Serving Per Container', '5', 0), ('Calories', '', 1), ('Total Fat Og', '0 Y', 2), ('Sodium', '100 mg 4', 3), ('Less than', '1g 0 “Y', 4), ('Based on a', '2.000 calorie diet.', 5)]
#
#
#
# [('Serving Per Container', '5', 0), ('Calories', '', 1), ('Total Fat Og', '0 Y', 2), ('Sodium', '100 mg 4', 3)]
#
#
#
# [('Sugars', '5', 0), ('Calories', '', 1), ('Total Fat Og', '0 Y', 2), ('Sodium', '100 mg 4', 3)]
#
#
#
# [('Calories', '', 2), ('Total Fat', '0 Y', 3), ('Sodium', '100 mg 4', 4), ('Sugars', '5', 1)]
#
#
#
# [('Calories', '', 2), ('Total Fat', '0 Y', 3), ('Sodium', '100 mg 4', 4), ('Sugars', '5', 1)]
#
#
#
#
#  Completed Labels for:
#  9164.jpg
#  Nutrition Facts
# Serving Size leaf(&g)
# Serving Per Container 56
#
# Amount Per Serving
# Calories 5
#
# ‘oe Daily Value
#
# Total Fat Og 0 Yo
#
# Sodium 100 mg 4%
#
# Total Carbohydrate
#
# Less than 1g 0 “Yo
#
# ProteinOg = =—i‘=ts
# Based on a 2.000 calorie diet. —
# Proccessing 9166.jpg
# [('Serving Size leaf', '8g', 0), ('Serving Per Container', '5', 1), ('Calones', '', 2), ('Total Fat Og', '0 “Y', 3), ('Sodium', '100 mg 4', 4), ('Lessthanig |', '0', 5)]
#
#
#
# [('Serving Size leaf', '8g', 0), ('Serving Per Container', '5', 1), ('Calones', '', 2), ('Total Fat Og', '0 “Y', 3), ('Sodium', '100 mg 4', 4)]
#
#
#
# [('Sugars', '8g', 0), ('Serving Per Container', '5', 1), ('Calones', '', 2), ('Total Fat Og', '0 “Y', 3), ('Sodium', '100 mg 4', 4)]
#
#
#
# [('Calories', '', 3), ('Total Fat', '0 “Y', 4), ('Sodium', '100 mg 4', 5), ('Sugars', '8g', 1)]
#
#
#
# [('Calories', '', 3), ('Total Fat', '0 “Y', 4), ('Sugars', '8g', 1)]
#
#
#
#
#  Completed Labels for:
#  9166.jpg
#  NUTrITION Facts
# Serving Size leaf(8g)
# Serving Per Container 56
#
# Amount Per Serving
# Calones 5
#
# %o Daily Value
# Total Fat Og 0 “Yo
# Sodium 100 mg 4%
# Total Carbohydrate
# Lessthanig | 0%
# ProteinOg = —t*™”
# Proccessing 99.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  99.jpg
#  get in touch:
# For recipes, information and
# where to buy, contact us.
#
# Delamere Dairy, Yew Tree Farm,
# Bexton Lane, Knutsford, Cheshire
#
# EWE dsd a
#
# Send us an email
# info@delameredairy.co.uk
# Speak to us on the phone...
#
# Wie ceereys
#
# Take a look at our lovely website...
#
#
#
# www.delameredairy.co.uk
# follow us On ¥ Ff
# Proccessing 942.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  942.jpg
#
# Proccessing 9158.jpg
# [('Serv Size', '1 oz (28g', 0), ('Calories', '7', 1), ('Total Fat', '6', 2), ('Sat Fat', '3.5', 3), ('Trans Fat', '0', 4), ('Cholest', '20m', 5), ('Sodium', '340m', 6), ('Fiber', '0', 7), ('Sugars', '0', 8), ('Protein', '5', 9), ('Vitamin A', '4% *', 10), ('Calcium', '6%', 11)]
#
#
#
# [('Serv Size', '1 oz (28g', 0), ('Calories', '7', 1), ('Total Fat', '6', 2), ('Sat Fat', '3.5', 3), ('Trans Fat', '0', 4), ('Cholest', '20m', 5), ('Sodium', '340m', 6), ('Sugars', '0', 8), ('Protein', '5', 9), ('Calcium', '6%', 11)]
#
#
#
# [('Serv Size', '1 oz (28g', 0), ('Calories', '7', 1), ('Total Fat', '6', 2), ('Sat Fat', '3.5', 3), ('Trans Fat', '0', 4), ('Cholest', '20m', 5), ('Sodium', '340m', 6), ('Sugars', '0', 8), ('Protein', '5', 9), ('Calcium', '6%', 11)]
#
#
#
# [('Serving Size', '1 oz (28g', 1), ('Calories', '7', 2), ('Total Fat', '6', 3), ('Saturated Fat', '3.5', 4), ('Trans Fat', '0', 5), ('Cholesterol', '20m', 6), ('Sodium', '340m', 7), ('Sugars', '0', 8), ('Protein', '5', 9)]
#
#
#
# [('Serving Size', '1 oz (28g', 1), ('Calories', '7', 2), ('Total Fat', '6', 3), ('Saturated Fat', '3.5', 4), ('Trans Fat', '0', 5), ('Cholesterol', '20m', 6), ('Sodium', '340m', 7), ('Sugars', '0', 8), ('Protein', '5', 9)]
#
#
#
#
#  Completed Labels for:
#  9158.jpg
#  Serv Size 1 oz (28g /
# Servings about é
# Amount/ Serving
# Calories 70
# Total Fat 69
# Sat Fat 3.59
# Trans Fat 0g
# Cholest 20mg
# Sodium 340mg
# Total Carb <ig
# Fiber 0g
# Sugars 0g
# Protein 59
# Vitamin A 4% * \
# Calcium 6% *
# Percent Daily Valees are base
# Proccessing 9159.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  9159.jpg
#  PASTEURIZED PA
# MILK, CHEESE
#
# SALT, ENZYMES
# Proccessing 943.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  943.jpg
#
# Proccessing 956.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  956.jpg
#
# Proccessing 9167.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  9167.jpg
#
# Proccessing 98.jpg
# [('eM ei ol Me Ee e-em al |', 'ei ol Me Ee e-em al |', 0), ('and use within', '3 days', 1), ('per', '100ml |per 250m', 2), ('<0.1g —', '—', 3), ('8400kJ/2000kcal =', '70g', 4), ('20g,', '90g, 6g', 5), ('120mg', '(15%) per 100mI/300mg pe', 6), ('portion ', '250ml). 300mg is 37.5% of an adult', 7), ('5 MI', '003945', 8)]
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  98.jpg
#  Delamere Dairy
#
# skimmed, sterilised, homogenised milk
#
# Our milk is carefully heat
# treated to give you a long-life
# cows’ milk that's extra delicious.
#
# eM ei ol Me Ee e-em al | 4
# and keeps in the cupboard
# until you need it.
#
# Did you know Delamere milk has
# Q brillfant flavour and T's fat
# free! It's ideal for cooking and
# baking. Plus it's also great in your
# tea or coffee. Visit our website
# for delicious recipe ideas.
#
# Storage:
#
# Store in a cool dry place.
# Once opened keep refrigerated
# and use within 3 days.
# Best before see bottle neck.
#
#
#
# For recipes, information and
# where to buy, contact us.
#
# Send us an email
# Nutritional information:
# AYA ed
# typical valves
# kJ/kcal
#
# Speak to us on the phone...
#
# UT Yale
# per 100ml |per 250ml
#
# <0.1g —
#
# Caen elon
# Erle clei
# Palais felt
#
# 0.1g
#
# Reference Intake (RI) (adult)
# 8400kJ/2000kcal = 70g,
# 20g, 90g, 6g
# 120mg (15%) per 100mI/300mg per
# portion (250ml). 300mg is 37.5% of an adults
# Nutrient Reference Intake (NRI)
#
# Take a look at our lovely website...
#
# follow us On # Ff
#
# 5 MI 003945
# Proccessing 917.jpg
# [("Wo>'sdooss¥aHV> SEHOLIND SU OL ", '1D.9GONS ATW ALTO', 0), ('BWILONINVG JY DOF ‘LAAN ONIGMOW! OL GALIWNOD', '51SUDN', 1)]
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  917.jpg
#  facia ce canes ee eer nee eat Q
#
#
#
# Peder ain om nena teren came =
#
# reece en mam ee pee ore rey et as
# Weinert Tia Hina o nd sharon conneror =a erLnTeamanem wenn!
# Aree ge ery come oar EY PET TIN mee aj MC oe |
# Fa ofS wees temo eisre ere
#
# Wo>'sdooss¥aHV> SEHOLIND SU OL S1D.9GONS ATW ALTON
# BWILONINVG JY DOF ‘LAAN ONIGMOW! OL GALIWNOD 51SUDNO
#
#
#
#
#
# CAKERS
#
#
#
#
#
# — STRAWBERRY —
# Strawberry sponge cake with rich strawberry filling
#
# Shearer ee rinse aon
#
# oleoetnnrnr
# Proccessing 952.jpg
# [('Serving Size ', '2', 0), ('Serving Per Container:', '24pc', 1), ('‘item  ——s Pe', '100g.22=SCNRV', 2), ('“Energy ', '365KJ 18', 3), ('Protein Og', '0', 4), ('Fat Og', '0', 5), ('Carbohydrate', '92.29 31', 6), ('Sodium', '24mg 0', 7)]
#
#
#
# [('Serving Size ', '2', 0), ('Serving Per Container:', '24pc', 1), ('“Energy ', '365KJ 18', 3), ('Protein Og', '0', 4), ('Carbohydrate', '92.29 31', 6), ('Sodium', '24mg 0', 7)]
#
#
#
# [('Sugars', '2', 0), ('Serving Per Container:', '24pc', 1), ('“Energy ', '365KJ 18', 3), ('Protein Og', '0', 4), ('Carbohydrate', '92.29 31', 6), ('Sodium', '24mg 0', 7)]
#
#
#
# [('Energy', '365KJ 18', 3), ('Sodium', '24mg 0', 6), ('Total Carbohydrate', '92.29 31', 5), ('Sugars', '2', 1), ('Protein', '0', 4)]
#
#
#
# [('Energy', '365KJ 18', 3), ('Total Carbohydrate', '92.29 31', 5), ('Sugars', '2', 1), ('Protein', '0', 4)]
#
#
#
#
#  Completed Labels for:
#  952.jpg
#  Nutrition Facts
# Serving Size :2g
# Serving Per Container: 24pcs
#
# ‘item  ——s Per100g.22=SCNRV%
# “Energy  365KJ 18%
# Protein Og 0%
# Fat Og 0%
# Carbohydrate 92.29 31%
#
# Sodium 24mg 0%
# Proccessing 9138.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  9138.jpg
#
# Proccessing 968.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  968.jpg
#
# Proccessing 9161.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  9161.jpg
#  f
# Cr Ese-S EF.
# EE NUTRITION INFORMAT
#
# FOR SATURATED FAT AN
# SODIUM CONTENT
# Proccessing 9160.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  9160.jpg
#
# Proccessing 969.jpg
# [('Serving Size', '15', 0), ('Serving Per Container', '4', 1), ('Omg(0%DV)', '', 2), ('Daily Values(DV) are based on a', '2,000 calorie die', 3)]
#
#
#
# [('Serving Size', '15', 0), ('Serving Per Container', '4', 1)]
#
#
#
# [('Serving Size', '15', 0), ('Serving Per Container', '4', 1)]
#
#
#
# [('Serving Size', '15', 1)]
#
#
#
# [('Serving Size', '15', 1)]
#
#
#
#
#  Completed Labels for:
#  969.jpg
#  NUTRITION FACTS
# Serving Size:15g
# Serving Per Container:48
#
# Amount Per Serving
#
# Omg(0%DV)
#
# Not a significant source of calories from
# fat,saturated fat,trans fat,cholesterol,dietary
# fiber,vitamin A vitamin C calcium and iron.Percent
# Daily Values(DV) are based on a 2,000 calorie diet
# Proccessing 9139.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  9139.jpg
#
# Proccessing 953.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  953.jpg
#
# Proccessing 951.jpg
# [('Serving Size ', '2', 0), ('serving Per Container:', '24pc', 1), ('tem Per', '100', 2), ('Energy ', '65K', 3), ('Carbohydrate', '92.2', 4), ('Sodium', '24m', 5)]
#
#
#
# [('Serving Size ', '2', 0), ('serving Per Container:', '24pc', 1), ('Energy ', '65K', 3), ('Carbohydrate', '92.2', 4), ('Sodium', '24m', 5)]
#
#
#
# [('Sugars', '2', 0), ('serving Per Container:', '24pc', 1), ('Energy ', '65K', 3), ('Carbohydrate', '92.2', 4), ('Sodium', '24m', 5)]
#
#
#
# [('Energy', '65K', 3), ('Sodium', '24m', 5), ('Total Carbohydrate', '92.2', 4), ('Sugars', '2', 1)]
#
#
#
# [('Energy', '65K', 3), ('Total Carbohydrate', '92.2', 4), ('Sugars', '2', 1)]
#
#
#
#
#  Completed Labels for:
#  951.jpg
#  Nutrition Facts
# Serving Size :2g
#
# serving Per Container: 24pcs
# tem Per 100g
#
# Energy S65KJ
#
# Protein Og
# Fat Og
# Carbohydrate 92.29
# Sodium 24mg
# Proccessing 9128.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  9128.jpg
#
# Proccessing 9162.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  9162.jpg
#  ail, =a, i a
# Tac
# Proccessing 9163.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  9163.jpg
#
# Proccessing 9129.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  9129.jpg
#
# Proccessing 950.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  950.jpg
#
# Proccessing 998.jpg
# [('7 aN] in Ses on', 'aN] in Ses on', 0), ('7 Slic ces Per Pack —', 'Slic ces Per Pack —', 1)]
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
#
#  Completed Labels for:
#  998.jpg
#  7 aN] in Ses on
#
#
#
# ce ieee sks
# meal!
# 7 Slic ces Per Pack —

# %%
len(n)
# Out:
# 167

# %% [markdown]
# ### DataFrame Creation from Raw Text

# %%
dx = pd.DataFrame(n)

# %%
dx.product_id.unique()
# Out:
# array(['img_result/74_Nutritions_1.918.jpg',
#        'img_result/11_Nutritions_1.995.jpg',
#        'img_result/7_Nutritions_1.949.jpg',
#        'img_result/76_Nutritions_1.91.jpg',
#        'img_result/82_Nutritions_1.9137.jpg',
#        'img_result/4_Nutritions_1.987.jpg',
#        'img_result/12_Nutritions_1.967.jpg',
#        'img_result/78_Nutritions_1.9152.jpg',
#        'img_result/78_Nutritions_1.9153.jpg',
#        'img_result/12_Nutritions_1.966.jpg',
#        'img_result/4_Nutritions_1.986.jpg',
#        'img_result/9_Nutritions_1.9126.jpg',
#        'img_result/7_Nutritions_1.948.jpg',
#        'img_result/11_Nutritions_1.994.jpg',
#        'img_result/74_Nutritions_1.919.jpg',
#        'img_result/11_Nutritions_1.996.jpg',
#        'img_result/80_Nutritions_1.9127.jpg',
#        'img_result/76_Nutritions_1.92.jpg',
#        'img_result/9_Nutritions_1.9124.jpg',
#        'img_result/4_Nutritions_1.984.jpg',
#        'img_result/12_Nutritions_1.970.jpg',
#        'img_result/12_Nutritions_1.971.jpg',
#        'img_result/4_Nutritions_1.985.jpg',
#        'img_result/9_Nutritions_1.9119.jpg',
#        'img_result/9_Nutritions_1.9125.jpg',
#        'img_result/76_Nutritions_1.93.jpg',
#        'img_result/11_Nutritions_1.997.jpg',
#        'img_result/74_Nutritions_1.922.jpg',
#        'img_result/11_Nutritions_1.993.jpg',
#        'img_result/9_Nutritions_1.9121.jpg',
#        'img_result/4_Nutritions_1.981.jpg',
#        'img_result/78_Nutritions_1.9154.jpg',
#        'img_result/78_Nutritions_1.9155.jpg',
#        'img_result/4_Nutritions_1.980.jpg',
#        'img_result/9_Nutritions_1.9120.jpg',
#        'img_result/76_Nutritions_1.96.jpg',
#        'img_result/11_Nutritions_1.992.jpg',
#        'img_result/74_Nutritions_1.921.jpg',
#        'img_result/76_Nutritions_1.94.jpg',
#        'img_result/9_Nutritions_1.9122.jpg',
#        'img_result/4_Nutritions_1.982.jpg',
#        'img_result/78_Nutritions_1.9157.jpg',
#        'img_result/78_Nutritions_1.9156.jpg',
#        'img_result/4_Nutritions_1.983.jpg',
#        'img_result/9_Nutritions_1.9123.jpg',
#        'img_result/76_Nutritions_1.95.jpg',
#        'img_result/75_Nutritions_1.97.jpg',
#        'img_result/74_Nutritions_1.920.jpg',
#        'img_result/1_Nutritions_1.932.jpg',
#        'img_result/8_Nutritions_1.9111.jpg',
#        'img_result/13_Nutritions_1.964.jpg',
#        'img_result/13_Nutritions_1.958.jpg',
#        'img_result/82_Nutritions_1.9140.jpg',
#        'img_result/6_Nutritions_1.976.jpg',
#        'img_result/6_Nutritions_1.977.jpg',
#        'img_result/13_Nutritions_1.959.jpg',
#        'img_result/13_Nutritions_1.965.jpg',
#        'img_result/1_Nutritions_1.933.jpg',
#        'img_result/1_Nutritions_1.931.jpg',
#        'img_result/8_Nutritions_1.9112.jpg',
#        'img_result/6_Nutritions_1.975.jpg',
#        'img_result/6_Nutritions_1.974.jpg',
#        'img_result/8_Nutritions_1.9113.jpg',
#        'img_result/1_Nutritions_1.930.jpg',
#        'img_result/5_Nutritions_1.9109.jpg',
#        'img_result/8_Nutritions_1.9117.jpg',
#        'img_result/1_Nutritions_1.934.jpg',
#        'img_result/13_Nutritions_1.962.jpg',
#        'img_result/2_Nutritions_1.939.jpg',
#        'img_result/10_Nutritions_1.990.jpg',
#        'img_result/10_Nutritions_1.991.jpg',
#        'img_result/2_Nutritions_1.938.jpg',
#        'img_result/13_Nutritions_1.963.jpg',
#        'img_result/1_Nutritions_1.935.jpg',
#        'img_result/5_Nutritions_1.9108.jpg',
#        'img_result/8_Nutritions_1.9116.jpg',
#        'img_result/8_Nutritions_1.9114.jpg',
#        'img_result/1_Nutritions_1.937.jpg',
#        'img_result/13_Nutritions_1.961.jpg',
#        'img_result/79_Nutritions_1.9149.jpg',
#        'img_result/6_Nutritions_1.973.jpg',
#        'img_result/6_Nutritions_1.972.jpg',
#        'img_result/79_Nutritions_1.9148.jpg',
#        'img_result/13_Nutritions_1.960.jpg',
#        'img_result/1_Nutritions_1.936.jpg',
#        'img_result/8_Nutritions_1.9115.jpg',
#        'img_result/8_Nutritions_1.9118.jpg',
#        'img_result/5_Nutritions_1.9106.jpg',
#        'img_result/5_Nutritions_1.999.jpg',
#        'img_result/79_Nutritions_1.9145.jpg',
#        'img_result/79_Nutritions_1.9151.jpg',
#        'img_result/81_Nutritions_1.9133.jpg',
#        'img_result/75_Nutritions_1.912.jpg',
#        'img_result/75_Nutritions_1.913.jpg',
#        'img_result/81_Nutritions_1.9132.jpg',
#        'img_result/73_Nutritions_1.923.jpg',
#        'img_result/79_Nutritions_1.9150.jpg',
#        'img_result/79_Nutritions_1.9144.jpg',
#        'img_result/83_Nutritions_1.9135.jpg',
#        'img_result/5_Nutritions_1.9107.jpg',
#        'img_result/5_Nutritions_1.9105.jpg',
#        'img_result/79_Nutritions_1.9146.jpg',
#        'img_result/81_Nutritions_1.9130.jpg',
#        'img_result/10_Nutritions_1.988.jpg',
#        'img_result/75_Nutritions_1.911.jpg',
#        'img_result/10_Nutritions_1.989.jpg',
#        'img_result/75_Nutritions_1.910.jpg',
#        'img_result/81_Nutritions_1.9131.jpg',
#        'img_result/79_Nutritions_1.9147.jpg',
#        'img_result/83_Nutritions_1.9136.jpg',
#        'img_result/5_Nutritions_1.9110.jpg',
#        'img_result/5_Nutritions_1.9104.jpg',
#        'img_result/1_Nutritions_1.929.jpg',
#        'img_result/5_Nutritions_1.9100.jpg',
#        'img_result/13_Nutritions_1.957.jpg',
#        'img_result/3_Nutritions_1.944.jpg',
#        'img_result/79_Nutritions_1.9143.jpg',
#        'img_result/73_Nutritions_1.924.jpg',
#        'img_result/6_Nutritions_1.979.jpg',
#        'img_result/75_Nutritions_1.914.jpg',
#        'img_result/81_Nutritions_1.9134.jpg',
#        'img_result/75_Nutritions_1.915.jpg',
#        'img_result/6_Nutritions_1.978.jpg',
#        'img_result/73_Nutritions_1.925.jpg',
#        'img_result/79_Nutritions_1.9142.jpg',
#        'img_result/3_Nutritions_1.945.jpg',
#        'img_result/5_Nutritions_1.9101.jpg',
#        'img_result/1_Nutritions_1.928.jpg',
#        'img_result/5_Nutritions_1.9103.jpg',
#        'img_result/3_Nutritions_1.947.jpg',
#        'img_result/73_Nutritions_1.927.jpg',
#        'img_result/75_Nutritions_1.916.jpg',
#        'img_result/73_Nutritions_1.926.jpg',
#        'img_result/79_Nutritions_1.9141.jpg',
#        'img_result/3_Nutritions_1.946.jpg',
#        'img_result/5_Nutritions_1.9102.jpg',
#        'img_result/84_Nutritions_1.9165.jpg',
#        'img_result/7_Nutritions_1.954.jpg',
#        'img_result/2_Nutritions_1.941.jpg',
#        'img_result/2_Nutritions_1.940.jpg',
#        'img_result/7_Nutritions_1.955.jpg',
#        'img_result/84_Nutritions_1.9164.jpg',
#        'img_result/84_Nutritions_1.9166.jpg',
#        'img_result/75_Nutritions_1.99.jpg',
#        'img_result/2_Nutritions_1.942.jpg',
#        'img_result/78_Nutritions_1.9158.jpg',
#        'img_result/78_Nutritions_1.9159.jpg',
#        'img_result/2_Nutritions_1.943.jpg',
#        'img_result/7_Nutritions_1.956.jpg',
#        'img_result/84_Nutritions_1.9167.jpg',
#        'img_result/75_Nutritions_1.98.jpg',
#        'img_result/74_Nutritions_1.917.jpg',
#        'img_result/7_Nutritions_1.952.jpg',
#        'img_result/82_Nutritions_1.9138.jpg',
#        'img_result/12_Nutritions_1.968.jpg',
#        'img_result/78_Nutritions_1.9161.jpg',
#        'img_result/78_Nutritions_1.9160.jpg',
#        'img_result/12_Nutritions_1.969.jpg',
#        'img_result/82_Nutritions_1.9139.jpg',
#        'img_result/7_Nutritions_1.953.jpg',
#        'img_result/7_Nutritions_1.951.jpg',
#        'img_result/80_Nutritions_1.9128.jpg',
#        'img_result/78_Nutritions_1.9162.jpg',
#        'img_result/78_Nutritions_1.9163.jpg',
#        'img_result/80_Nutritions_1.9129.jpg',
#        'img_result/7_Nutritions_1.950.jpg',
#        'img_result/11_Nutritions_1.998.jpg'], dtype=object)

# %%
dx.product_id = dx.product_id.apply(lambda x:x.replace('img_result/',''))

# %%
dx.head()
# Out:
#   Calories Cholesterol Dietary Fiber Energy Potassium Protein Saturated Fat  \
# 0      NaN         NaN           NaN    NaN       NaN     NaN           NaN
# 1      NaN         NaN           NaN    NaN       NaN     NaN           NaN
# 2      NaN         NaN           NaN    NaN       NaN     NaN           NaN
# 3      NaN         NaN           NaN    NaN       NaN     NaN           NaN
# 4       30         NaN           NaN    NaN       NaN     NaN           NaN
#
#   Serving Size Sodium Sugars Total Carbohydrate Total Fat Trans Fat  \
# 0          NaN    NaN    NaN                NaN       NaN       NaN
# 1          NaN    NaN    NaN                NaN       NaN       NaN
# 2          NaN    NaN    NaN                NaN       NaN       NaN
# 3          NaN    NaN    NaN                NaN       NaN       NaN
# 4           35    NaN    NaN                NaN       NaN       NaN
#
#                  product_id
# 0   74_Nutritions_1.918.jpg
# 1   11_Nutritions_1.995.jpg
# 2    7_Nutritions_1.949.jpg
# 3    76_Nutritions_1.91.jpg
# 4  82_Nutritions_1.9137.jpg

# %%
dx.set_index(keys='product_id').dropna(how='all')
# Out:
#                          Calories Cholesterol Dietary Fiber Energy Potassium  \
# product_id
# 82_Nutritions_1.9137.jpg       30         NaN           NaN    NaN       NaN
# 9_Nutritions_1.9126.jpg       NaN           0           NaN    NaN       NaN
# 11_Nutritions_1.994.jpg       NaN         NaN           NaN    NaN       NaN
# 9_Nutritions_1.9125.jpg         3           0           NaN    NaN         0
# 76_Nutritions_1.93.jpg         67         NaN           NaN    NaN       NaN
# 74_Nutritions_1.922.jpg       NaN          10             0    NaN       NaN
# 78_Nutritions_1.9155.jpg       70          20           NaN    NaN       NaN
# 76_Nutritions_1.96.jpg         67           0           NaN    NaN       NaN
# 74_Nutritions_1.921.jpg       170          10           NaN    NaN       NaN
# 76_Nutritions_1.94.jpg         67         NaN           NaN    NaN       NaN
# 13_Nutritions_1.965.jpg         0         NaN           NaN    NaN       NaN
# 1_Nutritions_1.933.jpg        NaN         NaN           NaN    NaN       NaN
# 1_Nutritions_1.931.jpg        NaN         NaN           NaN    NaN       NaN
# 1_Nutritions_1.934.jpg        NaN         NaN           NaN    NaN       NaN
# 10_Nutritions_1.990.jpg                   NaN           NaN    NaN       NaN
# 2_Nutritions_1.938.jpg        NaN         NaN           NaN    NaN       NaN
# 8_Nutritions_1.9116.jpg       NaN         NaN           NaN    NaN       NaN
# 8_Nutritions_1.9114.jpg        15         NaN           NaN    NaN       NaN
# 79_Nutritions_1.9148.jpg      NaN           0           NaN    NaN       NaN
# 8_Nutritions_1.9115.jpg      2000         NaN           NaN    NaN       NaN
# 73_Nutritions_1.923.jpg       NaN         NaN           NaN    NaN       NaN
# 79_Nutritions_1.9147.jpg      160           0           NaN    NaN       NaN
# 83_Nutritions_1.9136.jpg      NaN         NaN           NaN    NaN       NaN
# 3_Nutritions_1.944.jpg         30         NaN           NaN    NaN       NaN
# 73_Nutritions_1.924.jpg       100           2           NaN    NaN       NaN
# 73_Nutritions_1.925.jpg       100           2           NaN    NaN       NaN
# 5_Nutritions_1.9101.jpg       NaN         NaN           NaN     71       NaN
# 1_Nutritions_1.928.jpg        NaN         NaN           NaN    NaN       NaN
# 79_Nutritions_1.9141.jpg      160         NaN           NaN    NaN       NaN
# 84_Nutritions_1.9164.jpg                  NaN           NaN    NaN       NaN
# 84_Nutritions_1.9166.jpg                  NaN           NaN    NaN       NaN
# 78_Nutritions_1.9158.jpg        7          20           NaN    NaN       NaN
# 7_Nutritions_1.952.jpg        NaN         NaN           NaN    365       NaN
# 12_Nutritions_1.969.jpg       NaN         NaN           NaN    NaN       NaN
# 7_Nutritions_1.951.jpg        NaN         NaN           NaN     65       NaN
#
#                          Protein Saturated Fat Serving Size Sodium  Sugars  \
# product_id
# 82_Nutritions_1.9137.jpg     NaN           NaN           35    NaN     NaN
# 9_Nutritions_1.9126.jpg        0           NaN          NaN      0     NaN
# 11_Nutritions_1.994.jpg      NaN           NaN          NaN    NaN    12.3
# 9_Nutritions_1.9125.jpg        0             0            1      0     NaN
# 76_Nutritions_1.93.jpg       NaN           NaN            5     48     NaN
# 74_Nutritions_1.922.jpg      1.2          0.24          NaN    190  117.51
# 78_Nutritions_1.9155.jpg     NaN           3.5                 340       0
# 76_Nutritions_1.96.jpg       NaN             0          NaN    480     NaN
# 74_Nutritions_1.921.jpg      1.2            0.            1    190   11.51
# 76_Nutritions_1.94.jpg       NaN           NaN            5     48     NaN
# 13_Nutritions_1.965.jpg      NaN           NaN           40    NaN       2
# 1_Nutritions_1.933.jpg       NaN           NaN            8    NaN     NaN
# 1_Nutritions_1.931.jpg       NaN           NaN            8    NaN     NaN
# 1_Nutritions_1.934.jpg       NaN           NaN            8    NaN     NaN
# 10_Nutritions_1.990.jpg      NaN           NaN           14    NaN     NaN
# 2_Nutritions_1.938.jpg       NaN           NaN          21.    NaN     NaN
# 8_Nutritions_1.9116.jpg        2           NaN          NaN      7      16
# 8_Nutritions_1.9114.jpg      NaN             1           28    210     NaN
# 79_Nutritions_1.9148.jpg     NaN           NaN          NaN    250     NaN
# 8_Nutritions_1.9115.jpg      NaN           NaN           28    NaN     NaN
# 73_Nutritions_1.923.jpg      NaN           NaN            2    NaN     NaN
# 79_Nutritions_1.9147.jpg     NaN             5            1    250     NaN
# 83_Nutritions_1.9136.jpg     NaN           NaN          NaN    290     NaN
# 3_Nutritions_1.944.jpg       NaN           NaN           35    NaN     NaN
# 73_Nutritions_1.924.jpg      NaN                         22    NaN     NaN
# 73_Nutritions_1.925.jpg      NaN                         22    NaN     NaN
# 5_Nutritions_1.9101.jpg      NaN           NaN          NaN    NaN     NaN
# 1_Nutritions_1.928.jpg       NaN           NaN            8    NaN     NaN
# 79_Nutritions_1.9141.jpg     NaN           NaN          NaN    NaN     NaN
# 84_Nutritions_1.9164.jpg     NaN           NaN          NaN    100       5
# 84_Nutritions_1.9166.jpg     NaN           NaN          NaN    NaN       8
# 78_Nutritions_1.9158.jpg       5           3.5            1    340       0
# 7_Nutritions_1.952.jpg         0           NaN          NaN    NaN       2
# 12_Nutritions_1.969.jpg      NaN           NaN           15    NaN     NaN
# 7_Nutritions_1.951.jpg       NaN           NaN          NaN    NaN       2
#
#                          Total Carbohydrate Total Fat Trans Fat
# product_id
# 82_Nutritions_1.9137.jpg                NaN       NaN       NaN
# 9_Nutritions_1.9126.jpg                   7       NaN       NaN
# 11_Nutritions_1.994.jpg                 2.2       NaN       NaN
# 9_Nutritions_1.9125.jpg                 NaN         0       NaN
# 76_Nutritions_1.93.jpg                   11       NaN       NaN
# 74_Nutritions_1.922.jpg               25.12      1.63         0
# 78_Nutritions_1.9155.jpg                  1         6         0
# 76_Nutritions_1.96.jpg                  3.6         1       NaN
# 74_Nutritions_1.921.jpg               25.12      1.63         0
# 76_Nutritions_1.94.jpg                   11       NaN       NaN
# 13_Nutritions_1.965.jpg                 NaN       NaN       NaN
# 1_Nutritions_1.933.jpg                  NaN       NaN       NaN
# 1_Nutritions_1.931.jpg                  NaN       NaN       NaN
# 1_Nutritions_1.934.jpg                  NaN       NaN       NaN
# 10_Nutritions_1.990.jpg                 NaN         0       NaN
# 2_Nutritions_1.938.jpg                  NaN       NaN       NaN
# 8_Nutritions_1.9116.jpg                 NaN       NaN       NaN
# 8_Nutritions_1.9114.jpg                 NaN       NaN       NaN
# 79_Nutritions_1.9148.jpg                  3       NaN       NaN
# 8_Nutritions_1.9115.jpg                  4.       NaN       NaN
# 73_Nutritions_1.923.jpg                 NaN       NaN       NaN
# 79_Nutritions_1.9147.jpg                 13       NaN       NaN
# 83_Nutritions_1.9136.jpg                  1       NaN       NaN
# 3_Nutritions_1.944.jpg                  NaN       NaN       NaN
# 73_Nutritions_1.924.jpg                 NaN
# 73_Nutritions_1.925.jpg                 NaN
# 5_Nutritions_1.9101.jpg                  43       NaN       NaN
# 1_Nutritions_1.928.jpg                  NaN       NaN       NaN
# 79_Nutritions_1.9141.jpg                NaN       NaN       NaN
# 84_Nutritions_1.9164.jpg                NaN         0       NaN
# 84_Nutritions_1.9166.jpg                NaN         0       NaN
# 78_Nutritions_1.9158.jpg                NaN         6         0
# 7_Nutritions_1.952.jpg                 92.2       NaN       NaN
# 12_Nutritions_1.969.jpg                 NaN       NaN       NaN
# 7_Nutritions_1.951.jpg                 92.2       NaN       NaN

# %%
dx.product_id.unique()
# Out:
# array(['1_Nutritions_29.jpg', '9_Nutritions_127.jpg',
#        '73_Nutritions_21.jpg', '6_Nutritions_75.jpg',
#        '5_Nutritions_101.jpg', '8_Nutritions_115.jpg',
#        '81_Nutritions_135.jpg', '12_Nutritions_69.jpg',
#        '12_Nutritions_68.jpg', '81_Nutritions_134.jpg',
#        '8_Nutritions_114.jpg', '5_Nutritions_100.jpg',
#        '6_Nutritions_74.jpg', '73_Nutritions_20.jpg',
#        '9_Nutritions_126.jpg', '1_Nutritions_28.jpg',
#        '9_Nutritions_124.jpg', '73_Nutritions_22.jpg',
#        '6_Nutritions_76.jpg', '5_Nutritions_102.jpg',
#        '8_Nutritions_116.jpg', '81_Nutritions_136.jpg',
#        '8_Nutritions_117.jpg', '5_Nutritions_103.jpg',
#        '6_Nutritions_77.jpg', '73_Nutritions_23.jpg',
#        '3_Nutritions_48.jpg', '9_Nutritions_125.jpg',
#        '9_Nutritions_121.jpg', '80_Nutritions_129.jpg',
#        '73_Nutritions_27.jpg', '6_Nutritions_73.jpg',
#        '7_Nutritions_49.jpg', '5_Nutritions_107.jpg',
#        '8_Nutritions_113.jpg', '81_Nutritions_133.jpg',
#        '81_Nutritions_132.jpg', '5_Nutritions_112.jpg',
#        '5_Nutritions_106.jpg', '6_Nutritions_72.jpg',
#        '73_Nutritions_26.jpg', '80_Nutritions_128.jpg',
#        '9_Nutritions_122.jpg', '73_Nutritions_24.jpg',
#        '5_Nutritions_110.jpg', '5_Nutritions_104.jpg',
#        '13_Nutritions_57.jpg', '5_Nutritions_105.jpg',
#        '5_Nutritions_111.jpg', '73_Nutritions_25.jpg',
#        '9_Nutritions_123.jpg', '75_Nutritions_8.jpg',
#        '79_Nutritions_144.jpg', '79_Nutritions_150.jpg',
#        '76_Nutritions_2.jpg', '5_Nutritions_99.jpg',
#        '76_Nutritions_3.jpg', '79_Nutritions_145.jpg',
#        '75_Nutritions_9.jpg', '2_Nutritions_38.jpg',
#        '79_Nutritions_147.jpg', '76_Nutritions_1.jpg',
#        '11_Nutritions_93.jpg', '11_Nutritions_92.jpg',
#        '79_Nutritions_146.jpg', '2_Nutritions_39.jpg',
#        '74_Nutritions_18.jpg', '79_Nutritions_142.jpg',
#        '76_Nutritions_4.jpg', '82_Nutritions_140.jpg',
#        '78_Nutritions_158.jpg', '10_Nutritions_90.jpg',
#        '11_Nutritions_96.jpg', '10_Nutritions_91.jpg',
#        '78_Nutritions_159.jpg', '11_Nutritions_97.jpg',
#        '79_Nutritions_143.jpg', '74_Nutritions_19.jpg',
#        '79_Nutritions_141.jpg', '11_Nutritions_95.jpg',
#        '11_Nutritions_94.jpg', '74_Nutritions_17.jpg',
#        '75_Nutritions_11.jpg', '4_Nutritions_83.jpg',
#        '78_Nutritions_157.jpg', '11_Nutritions_98.jpg',
#        '78_Nutritions_156.jpg', '4_Nutritions_82.jpg',
#        '74_Nutritions_16.jpg', '75_Nutritions_10.jpg',
#        '75_Nutritions_12.jpg', '4_Nutritions_80.jpg',
#        '78_Nutritions_154.jpg', '10_Nutritions_88.jpg',
#        '10_Nutritions_89.jpg', '78_Nutritions_155.jpg',
#        '4_Nutritions_81.jpg', '75_Nutritions_13.jpg',
#        '75_Nutritions_7.jpg', '4_Nutritions_85.jpg',
#        '78_Nutritions_151.jpg', '4_Nutritions_84.jpg',
#        '75_Nutritions_6.jpg', '75_Nutritions_14.jpg',
#        '79_Nutritions_148.jpg', '4_Nutritions_86.jpg',
#        '78_Nutritions_152.jpg', '78_Nutritions_153.jpg',
#        '4_Nutritions_87.jpg', '79_Nutritions_149.jpg',
#        '75_Nutritions_15.jpg', '75_Nutritions_5.jpg',
#        '1_Nutritions_34.jpg', '2_Nutritions_45.jpg',
#        '82_Nutritions_138.jpg', '7_Nutritions_52.jpg',
#        '5_Nutritions_108.jpg', '8_Nutritions_120.jpg',
#        '84_Nutritions_162.jpg', '5_Nutritions_109.jpg',
#        '83_Nutritions_137.jpg', '7_Nutritions_53.jpg',
#        '82_Nutritions_139.jpg', '2_Nutritions_44.jpg',
#        '1_Nutritions_35.jpg', '1_Nutritions_37.jpg',
#        '80_Nutritions_131.jpg', '7_Nutritions_51.jpg',
#        '84_Nutritions_161.jpg', '13_Nutritions_65.jpg',
#        '13_Nutritions_59.jpg', '13_Nutritions_58.jpg',
#        '13_Nutritions_64.jpg', '84_Nutritions_160.jpg',
#        '7_Nutritions_50.jpg', '80_Nutritions_130.jpg',
#        '1_Nutritions_36.jpg', '1_Nutritions_32.jpg',
#        '2_Nutritions_43.jpg', '7_Nutritions_54.jpg',
#        '12_Nutritions_66.jpg', '13_Nutritions_60.jpg',
#        '12_Nutritions_67.jpg', '13_Nutritions_61.jpg',
#        '7_Nutritions_55.jpg', '2_Nutritions_42.jpg',
#        '1_Nutritions_33.jpg', '1_Nutritions_31.jpg',
#        '3_Nutritions_46.jpg', '2_Nutritions_40.jpg',
#        '6_Nutritions_79.jpg', '8_Nutritions_119.jpg',
#        '13_Nutritions_63.jpg', '12_Nutritions_71.jpg',
#        '12_Nutritions_70.jpg', '13_Nutritions_62.jpg',
#        '8_Nutritions_118.jpg', '6_Nutritions_78.jpg',
#        '7_Nutritions_56.jpg', '3_Nutritions_47.jpg',
#        '2_Nutritions_41.jpg', '1_Nutritions_30.jpg'], dtype=object)

# %%
dx.shape
# Out:
# (162, 14)

# %% [markdown]
# #### Creating A Dataframe from Raw Text (Try 1)

# %%
test = n[0].split('\n')

# %%
#df_test = pd.DataFrame(test)

# %%
#df_test[0][19]

# %%
df_test

# %%
df_test = df_test.rename(columns={0:'data'})

# %%
df_test[df_test['data'].str.contains('Serving')]

# %%
df_test['data'].str.extract('(\d+?[Aa-zZ]+)')

# %% [markdown]
# ## Reference_codes

# %% [markdown]
# ### All_Labels:

# %%
#sys.path.append('/usr/local/lib/python2.7/site-packages')


def writeFile(directory, fileName, content):
    outFile = open('outputs/' + directory + '/' + fileName + '.txt', 'w')
    outFile.write(content)
    outFile.close()

# Setup regex for stripping file names
p = re.compile('[0-9]+.jpg')
    
# Use images in the labels directory
for file in glob.glob('../labels/*.jpg'):
    fileName = p.findall(file)[0]
    print ("Proccessing " + fileName)
    outFileName = fileName[0:len(fileName)-4]
    # Get default text recognition 
    output = pytesseract.image_to_string(Image.open(file))
    #print(output)

    # Write default text output to 'outputs/default' directory
    writeFile('default', outFileName, output)

    # Open image as black and white
    bw = cv2.imread(file, 0)

    # Apply adaptive thresholding to images
    thresh = cv2.adaptiveThreshold(bw, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,\
            cv2.THRESH_BINARY, 11, 2)

    # Get text recognition from thresholded images
    output = pytesseract.image_to_string(Image.fromarray(bw))
    writeFile('bw', outFileName, output)

    break

# %%
def label_Recognizer(path):
    import re
#    import end_to_end
    import os
    from matplotlib import pyplot 
    files = []
    # r=root, d=directories, f = files
    for  r,d, f in os.walk(path):
        for file in f:
            files.append(os.path.join(file))
    p = re.compile('[0-9]+.jpg')
    all_result = []
    for f in files:
        print(f)
     #   out_dict = end_to_end.end_to_end(f'{path}\{f}')
        #-----------------
        for file in glob.glob('./img_result/*.jpg'):
            fileName = p.findall(file)[0]
            print ("Proccessing " + fileName)
            outFileName = fileName[0:len(fileName)-4]
            # Get default text recognition 
            output = pytesseract.image_to_string(Image.open(file))
            print("/n", output)
            all_result.append(output)

            # Write default text output to 'outputs/default' directory
#             writeFile('default', outFileName, output)

#             # Open image as black and white
#             bw = cv2.imread(file, 0)

#             # Apply adaptive thresholding to images
#             thresh = cv2.adaptiveThreshold(bw, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,\
#                     cv2.THRESH_BINARY, 11, 2)

#             # Get text recognition from thresholded images
#             output = pytesseract.image_to_string(Image.fromarray(bw))
                

#         #-----------------
# #         print('This is out_dict type', type(out_dict))
# #         print(f.replace(r'.jpg',''))
# #         out_dict['Image_id']=f.replace(r'.jpg','')
#             all_result.append(output)
            
#         break

    df = pd.DataFrame(all_result)
    df = pd.DataFrame(columns=['Image_id','Nutrient', 'Amount', 'Unit', 'Serving Size','Serving Size Unit','Language'])
    df_long = df.melt(id_vars=['Serving Size','Image_id'])
    Units = {'Calories': 'Kcal',
        'Energy': 'kJ',
        'Total Fat': 'g',
        'Saturated Fat': 'g',
        'Trans Fat': 'g',
        'Poly Fat': 'g',
        'Mono Fat': 'g',
        'Cholesterol': 'mg',
        'Sodium': 'mg',
        'Potassium': 'g',
        'Total Carbohydrate': 'g',
        'Dietary Fiber': 'g',
        'Sugars': 'g',
        'Protein': 'g'}
    df_long['Serving Size Unit']= 'g'
    df_long.columns = ['Serving Size','Image_id','Nutrient','Amount','Serving Size Unit']
    df_long['Unit'] = [Units [x] for x in df_long['Nutrient']]
    df_long['Language'] = 'English'
    Final_Outcome = df_long[['Image_id','Nutrient', 'Amount', 'Unit', 'Serving Size','Serving Size Unit','Language']]
    Final_Outcome.to_excel('DSI-V-Abdulrahman.xlsx', index=False)
    return Final_Outcome

# %%
basename = os.path.basename("./img_result")
label_impath = impath.replace(basename, 'tmp_' + basename)
# label_impath = impath.lower().replace('.jpg', 'label_tmp.jpg')
cv2.imwrite(label_impath, label_im)

start = timer()
# Apply Tesseract to image
output = apply_tesseract(label_impath, demo=demo)
#        print ("\n")
output = pytesseract.image_to_string(label_impath,lang='eng')
#     print(arabic)

end = timer()
print('OCR time: %2f' % (end-start))
os.remove(label_impath)

start = timer()
ocr_label = post_process(output, demo=demo)
print(ocr_label)

end = timer()
print('Post process time: %2f' % (end-start))

if show:
    draw_image(label_im, 'Transformed label: %s' % impath)

return ocr_label

# %% [markdown]
# ### image view

# %%
io.imshow('./test_result.png')

# %% [markdown]
# ### Text with Tesseract - codes:

# %%
import pytesseract
from PIL import Image, ImageEnhance, ImageFilter

im = Image.open("test_result.png") # the second one 
im = im.filter(ImageFilter.MedianFilter())
enhancer = ImageEnhance.Contrast(im)
im = enhancer.enhance(22)
im = im.convert('1')
im.save('test2.jpg')

text = pytesseract.image_to_string(Image.open('test2.jpg'))
print(text)

# %% [markdown]
# #### Method 2

# %%
# A seconde way to extract text - OCR 
import os
import tempfile
import subprocess

def ocr(path):
    temp = tempfile.NamedTemporaryFile(delete=False)

    process = subprocess.Popen(['tesseract', path, temp.name], stdout=subprocess.PIPE, stderr=subprocess.STDOUT)
    process.communicate()

    with open(temp.name + '.txt', 'r') as handle:
        contents = handle.read()

    os.remove(temp.name + '.txt')
    os.remove(temp.name)

    return contents

str = ocr('test_result.png')
print(str)

# %%
img = cv2.imread('img/product_5.jpg',0)

# %%
idx = 0
boxes = []
for c in contours:
    # Returns the location and width,height for every contour
    x, y, w, h = cv2.boundingRect(c)
    if (w > 80 and h > 20) and w > 3*h:
        idx += 1
        boxes.append(img[y:y+h, x:x+w])
# If the box height is greater then 20, widht is >80, then only save it as a box in "cropped/" folder.
    if (w > 80 and h > 20) and w > 3*h:
        idx += 1
        boxes.append(img[y:y+h, x:x+w])
        idx = 0
boxes = []
for c in contours:
    # Returns the location and width,height for every contour
    x, y, w, h = cv2.boundingRect(c)
    if (w > 80 and h > 20) and w > 3*h:
        idx += 1
        boxes.append(img[y:y+h, x:x+w])
# If the box height is greater then 20, widht is >80, then only save it as a box in "cropped/" folder.
    if (w > 80 and h > 20) and w > 3*h:
        idx += 1
        boxes.append(img[y:y+h, x:x+w])

# %%
boxes
