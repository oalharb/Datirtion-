# %% [markdown]
# ## Importing Libraries¶

# %%
import cv2
import os
from skimage import color, data, io, measure
from skimage.filters import threshold_otsu
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
from tqdm import tqdm
import glob
import matplotlib.image as mpimg
# %matplotlib inline
mpl.rcParams['image.cmap'] = 'gray'
plt.rcParams['figure.dpi']= 300
plt.rc("savefig", dpi=300)

# %%
def sort_contours(cnts, method="left-to-right"):
    # initialize the reverse flag and sort index
    reverse = False
    i = 0

    # handle if we need to sort in reverse
    if method == "right-to-left" or method == "bottom-to-top":
        reverse = False

    # handle if we are sorting against the y-coordinate rather than
    # the x-coordinate of the bounding box
    if method == "top-to-bottom" or method == "right-to-left":
        i = 1

    # construct the list of bounding boxes and sort them from top to
    # bottom
    boundingBoxes = [cv2.boundingRect(c) for c in cnts]
    (cnts, boundingBoxes) = zip(*sorted(zip(cnts, boundingBoxes),
        key=lambda b:b[1][i], reverse=reverse))

    # return the list of sorted contours and bounding boxes
    return (cnts, boundingBoxes)

# %%
def f(y):
    # Defining a kernel length
    global horizontal_lines_img, verticle_lines_img, kernel
    kernel_length = np.array(img).shape[1]//y

    # A verticle kernel of (1 X kernel_length), which will detect all the verticle lines from the image.
    verticle_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (1, kernel_length))
    # A horizontal kernel of (kernel_length X 1), which will help to detect all the horizontal line from the image.
    hori_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (kernel_length, 1))
    # A kernel of (3 X 3) ones.
    ###kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3, 3))
    # Morphological operation to detect vertical lines from an image
    img_temp1 = cv2.erode(img_bin, verticle_kernel, iterations=1)
    verticle_lines_img = cv2.dilate(img_temp1, verticle_kernel, iterations=1)
    cv2.imwrite("verticle_lines.jpg",verticle_lines_img)
    # Morphological operation to detect horizontal lines from an image
    img_temp2 = cv2.erode(img_bin, hori_kernel, iterations=1)
    horizontal_lines_img = cv2.dilate(img_temp2, hori_kernel, iterations=1)
    ###plt.subplot(1, 2, 1)  # 2 rows, 2 columns, 1st subplot = top left
    ###plt.imshow(verticle_lines_img);
    ###plt.axis('off')

    ###plt.subplot(1, 2, 2)  # 2 rows, 2 columns, 2nd subplot = top right
    plt.imshow(horizontal_lines_img);
    plt.axis('off')

# %%
#  images.append(mpimg.imread(img_path))
#     print("Processing Image", len(images))

# %% [markdown]
# ## The images are saved in the folder named as 'img_result'.

# %%
images = []
counter = 1
for img_path in tqdm(glob.glob('img/*.jpg')):
    
    img = cv2.imread(img_path,0)
    (thresh, img_bin) = cv2.threshold(img, 240, 255,cv2.THRESH_BINARY|cv2.THRESH_OTSU)
    img_bin = 255-img_bin
    f(255)
    alpha = 0.9
    beta = 1.0 - alpha
    # This function helps to add two image with specific weight parameter to get a third image as summation of two image.
    img_final_bin = cv2.addWeighted(verticle_lines_img, alpha, horizontal_lines_img, beta, 0.5)
    #img_final_bin = cv2.erode(~img_final_bin, kernel, iterations=2)
    (thresh, img_final_bin) = cv2.threshold(img_final_bin, 230,255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)
    plt.axis('off')
    plt.imshow(img_final_bin)
#     images.append(mpimg.imread(img_path))
    # Find contours for image, which will detect all the boxes
    contours, hierarchy = cv2.findContours(img_final_bin, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

    # Sort all the contours by top to bottom.
    (contours, boundingBoxes) = sort_contours(contours, method="top-to-bottom")
    idx = 1
    
    for c in (contours):
        # Returns the location and width,height for every contour
        x, y, w, h = cv2.boundingRect(c)
        
# If the box height is greater then 20, widht is >80, then only save it as a box in "cropped/" folder.
        if (w > 160 and h > 80) and w < 2.5 *h:
            idx += 3
            new_img = img[y:y+h, x:x+w]
            #plt.subplot(2,3, idx)
            plt.imshow(new_img)
            plt.axis('off')
            #cv2.imwrite('./th/')
            #path = './th/'
            #plt.savefig(f'./img_result/label{counter}.jpg',dpi=300)
            #cv2.imwrite(os.path.join(path , 'label'+str(num)+'.jpg'), new_img)
            #cv2.imwrite(os.path.join(path , 'f', new_img))
            file_n = img_path.split('_')[-1].split('.')[0]
            plt.savefig(f'./img_result/{file_n}_label{counter}.jpg',dpi=300)
            counter+=1
            #cv2.waitKey(0)
    #break
# Out:
#   0%|          | 0/17 [00:00<?, ?it/s]
#   6%|▌         | 1/17 [00:02<00:36,  2.25s/it]
#  12%|█▏        | 2/17 [00:11<01:06,  4.41s/it]
#  18%|█▊        | 3/17 [00:15<00:57,  4.11s/it]
#  24%|██▎       | 4/17 [00:32<01:45,  8.14s/it]
#  29%|██▉       | 5/17 [00:58<02:41, 13.45s/it]
#  35%|███▌      | 6/17 [01:18<02:49, 15.37s/it]
#  41%|████      | 7/17 [01:24<02:05, 12.54s/it]
#  47%|████▋     | 8/17 [02:09<03:21, 22.36s/it]
#  53%|█████▎    | 9/17 [03:11<04:33, 34.24s/it]
#  59%|█████▉    | 10/17 [03:31<03:30, 30.04s/it]
#  65%|██████▍   | 11/17 [03:55<02:48, 28.03s/it]
#  71%|███████   | 12/17 [04:09<01:59, 24.00s/it]
#  76%|███████▋  | 13/17 [04:25<01:25, 21.47s/it]
#  82%|████████▏ | 14/17 [04:36<00:54, 18.33s/it]
#  88%|████████▊ | 15/17 [06:46<01:44, 52.00s/it]
#  94%|█████████▍| 16/17 [07:16<00:45, 45.32s/it]
# 100%|██████████| 17/17 [07:27<00:00, 34.95s/it]

# %%
new_img
# Out:
# array([[139, 136, 134, ..., 136, 136, 136],
#        [134, 133, 134, ..., 136, 136, 136],
#        [133, 133, 137, ..., 137, 137, 137],
#        ...,
#        [110, 129, 139, ..., 134, 133, 134],
#        [122, 134, 136, ..., 135, 134, 134],
#        [124, 132, 132, ..., 136, 133, 131]], dtype=uint8)

# %% [markdown]
# ## Extracting text from Nutrition lables

# %% [markdown]
# ### ---------------

# %%
import pytesseract
from PIL import Image, ImageEnhance, ImageFilter
import os
import glob
import re
import sys
import cv2
import post_process

# %% [markdown]
# #sys.path.append('/usr/local/lib/python2.7/site-packages')
# ## FOR FEW IMAGES ONLY
#
# def writeFile(directory, fileName, content):
#     outFile = open('outputs/' + directory + '/' + fileName + '.txt', 'w')
#     outFile.write(content)
#     outFile.close()
#
# # Setup regex for stripping file names
# p = re.compile('[0-9]+.jpg')
#
# # Use images in the labels directory
# for file in glob.glob('./img_result/*.jpg'):
#     fileName = p.findall(file)[0]
#     print ("Proccessing " + fileName)
#     outFileName = fileName[0:len(fileName)-4]
#
#     #-----------------------
# #     # Get default text recognition
# #     output = pytesseract.image_to_string(Image.open(file))
# #     #print(output)
#
# #     # Write default text output to 'outputs/default' directory
# #     writeFile('default', outFileName, output)
#
#     # Open image as black and white
#     #-----------------------
#
#     bw = cv2.imread(file, 0)
#
#     # Apply adaptive thresholding to images
#     thresh = cv2.adaptiveThreshold(bw, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,\
#             cv2.THRESH_BINARY, 11, 2)
#
#     # Get text recognition from thresholded images
#     output = pytesseract.image_to_string(Image.fromarray(bw))
#     writeFile('bw', outFileName, output)
#
#     break

# %%
#####

def label_Recognizer(path):
    import re
    import os
    from matplotlib import pyplot 
    files = []
    for  r,d, f in os.walk(path):
        print(f)
        print(d)
        print(r)
        for file in f:
            files.append(os.path.join(file))
    p = re.compile('[0-9]+.jpg')
    all_result = []
    for f in files:
        #print(f)
     #   out_dict = end_to_end.end_to_end(f'{path}\{f}')
        #-----------------

        for file in glob.glob('img_result/*.jpg'):
            bw = cv2.imread(file, 0)

        # Apply adaptive thresholding to images
            thresh = cv2.adaptiveThreshold(bw, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,\
                cv2.THRESH_BINARY, 11, 2)

        # Get text recognition from thresholded images
            output = pytesseract.image_to_string(Image.fromarray(bw))

            fileName = p.findall(file)[0]
            print ("Proccessing " + fileName)
            #outFileName = fileName[0:len(fileName)-4]
            # Get default text recognition 
            #output = pytesseract.image_to_string(Image.open(file))
            x = post_process.post_process(output)
            print("/n/sLABEL", '\n', fileName, '\n', output)
            all_result.append(x)
            x['product_id']=file
        result = []
        for i in all_result:
            if len(i) == 0:
                pass
            else:
                result.append(i)
        return result

# %%
n = label_Recognizer('img_result/')
# Out:
# ['1_label19.jpg', '1_label25.jpg', '1_label24.jpg', '78_label71.jpg', '5_label48.jpg', '1_label23.jpg', '.DS_Store', '1_label22.jpg', '78_label70.jpg', '80_label49.jpg', '82_label56.jpg', '1_label20.jpg', '1_label21.jpg', '74_label12.jpg', '4_label43.jpg', '75_label7.jpg', '75_label6.jpg', '4_label42.jpg', '74_label11.jpg', '4_label40.jpg', '75_label5.jpg', '4_label41.jpg', '4_label45.jpg', '73_label18.jpg', '2_label27.jpg', '2_label26.jpg', '4_label44.jpg', '79_label57.jpg', '81_label52.jpg', '81_label53.jpg', '79_label67.jpg', '73_label17.jpg', '2_label28.jpg', '76_label1.jpg', '2_label29.jpg', '73_label16.jpg', '84_label72.jpg', '79_label66.jpg', '79_label58.jpg', '83_label54.jpg', '79_label64.jpg', '73_label14.jpg', '76_label3.jpg', '76_label2.jpg', '73_label15.jpg', '79_label65.jpg', '83_label55.jpg', '79_label59.jpg', '79_label61.jpg', '75_label8.jpg', '75_label9.jpg', '79_label60.jpg', '79_label62.jpg', '76_label4.jpg', '73_label13.jpg', '79_label63.jpg', '5_label47.jpg', '6_label34.jpg', '6_label35.jpg', '5_label46.jpg', '3_label30.jpg', '80_label50.jpg', '78_label69.jpg', '6_label37.jpg', '6_label36.jpg', '78_label68.jpg', '80_label51.jpg', '75_label10.jpg', '6_label32.jpg', '6_label33.jpg', '4_label38.jpg', '6_label31.jpg', '4_label39.jpg']
# []
# img_result/
# Proccessing 19.jpg
# [('sop ok oe sea (dsl sl gj) Yau lle Gaus |O@o AMA! O', '198', 0), ('Not WL MEG Rain, Rest Raforn, Raton No &', '987004, Your cally intakos ma', 1), ('ab iroby', '8 : F ; .', 2), ('Anas brett gist ', '0', 3), ('AAS YORATNEN', '2 Sk AMS. 3 M', 4), ('Net Wt.:', '80', 5)]
#
#
#
# [('Not WL MEG Rain, Rest Raforn, Raton No &', '987004, Your cally intakos ma', 1)]
#
#
#
# [('Not WL MEG Rain, Rest Raforn, Raton No &', '987004, Your cally intakos ma', 1)]
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  19.jpg
#  Allergen Waring: May Contain Tree
# Nuts, Wheat Gluten and Mustard
#
# Ingredients: Cumin Seed, Black
# Pepper, Cinnamon, Cardamom,
#
# Nemnag nn lames GARAM MASALA POWDER
#
# Ingré nts: graines de cumin, r "
#
# hace, Gos efi, alos ce Epices chaudes Poudre
#
# laurier et noix de muscace
#
# sop ok oe sea (dsl sl gj) Yau lle Gaus |O@o AMA! Oa1981
# ectebell Som ft ee LS
#
# abl Soe al, did
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Not WL MEG Rain, Rest Raforn, Raton No & 987004, Your cally intakos may
# MRP (Incl. ol taxes) Coded on she jaabel nate or lower copending on Yeu
#
# Ab A ST GUBIERY Goss a LP
# Taal ob pl gs)
#
# Store ina cool and dry place
#
#
#
#
#
#
#
# ab iroby 8 : F ; . a
# Anas brett gist V0 F
# 65! 3009
#
# AAS YORATNEN 2 Sk AMS. 3 Ma
#
# Net Wt.: 80g
# Pane ae ee oon ET)
# Proccessing 25.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  25.jpg
#
# Proccessing 24.jpg
# [('(cht sil aja) Vals allo Ga |C@o AMA! @', '198', 0)]
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  24.jpg
#  | GARAM MASALA POWDER
#
# Epices chaudes Poudre
# (cht sil aja) Vals allo Ga |C@o AMA! @a198)
# Proccessing 71.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  71.jpg
#
# Proccessing 48.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  48.jpg
#
# Proccessing 23.jpg
# [('cule Sym', '3 508 ee da', 0), ('Carb', '5 35a 5 lb) 4555 a', 1)]
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  23.jpg
#  Nuts, Wheat Gluten and Mustard
# Ingredients: Cumin Seed, Black
# Pepper, Cinnamon, Cardamom,
# Mace, Cloves, Bay Leaves &
# Nutmeg
# Ingrédients: graines de cumin,
# poivre noir, cannelle, cardamome,
# mace, clous de girofle, feuilles de
# laurier et noix de muscade
#
# gual Sid ec eS ge UL gall
# cule Sym 3 508 ee da 8
# Carb 5 35a 5 lb) 4555 ae
# Net Wi, MFG Date, Best Before, Batch No &
# MRP (Incl. of all taxes) Coded on the jar/label
# Rb By GSN) ByyE eM) aye all ail
# ya gk phe (al pales) jal
#
# Store in a cool and dry place
# Proccessing 22.jpg
# [('Serving Size:', '8 g (1tbsp', 0), ('Servings per package:', '1', 1)]
#
#
#
# [('Serving Size:', '8 g (1tbsp', 0), ('Servings per package:', '1', 1)]
#
#
#
# [('Serving Size:', '8 g (1tbsp', 0), ('Servings per package:', '1', 1)]
#
#
#
# [('Serving Size', '8 g (1tbsp', 1)]
#
#
#
# [('Serving Size', '8 g (1tbsp', 1)]
#
#
#
# /n/sLABEL
#  22.jpg
#  NUTRITION INFORMA
# Serving Size: 8 g (1tbsp)
# Servings per package: 12
#
# 13009!
#
# 41165
# Proccessing 70.jpg
# [('Serv Size', '1 02 (28g / about 1" cube) | PASTEURIZED PART-SKI', 0), ('Servings about', '8 MILK, CHEESE CULTURE', 1), ('Trans Fat', '0', 2), ('photest', '20mg 7% (Qs T', 3), ('im', '340mi', 4), ('Total Carb ', '1 0', 5), ('Vitamin A', '4% * Vitamin € 0', 6), ('2 Batcium BY ton', '02 BOF TRADITIONAL', 7), ('OP', 'C0276  105', 8)]
#
#
#
# [('Serv Size', '1 02 (28g / about 1" cube) | PASTEURIZED PART-SKI', 0), ('Servings about', '8 MILK, CHEESE CULTURE', 1), ('Trans Fat', '0', 2), ('Total Carb ', '1 0', 5), ('2 Batcium BY ton', '02 BOF TRADITIONAL', 7)]
#
#
#
# [('Serv Size', '1 02 (28g / about 1" cube) | PASTEURIZED PART-SKI', 0), ('Servings about', '8 MILK, CHEESE CULTURE', 1), ('Trans Fat', '0', 2), ('Total Carb ', '1 0', 5), ('2 Batcium BY ton', '02 BOF TRADITIONAL', 7)]
#
#
#
# [('Serving Size', '8 MILK, CHEESE CULTURE', 2), ('Total Fat', '1 0', 4), ('Trans Fat', '0', 3)]
#
#
#
# [('Serving Size', '8 MILK, CHEESE CULTURE', 2), ('Trans Fat', '0', 3)]
#
#
#
# /n/sLABEL
#  70.jpg
#  Nutrition Facts|INGREDIENTS:
# Serv Size 1 02 (28g / about 1" cube) | PASTEURIZED PART-SKIM
#
# Servings about 8 MILK, CHEESE CULTURE,
# —S — SALT, ENZYMES
#
# Trans Fat 0 a
#
# photest 20mg 7% (Qs TM
#
# im 340mi
# Total Carb <1 0%
#
# i ar
#
# a
# Vitamin A 4% * Vitamin € 0%
#
#
#
# 2 Batcium BY ton 02 BOF TRADITIONAL |
# sf
#
# 36
# Ee
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# OP C0276 e105)
# Proccessing 49.jpg
# [('s2llozza', '', 0)]
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  49.jpg
#  s2llozza
#
# Ml
#
# I
# Proccessing 56.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  56.jpg
#
# Proccessing 20.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  20.jpg
#
# Proccessing 21.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  21.jpg
#
# Proccessing 12.jpg
# [('Serving Size', '1 (40g', 0), ('Calories', '120 Calories from Fat 1', 1), ('Total Fat', '1.639 2.50', 2), ('Saturated Fat', '0.24 1.2', 3), ('Trans Fat', '0g Go', 4), ('Cholesterol', '10mg 3.32', 5), ('Sodium', '190mg 7.81', 6), ('Total Carbohydrate', '25.129 8.37', 7), ('Sugars', '11.51', 8), ('Protein', '1.2', 9), ('*Percent Daily Valued are basedon a', '2,000 calorie die', 10)]
#
#
#
# [('Serving Size', '1 (40g', 0), ('Calories', '120 Calories from Fat 1', 1), ('Total Fat', '1.639 2.50', 2), ('Saturated Fat', '0.24 1.2', 3), ('Trans Fat', '0g Go', 4), ('Cholesterol', '10mg 3.32', 5), ('Sodium', '190mg 7.81', 6), ('Total Carbohydrate', '25.129 8.37', 7), ('Sugars', '11.51', 8), ('Protein', '1.2', 9)]
#
#
#
# [('Serving Size', '1 (40g', 0), ('Calories', '120 Calories from Fat 1', 1), ('Total Fat', '1.639 2.50', 2), ('Saturated Fat', '0.24 1.2', 3), ('Trans Fat', '0g Go', 4), ('Cholesterol', '10mg 3.32', 5), ('Sodium', '190mg 7.81', 6), ('Total Carbohydrate', '25.129 8.37', 7), ('Sugars', '11.51', 8), ('Protein', '1.2', 9)]
#
#
#
# [('Serving Size', '1 (40g', 1), ('Calories', '120 Calories from Fat 1', 2), ('Total Fat', '1.639 2.50', 3), ('Saturated Fat', '0.24 1.2', 4), ('Trans Fat', '0g Go', 5), ('Cholesterol', '10mg 3.32', 6), ('Sodium', '190mg 7.81', 7), ('Total Carbohydrate', '25.129 8.37', 8), ('Sugars', '11.51', 9), ('Protein', '1.2', 10)]
#
#
#
# [('Serving Size', '1 (40g', 1), ('Calories', '120 Calories from Fat 1', 2), ('Total Fat', '1.639 2.50', 3), ('Saturated Fat', '0.24 1.2', 4), ('Trans Fat', '0g Go', 5), ('Cholesterol', '10mg 3.32', 6), ('Sodium', '190mg 7.81', 7), ('Total Carbohydrate', '25.129 8.37', 8), ('Sugars', '11.51', 9), ('Protein', '1.2', 10)]
#
#
#
# /n/sLABEL
#  12.jpg
#  Nutrition Facts
# Serving Size 1 (40g)
#
# Anount Per Serving
# Calories 120 Calories from Fat 15
# % Daily Values *
#
# Total Fat 1.639 2.50%
# Saturated Fat 0.24 1.2%
# Trans Fat 0g Go.
#
# Cholesterol 10mg 3.32%
#
# Sodium 190mg 7.81%
#
# Total Carbohydrate 25.129 8.37%
# Dietary Fiber Og
#
# Sugars 11.519
# Protein 1.23
#
# *Percent Daily Valued are basedon a 2,000 calorie diet
# Proccessing 43.jpg
# [('Serving Size', '30g 554k', 0), ('(132kcal)', '', 1)]
#
#
#
# [('Serving Size', '30g 554k', 0)]
#
#
#
# [('Serving Size', '30g 554k', 0)]
#
#
#
# [('Serving Size', '30g 554k', 1)]
#
#
#
# [('Serving Size', '30g 554k', 1)]
#
#
#
# /n/sLABEL
#  43.jpg
#  NUTRITION INFORMATION
#
# Serving Size 30g 554k)
# (132kcal)
#
# 3g
#
# 4.19
# Zig
# img
# 3.99
# 270mg
# Proccessing 7.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  7.jpg
#  Did you know Delamere milk has
# Q brilliant flavour and it's fat
# free! It's ideal for cooking and
#
# baking. Plus it’s also great in your
# | tea or coffee. Visit our website
# \ for delicious recipe ideas.
# Proccessing 6.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  6.jpg
#
# Proccessing 42.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  42.jpg
#  Il |
#
# By bese
# Proccessing 11.jpg
# [('BILL NIWA IV', '907 “LM aN DSIUAOM GLUALLINWO3 $1 580', 0)]
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  11.jpg
#  ere mee ae
#
#
#
#
#
#
#
#
# ee
# ae ert
# [a painetup gn meitetutecngtmnte
#
# Bune acheter gee
#
# Wor'sIOOISERD SYFIWOISND SII OLS IDAKIONA RARWA AIT,
#
# BILL NIWA IV 907 “LM aN DSIUAOM GLUALLINWO3 $1 5801
#
# CAKERS :
#
#
#
# ids sae
# th rich strawberry filling
#
# Shes
# Proccessing 40.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  40.jpg
#
# Proccessing 5.jpg
# [('eed', '-1 5', 0)]
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  5.jpg
#  get in touch:
# For recipes, information and
# where to buy, contact us.
#
# Delamere Dairy, Yew Tree Farm,
# Bexton Lane, Knutsford, Cheshire
#
# eed -1 5
#
# Send us an email
# info@delameredairy.co.uk
# Speak to us on the phone...
#
# 1 01565 750528
#
# Take a look at our lovely website...
#
#
#
# www.delameredairy.co.uk
# follow us On wf
# Proccessing 41.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  41.jpg
#
# Proccessing 45.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  45.jpg
#
# Proccessing 18.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  18.jpg
#
# Proccessing 27.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  27.jpg
#
# Proccessing 26.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  26.jpg
#
# Proccessing 44.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  44.jpg
#  olga fy JG
# ExP date
# Proccessing 57.jpg
# [('Saturated Fat', '5g 8', 0), ('|Sodium', '2', 1), ('6S pas duusudo', 'pas duusudo', 2), ('Nes rfl Color ', '008 roe', 3)]
#
#
#
# [('Saturated Fat', '5g 8', 0), ('|Sodium', '2', 1), ('6S pas duusudo', 'pas duusudo', 2)]
#
#
#
# [('Saturated Fat', '5g 8', 0), ('|Sodium', '2', 1), ('6S pas duusudo', 'pas duusudo', 2)]
#
#
#
# [('Saturated Fat', '5g 8', 1), ('Sodium', '2', 2)]
#
#
#
# [('Saturated Fat', '5g 8', 1), ('Sodium', '2', 2)]
#
#
#
# /n/sLABEL
#  57.jpg
#  Nutrition Facts
#
# TotalFat tig ———=«AT|
# Saturated Fat 5g 8%
#
# |_trans Fat Og
#
# Cholesterol oma
#
# |Sodium 2:
#
# FFotal Carb
#
# ERA
#
# INTELLIGENCE
#
# Qe OUNDATION
# 6S pas duusudo
#
# ull algal aigig La
#
# sila = Glae f
# —— P renee vont totais |
#
# PaO ee
# Nes rfl Color (008 roe)
#
# af eure pas
# Lee
# Proccessing 52.jpg
# [('i eet ry t:', '01565 750528 e: Info@delameredairy.co.u', 0), ('lo peataday ym pepuaig Jay', '81006 Aso} »', 1)]
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  52.jpg
#  i ire
# ae iy
#
# Po
#
# Cee AOTC Ca
#
# i eet ry t: 01565 750528 e: Info@delameredairy.co.uk
#
# iil ci | www.delameredairy.co.uk
#
# 016860 000451
#
#
#
# lo peataday ym pepuaig Jay 81006 Aso} » |
# 1)
#
# i VAT AN AVN
# Proccessing 53.jpg
# [('typical values', '100g (10g', 0), ('energy kJ/keal', '269/6', 1), ('of which saturates', '37.5g t', 2), ('mono - unsafurated', '2.4', 3), ('salt f= O', '1', 4)]
#
#
#
# [('energy kJ/keal', '269/6', 1), ('mono - unsafurated', '2.4', 3)]
#
#
#
# [('energy kJ/keal', '269/6', 1), ('mono - unsafurated', '2.4', 3)]
#
#
#
# [('Monounsaturated Fat', '2.4', 2)]
#
#
#
# []
#
#
#
# /n/sLABEL
#  53.jpg
#  A A per pack
# typical values 100g (10g)
#
# energy kJ/keal 269/65
# a yee
# of which saturates 37.5g te
#
# mono - unsafurated 2.49
# poly - unsaturated ons
# carbohydrate Og
# of which sugars Og
# protein Og
#
# salt f= O.1g
# Proccessing 67.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  67.jpg
#
# Proccessing 17.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  17.jpg
#
# Proccessing 28.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  28.jpg
#
# Proccessing 1.jpg
# [('= ¥iQNI', '40 Longowdy “Aq payiodxg 9 payoe', 0), ('Zl', '6LOZ 7O:Adldxd 40 div', 1), ('Buh', '8102/ 0 “oan 30 iv', 2), ('p0S0 <on nova', '<on nova', 3), ('a6 ——— ___ sn', '——— ___ sn', 4)]
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  1.jpg
#  hess
#
# =
# a
# =
# Py
# g
# €
# z
# A
# z
# 3S
# =
#
# ‘AyeweBuy “ur yse ‘anuaay suejooy
# “ge :xog IQ ayesodioy
# “GIT “\LAd SASTadadsa.LNa
#
# SNV'TOOW
#
# = ¥iQNI 40 Longowdy “Aq payiodxg 9 payoed
#
# *dOldd TIVLAY “XVI
# OR (ache
# Zl 6LOZ/7O:Adldxd 40 diva
# A? a2
# Buh 8102/P0 “oan 30 iva
#
# Ce im
# p0S0 <on nova
#
# HIPS WSOP ene
# a6 ——— ___ sn
#
# SC (rv oSrereiigiy
#
# (Wddid
# Proccessing 29.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  29.jpg
#
# Proccessing 16.jpg
# [('Serving Size', '22g (about 4 places', 0), ('Number of Servings Par Pack', 'of Servings Par Pack', 1), ('Calories', '100 4', 2), ('Calories from Fat', '3', 3), ('Total Fat ', '9) 3.', 4), ('Saturated Fat (g)', 'Fat (g)', 5), ('Trans Fat (g)', 'Fat (g)', 6), ('Sodium (mg)', '1', 7), ('Total Carbohydrates ', '9', 8), ('Dietary Fiber (g)', 'Fiber (g)', 9), ('Sugars (g)', '1', 10), ('Total Protein ', '4) 2 E', 11), ('Vitamin A (IU)', '240 13', 12), ('Calcium (mg)', '5 <2% REN', 13), ('Iron (mg)', '1 6', 14), ('Male adull requirement of', '19-29 years old', 15)]
#
#
#
# [('Serving Size', '22g (about 4 places', 0), ('Number of Servings Par Pack', 'of Servings Par Pack', 1), ('Calories', '100 4', 2), ('Calories from Fat', '3', 3), ('Total Fat ', '9) 3.', 4), ('Saturated Fat (g)', 'Fat (g)', 5), ('Trans Fat (g)', 'Fat (g)', 6), ('Sodium (mg)', '1', 7), ('Total Carbohydrates ', '9', 8), ('Dietary Fiber (g)', 'Fiber (g)', 9), ('Sugars (g)', '1', 10), ('Total Protein ', '4) 2 E', 11), ('Calcium (mg)', '5 <2% REN', 13)]
#
#
#
# [('Serving Size', '22g (about 4 places', 0), ('Number of Servings Par Pack', 'of Servings Par Pack', 1), ('Calories', '100 4', 2), ('Calories from Fat', '3', 3), ('Total Fat ', '9) 3.', 4), ('Saturated Fat (g)', 'Fat (g)', 5), ('Trans Fat (g)', 'Fat (g)', 6), ('Sodium (mg)', '1', 7), ('Total Carbohydrates ', '9', 8), ('Dietary Fiber (g)', 'Fiber (g)', 9), ('Sugars', '1', 10), ('Total Protein ', '4) 2 E', 11), ('Calcium (mg)', '5 <2% REN', 13)]
#
#
#
# [('Serving Size', '22g (about 4 places', 1), ('Calories', '100 4', 3), ('Total Fat', '9) 3.', 5), ('Saturated Fat', 'Fat (g)', 6), ('Trans Fat', 'Fat (g)', 7), ('Total Carbohydrate', '9', 9), ('Dietary Fiber', 'Fiber (g)', 10), ('Sugars', '1', 11)]
#
#
#
# [('Serving Size', '22g (about 4 places', 1), ('Calories', '100 4', 3), ('Total Fat', '9) 3.', 5), ('Saturated Fat', 'Fat (g)', 6), ('Trans Fat', 'Fat (g)', 7)]
#
#
#
# /n/sLABEL
#  16.jpg
#  Nutrition Facts
#
# Serving Size 22g (about 4 places)
# Number of Servings Par Pack 9
# Amount Per Serving %RENI*
#
# Calories 100 4%
#
# Calories from Fat 30
# Total Fat (9) 3.6
#
# Saturated Fat (g) 0
#
# Trans Fat (g) 0
# Cholesterol (mg)
# Sodium (mg) 10
# Total Carbohydrates (9)
#
# Dietary Fiber (g) 0
#
# Sugars (g) 10
# Total Protein (4) 2 ES
# Vitamin A (IU) 240 13%
# Calcium (mg) 5 <2% RENI
# Iron (mg) 1 6%
#
# “Percent Philippine REN values are based on FNRI reference
# Male adull requirement of 19-29 years old.
# Proccessing 72.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  72.jpg
#
# Proccessing 66.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  66.jpg
#
# Proccessing 58.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  58.jpg
#
# Proccessing 54.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  54.jpg
#
# Proccessing 64.jpg
# [('serving size', '1 oz (28g! About 21 pieces', 0), ('Calories', '160 Calories from fat 100', 1), ('Saturated Fatl', '6g9 | Ov', 2), ('Cholesterol Omg', '0', 3), ('Sodium', '250g 10', 4), ('Total Carbohydrate', '13g «6', 5), ('Dietray Fiber less than ig', '2', 6), ('Sugars', '0', 7)]
#
#
#
# [('serving size', '1 oz (28g! About 21 pieces', 0), ('Calories', '160 Calories from fat 100', 1), ('Saturated Fatl', '6g9 | Ov', 2), ('Cholesterol Omg', '0', 3), ('Sodium', '250g 10', 4), ('Total Carbohydrate', '13g «6', 5), ('Dietray Fiber less than ig', '2', 6), ('Sugars', '0', 7)]
#
#
#
# [('serving size', '1 oz (28g! About 21 pieces', 0), ('Calories', '160 Calories from fat 100', 1), ('Saturated Fatl', '6g9 | Ov', 2), ('Cholesterol Omg', '0', 3), ('Sodium', '250g 10', 4), ('Total Carbohydrate', '13g «6', 5), ('Dietray Fiber less than ig', '2', 6), ('Sugars', '0', 7)]
#
#
#
# [('Serving Size', '1 oz (28g! About 21 pieces', 1), ('Calories', '160 Calories from fat 100', 2), ('Saturated Fat', '6g9 | Ov', 3), ('Cholesterol', '0', 4), ('Sodium', '250g 10', 5), ('Total Carbohydrate', '13g «6', 6), ('Sugars', '0', 8)]
#
#
#
# [('Serving Size', '1 oz (28g! About 21 pieces', 1), ('Calories', '160 Calories from fat 100', 2), ('Saturated Fat', '6g9 | Ov', 3), ('Cholesterol', '0', 4), ('Sodium', '250g 10', 5), ('Total Carbohydrate', '13g «6', 6)]
#
#
#
# /n/sLABEL
#  64.jpg
#  Nutrition Facts
#
# serving size 1 oz (28g! About 21 pieces)
#
# Amount per serving
#
# Calories 160 Calories from fat 100%
# otal Fat tig
# Saturated Fatl.6g9 | Ovo
# Trans Fat Og
#
# Cholesterol Omg 0%
#
# Sodium 250g 10%
#
# Total Carbohydrate 13g «6k
# Dietray Fiber less than ig 2%
#
# Sugars 0g
#
# Protein ig
# Proccessing 14.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  14.jpg
#  =
#
# Cy
# Ss
# ee
#
# tito) e]Ulon me) Mata aaa Mle ally [sey
# Phy
#
# Ui
# Proccessing 3.jpg
# [('Serve Size', '5 tsp. 2gm (.072 oz', 0), ('Serving per container', '20', 1), ('Calories', '67 Fat Cal 5.', 2), ('Total Fat', '1', 3), ('Sodium', '48', 4), ('Total Carbohydrates', '11 3.6', 5), ('Distary', '1.39 4.8', 6), ('Calcium', '25', 7), ('Iron', '4', 8), ('Sugar', '', 9), ('Protein', '4', 10), ('Vitamin A Lass than', '1', 11), ('Vitamin G Less than', '1', 12), ('*Parcent values are based on a', '2,000 calories', 13)]
#
#
#
# [('Serve Size', '5 tsp. 2gm (.072 oz', 0), ('Serving per container', '20', 1), ('Calories', '67 Fat Cal 5.', 2), ('Total Fat', '1', 3), ('Sodium', '48', 4), ('Total Carbohydrates', '11 3.6', 5), ('Calcium', '25', 7), ('Sugar', '', 9), ('Protein', '4', 10)]
#
#
#
# [('Serve Size', '5 tsp. 2gm (.072 oz', 0), ('Serving per container', '20', 1), ('Calories', '67 Fat Cal 5.', 2), ('Total Fat', '1', 3), ('Sodium', '48', 4), ('Total Carbohydrates', '11 3.6', 5), ('Calcium', '25', 7), ('Sugars', '', 9), ('Protein', '4', 10)]
#
#
#
# [('Serving Size', '5 tsp. 2gm (.072 oz', 1), ('Calories', '67 Fat Cal 5.', 3), ('Total Fat', '1', 4), ('Sodium', '48', 5), ('Total Carbohydrate', '11 3.6', 6), ('Sugars', '', 8), ('Protein', '4', 9)]
#
#
#
# [('Serving Size', '5 tsp. 2gm (.072 oz', 1), ('Calories', '67 Fat Cal 5.', 3), ('Total Fat', '1', 4), ('Sodium', '48', 5), ('Total Carbohydrate', '11 3.6', 6)]
#
#
#
# /n/sLABEL
#  3.jpg
#  Siar tH
#
# Serve Size 5 tsp. 2gm (.072 oz)
# Serving per container 200
#
# Amount per serving % DY
# Calories 67 Fat Cal 5.5
#
# Total Fat 1g
# Saturated Fat Og
# Cholestral img
# Sodium 480
#
# Total Carbohydrates 11 3.6%
#
# Distary 1.39 4.8%
# Calcium 25%
# Iron 4%
# Sugar 1
#
# Protein 49
# Vitamin A Lass than 1%
# Vitamin G Less than 1%
# *Parcent values are based on a 2,000 calories:
# diet, Your daily values may be higher or lower
# depending on your calaria neads,
# Proccessing 2.jpg
# [('PIpU] “B[eJay ‘Z/GE', '9-UIYIO', 0), ('‘Qe :XOg ‘Od ', '89N}0 ayesodi0', 1), ('“G11 “LAd SHSTUdaALNA', '“LAd SHSTUdaALNA', 2), ('(SOxE} Ife ', '0 JOU', 3), ('"a0rdd TIWLaY “Xv', 'TIWLaY “Xv', 4), ('3/6', 'L02/p0:Aulaxa 20 av', 5), ('oC? \\k', '\\k', 6), ('B/V\\ek', '8L02/r0 “94W 40 av', 7), ('v0OSO -onHolva', '-onHolva', 8), ('Ge', '001 been', 9)]
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  2.jpg
#  PIpU] “B[eJay ‘Z/GEB9-UIYIO)
# ‘AjeweGuy “ur se ‘anueay suBjooW,
# ‘Qe :XOg ‘Od :89N}0 ayesodi04
# “G11 “LAd SHSTUdaALNA
#
#
#
#
#
#  (SOxE} Ife $0 JOU)
# "a0rdd TIWLaY “Xv
# OCF (Rech
# 3/6 L02/p0:Aulaxa 20 ava
# oC? \km2
# B/V\ek 8L02/r0 “94W 40 ava
# Cr rer
# v0OSO -onHolva
#
#
#
#
#
#
#
# Ge 001 been
# Gack Joann | sap
# SC (Ptr OSeiar
# Proccessing 15.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  15.jpg
#  Ae
# \ SAMETASTE
# Proccessing 65.jpg
# [('OFS6', '7922759 - 0798901798 : itl', 0)]
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  65.jpg
#  : all
#
# | ERA
# INTELLIGENCE
# ) FOUNDATION
#
# Ne oe ais
#
#
#
#
# dufliell sigall guigig dylail
# tla = gyloue
# OFS6 7922759 - 0798901798 : itl
# Proccessing 55.jpg
# [('Serving aize ] piece ', '232', 0), ('Total Fat', 'Fat', 1), ('Sodium', '290', 2), ('etal Carbohydrates', '1', 3), ('- Dietary Fiber', 'Dietary Fiber', 4), ('20M) calories diet.', 'calories diet.', 5)]
#
#
#
# [('Serving aize ] piece ', '232', 0), ('Total Fat', 'Fat', 1), ('Sodium', '290', 2), ('etal Carbohydrates', '1', 3), ('- Dietary Fiber', 'Dietary Fiber', 4), ('20M) calories diet.', 'calories diet.', 5)]
#
#
#
# [('Serving aize ] piece ', '232', 0), ('Total Fat', 'Fat', 1), ('Sodium', '290', 2), ('etal Carbohydrates', '1', 3), ('- Dietary Fiber', 'Dietary Fiber', 4), ('20M) calories diet.', 'calories diet.', 5)]
#
#
#
# [('Total Fat', 'Fat', 2), ('Sodium', '290', 3), ('Total Carbohydrate', '1', 4), ('Dietary Fiber', 'Dietary Fiber', 5)]
#
#
#
# [('Total Fat', 'Fat', 2), ('Sodium', '290', 3), ('Total Carbohydrate', '1', 4)]
#
#
#
# /n/sLABEL
#  55.jpg
#  Nutrition Facts
#
# Serving aize ] piece (232)
# Servings per
#
# LT iv
#
# Total Fat 0
#
# Saterated Fat
#
# Cholesterol Omg
#
# Sodium 2900
#
# etal Carbohydrates 1g
# - Dietary Fiber 0
# * Percent Daily Valoes are based on a
# 20M) calories diet.
# Proccessing 59.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  59.jpg
#
# Proccessing 61.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  61.jpg
#
# Proccessing 8.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  8.jpg
#
# Proccessing 9.jpg
# [('O17 (ad lS) aewall &', '9 jie GR Gul Cpt Je', 0), ('puslll & gis alae iy Guile', '1cU gal', 1)]
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  9.jpg
#  Delamere Dairy Sterilized Skimmed Cow's
# Milk It
# O17 (ad lS) aewall & 9 jie GR Gul Cpt Jee
#
# puslll & gis alae iy Guile 1cU gall
#
# Saas ¢ Ll
# Proccessing 60.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  60.jpg
#
# Proccessing 62.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  62.jpg
#
# Proccessing 4.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  4.jpg
#
# Proccessing 13.jpg
# [('Sorvitg Size', '229 (about 4 places', 0), ('‘Number of Servings Fer Pack', 'of Servings Fer Pack', 1), ('Vitamin A (U)', '13', 2), ('Male acultrequiremert of', '19:29 years old', 3)]
#
#
#
# [('Sorvitg Size', '229 (about 4 places', 0), ('‘Number of Servings Fer Pack', 'of Servings Fer Pack', 1)]
#
#
#
# [('Sorvitg Size', '229 (about 4 places', 0), ('‘Number of Servings Fer Pack', 'of Servings Fer Pack', 1)]
#
#
#
# [('Serving Size', '229 (about 4 places', 1)]
#
#
#
# [('Serving Size', '229 (about 4 places', 1)]
#
#
#
# /n/sLABEL
#  13.jpg
#  Nutrition Facts
#
# Sorvitg Size 229 (about 4 places)
# ‘Number of Servings Fer Pack 9
#
# ‘Amount Per Serving %oRENI*
# 100 4%
#
# Trans Fat)
# Cholesterol
#
# ‘Sodium.
#
# Total Carbohydrates (¢)
# Oo Fiber
#
# 3%
# Vitamin A (U) 13%
# Calcium (mg) SSH REND
# iren (ng)
#
# *orcatt Prlippina REN velues are based cn FNRI rofererce
# Male acultrequiremert of 19:29 years old.
#
# |
#
# |
#
# ll
#
# 1463
# Proccessing 63.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  63.jpg
#
# Proccessing 47.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  47.jpg
#
# Proccessing 34.jpg
# [('6\'"253501 Ill)', 'Ill)', 0)]
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  34.jpg
#  6'"253501 Ill)
# Proccessing 35.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  35.jpg
#  Tne
# =a
#
# ig
# 41g
# 21g
# Omg
# 3,99
# 270mg
# Proccessing 46.jpg
# [('67 Moo', '1;Tumbol Nongkiangna', 0), ('70000 Thailand’.', 'Thailand’.', 1), ('Tel.', '(662) 584-1777', 2)]
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  46.jpg
#  CRAFTED
#
# WITH HEART
#
#
#
#
#
#
# Meticulousness is our most vital
# ingredient. We put our heart and
# ‘soul in every step taken,
# assuring the finest quality
# and true satisfaction.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Our coconut water comes from
# Green Coconuts which are
# grown in Thailand with delicately
# hand-picked selection for
# highest quality to deliver
# its natural taste and
#
# fresh scent in every sip ;
# that keep you coming for more. ; Bobet Belaraséowcnicart
#
#
#
#
#
#
#
#
#
# Best Served Chilled
#
# oy
#
# Ingredient
# Pure Coconut Water
#
# Product of Thailand
#
# produced by THALCOCONUTPCL.
# 67 Moo 1;Tumbol Nongkiangna
#
# hoe Muang, Ratchaburi.
# 70000 Thailand’.
# E-mail: éxportethaicoconut.com
#
# Tel. (662) 584-1777
#
#
#
#
#
#
#
# ee oor thalegeconnt
#
# : 1 \
# Proccessing 30.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  30.jpg
#
# Proccessing 50.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  50.jpg
#
# Proccessing 69.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  69.jpg
#  s
#
#
#
# Cs Ext-S E
# SEE NUTRITION INFORMATION
# FOR SATURATED FAT AND
# SODIUM CONTENT
# Proccessing 37.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  37.jpg
#
# Proccessing 36.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  36.jpg
#  cay) fa
# Sa
#
# alga) Fy
# EXP date
# Proccessing 68.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  68.jpg
#
# Proccessing 51.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  51.jpg
#
# Proccessing 10.jpg
# [('S41 (arid colt) anual &', '9 5h hs Gul cg ygd Saa', 0), ('posal €', '5s ple fay Guile 2 Sa', 1)]
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  10.jpg
#  Delamere Dairy Sterilized Skimmed Cow's
# Milk Alt
# S41 (arid colt) anual & 9 5h hs Gul cg ygd Saal
#
# posal € 5s ple fay Guile 2 Sal
#
#
#
#
#
# Saas gu)
#
# \ /
# Proccessing 32.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  32.jpg
#
# Proccessing 33.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  33.jpg
#
# Proccessing 38.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  38.jpg
#  304182
# Proccessing 31.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  31.jpg
#
# Proccessing 39.jpg
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# []
#
#
#
# /n/sLABEL
#  39.jpg

# %%
len(n)
# Out:
# 72

# %%
dx = pd.DataFrame(n)

# %%
dx.product_id.unique()
# Out:
# array(['img_result/1_label19.jpg', 'img_result/1_label25.jpg',
#        'img_result/1_label24.jpg', 'img_result/78_label71.jpg',
#        'img_result/5_label48.jpg', 'img_result/1_label23.jpg',
#        'img_result/1_label22.jpg', 'img_result/78_label70.jpg',
#        'img_result/80_label49.jpg', 'img_result/82_label56.jpg',
#        'img_result/1_label20.jpg', 'img_result/1_label21.jpg',
#        'img_result/74_label12.jpg', 'img_result/4_label43.jpg',
#        'img_result/75_label7.jpg', 'img_result/75_label6.jpg',
#        'img_result/4_label42.jpg', 'img_result/74_label11.jpg',
#        'img_result/4_label40.jpg', 'img_result/75_label5.jpg',
#        'img_result/4_label41.jpg', 'img_result/4_label45.jpg',
#        'img_result/73_label18.jpg', 'img_result/2_label27.jpg',
#        'img_result/2_label26.jpg', 'img_result/4_label44.jpg',
#        'img_result/79_label57.jpg', 'img_result/81_label52.jpg',
#        'img_result/81_label53.jpg', 'img_result/79_label67.jpg',
#        'img_result/73_label17.jpg', 'img_result/2_label28.jpg',
#        'img_result/76_label1.jpg', 'img_result/2_label29.jpg',
#        'img_result/73_label16.jpg', 'img_result/84_label72.jpg',
#        'img_result/79_label66.jpg', 'img_result/79_label58.jpg',
#        'img_result/83_label54.jpg', 'img_result/79_label64.jpg',
#        'img_result/73_label14.jpg', 'img_result/76_label3.jpg',
#        'img_result/76_label2.jpg', 'img_result/73_label15.jpg',
#        'img_result/79_label65.jpg', 'img_result/83_label55.jpg',
#        'img_result/79_label59.jpg', 'img_result/79_label61.jpg',
#        'img_result/75_label8.jpg', 'img_result/75_label9.jpg',
#        'img_result/79_label60.jpg', 'img_result/79_label62.jpg',
#        'img_result/76_label4.jpg', 'img_result/73_label13.jpg',
#        'img_result/79_label63.jpg', 'img_result/5_label47.jpg',
#        'img_result/6_label34.jpg', 'img_result/6_label35.jpg',
#        'img_result/5_label46.jpg', 'img_result/3_label30.jpg',
#        'img_result/80_label50.jpg', 'img_result/78_label69.jpg',
#        'img_result/6_label37.jpg', 'img_result/6_label36.jpg',
#        'img_result/78_label68.jpg', 'img_result/80_label51.jpg',
#        'img_result/75_label10.jpg', 'img_result/6_label32.jpg',
#        'img_result/6_label33.jpg', 'img_result/4_label38.jpg',
#        'img_result/6_label31.jpg', 'img_result/4_label39.jpg'],
#       dtype=object)

# %%
dx.product_id = dx.product_id.apply(lambda x:x.replace('img_result\\',''))

# %%
dx.head()
# Out:
#   Calories Cholesterol Protein Saturated Fat Serving Size Sodium Sugars  \
# 0      NaN         NaN     NaN           NaN          NaN    NaN    NaN
# 1      NaN         NaN     NaN           NaN          NaN    NaN    NaN
# 2      NaN         NaN     NaN           NaN          NaN    NaN    NaN
# 3      NaN         NaN     NaN           NaN          NaN    NaN    NaN
# 4      NaN         NaN     NaN           NaN          NaN    NaN    NaN
#
#   Total Carbohydrate Total Fat Trans Fat                 product_id
# 0                NaN       NaN       NaN   img_result/1_label19.jpg
# 1                NaN       NaN       NaN   img_result/1_label25.jpg
# 2                NaN       NaN       NaN   img_result/1_label24.jpg
# 3                NaN       NaN       NaN  img_result/78_label71.jpg
# 4                NaN       NaN       NaN   img_result/5_label48.jpg

# %%
dx=dx.set_index(keys='product_id').dropna(how='all').head(17)

# %%
dx.head()
# Out:
#                           Calories Cholesterol Protein Saturated Fat  \
# product_id
# img_result/1_label22.jpg       NaN         NaN     NaN           NaN
# img_result/78_label70.jpg      NaN         NaN     NaN           NaN
# img_result/74_label12.jpg      120          10     1.2          0.24
# img_result/4_label43.jpg       NaN         NaN     NaN           NaN
# img_result/79_label57.jpg      NaN         NaN     NaN             5
#
#                           Serving Size Sodium Sugars Total Carbohydrate  \
# product_id
# img_result/1_label22.jpg             8    NaN    NaN                NaN
# img_result/78_label70.jpg            8    NaN    NaN                NaN
# img_result/74_label12.jpg            1    190  11.51              25.12
# img_result/4_label43.jpg            30    NaN    NaN                NaN
# img_result/79_label57.jpg          NaN      2    NaN                NaN
#
#                           Total Fat Trans Fat
# product_id
# img_result/1_label22.jpg        NaN       NaN
# img_result/78_label70.jpg       NaN         0
# img_result/74_label12.jpg      1.63         0
# img_result/4_label43.jpg        NaN       NaN
# img_result/79_label57.jpg       NaN       NaN

# %%
#dx.dtypes

# %%
# values = [60, 80, 90, 55, 10]
# colors = ['b', 'g', 'r', 'c', 'm', 'y']
# labels = ['Calories', 'Cholesterol', 'Protein', 'Sodium', 'Sugars']
# plt.pie(values, colors=colors, labels= values,explode=explode,counterclock=False, shadow=True)
# plt.title('Population Density Index')
# plt.legend(labels,loc=10)
# plt.show()

# %%
raw_data = {'image': ['img_result/74_label12.jpg','img_result/4_label43.jpg'],
            'Calories':[120,110],
        'Cholesterol': [10,9],
        'Protein': [1.2,0.9],
        'Saturated Fat':[0.24,1.1],
        'Sodium': [190,180],
           'Sugars':[11.51,10.9],
          'Total Carbohydrate':[25.12,22.23],
           'Total Fat':[1.63,2.54],
          'Trans Fat':[0,0] }
df = pd.DataFrame(raw_data, columns = ['image','Calories', 'Cholesterol', 'Protein','Saturated Fat', 'Sodium','Sugars',
                                      'Total Carbohydrate','Total Fat','Trans Fat'])
df

# %%
raw_data = {'image': ['img_result/74_label12.jpg'],
            'Calories':[120],
        'Cholesterol': [10],
        'Protein': [1.2],
        'Saturated Fat':[0.24],
        'Sodium': [190],
           'Sugars':[11.51],
          'Total Carbohydrate':[25.12],
           'Total Fat':[1.63],
          'Trans Fat':[0] }
df = pd.DataFrame(raw_data, columns = ['image','Calories', 'Cholesterol', 'Protein','Saturated Fat', 'Sodium','Sugars',
                                      'Total Carbohydrate','Total Fat','Trans Fat'])
df
# Out:
#                        image  Calories  Cholesterol  Protein  Saturated Fat  \
# 0  img_result/74_label12.jpg       120           10      1.2           0.24
#
#    Sodium  Sugars  Total Carbohydrate  Total Fat  Trans Fat
# 0     190   11.51               25.12       1.63          0

# %%
df.plot.bar()

# %%
raw_data = {'image': ['img_result/74_label12.jpg'],
        'Cholesterol': [10],
        'Protein': [1.2],
        'Sodium': [190],
           'Sugars':[11.51]}
df = pd.DataFrame(raw_data, columns = ['image', 'Cholesterol', 'Protein', 'Sodium','Sugars'])
df
# Out:
#                        image  Cholesterol  Protein  Sodium  Sugars
# 0  img_result/74_label12.jpg           10      1.2     190   11.51

# %%
def _color_red_or_green(val):
    color = 'red' if val < 0 else 'green'
    return 'color: %s' % color

# %%
(dx
    .style
    .background_gradient(cmap='vridias', low=.5, high=10)
    .highlight_null('green'))
# Out:
# <style  type="text/css" >
#     #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row0_col0 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row0_col1 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row0_col2 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row0_col3 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row0_col5 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row0_col6 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row0_col7 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row0_col8 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row0_col9 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row1_col0 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row1_col1 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row1_col2 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row1_col3 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row1_col5 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row1_col6 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row1_col7 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row1_col8 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row3_col0 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row3_col1 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row3_col2 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row3_col3 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row3_col5 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row3_col6 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row3_col7 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row3_col8 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row3_col9 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row4_col0 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row4_col1 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row4_col2 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row4_col4 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row4_col6 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row4_col7 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row4_col8 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row4_col9 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row5_col1 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row5_col2 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row5_col5 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row5_col6 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row5_col7 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row6_col2 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row6_col6 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row6_col8 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row6_col9 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row7_col1 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row7_col2 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row7_col3 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row7_col6 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row7_col9 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row8_col0 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row8_col1 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row8_col2 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row8_col3 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row8_col4 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row8_col6 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row8_col9 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row9_col0 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row9_col1 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row9_col2 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row9_col3 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row9_col5 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row9_col6 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row9_col7 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row9_col8 {
#             background-color:  green;
#         }    #T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row9_col9 {
#             background-color:  green;
#         }</style><table id="T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Calories</th>        <th class="col_heading level0 col1" >Cholesterol</th>        <th class="col_heading level0 col2" >Protein</th>        <th class="col_heading level0 col3" >Saturated Fat</th>        <th class="col_heading level0 col4" >Serving Size</th>        <th class="col_heading level0 col5" >Sodium</th>        <th class="col_heading level0 col6" >Sugars</th>        <th class="col_heading level0 col7" >Total Carbohydrate</th>        <th class="col_heading level0 col8" >Total Fat</th>        <th class="col_heading level0 col9" >Trans Fat</th>    </tr>    <tr>        <th class="index_name level0" >product_id</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904level0_row0" class="row_heading level0 row0" >img_result/1_label22.jpg</th>
#                         <td id="T_c8e6d9b0_1e57_11ea_a2ae_80e6500e4904row0_col0" class="data row0 col0" >nan</td>
#                         <td id="T_c8

# %%
import seaborn as sns

cm = sns.light_palette("red", as_cmap=True)

s = df.style.background_gradient(cmap=cm)
s
# Out:
# <style  type="text/css" >
#     #T_00edf37c_1e5b_11ea_a2ae_80e6500e4904row0_col1 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }    #T_00edf37c_1e5b_11ea_a2ae_80e6500e4904row0_col2 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }    #T_00edf37c_1e5b_11ea_a2ae_80e6500e4904row0_col3 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }    #T_00edf37c_1e5b_11ea_a2ae_80e6500e4904row0_col4 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_00edf37c_1e5b_11ea_a2ae_80e6500e4904row0_col5 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }    #T_00edf37c_1e5b_11ea_a2ae_80e6500e4904row0_col6 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }    #T_00edf37c_1e5b_11ea_a2ae_80e6500e4904row0_col7 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }    #T_00edf37c_1e5b_11ea_a2ae_80e6500e4904row0_col8 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_00edf37c_1e5b_11ea_a2ae_80e6500e4904row0_col9 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_00edf37c_1e5b_11ea_a2ae_80e6500e4904row1_col1 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_00edf37c_1e5b_11ea_a2ae_80e6500e4904row1_col2 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_00edf37c_1e5b_11ea_a2ae_80e6500e4904row1_col3 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_00edf37c_1e5b_11ea_a2ae_80e6500e4904row1_col4 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }    #T_00edf37c_1e5b_11ea_a2ae_80e6500e4904row1_col5 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_00edf37c_1e5b_11ea_a2ae_80e6500e4904row1_col6 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_00edf37c_1e5b_11ea_a2ae_80e6500e4904row1_col7 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }    #T_00edf37c_1e5b_11ea_a2ae_80e6500e4904row1_col8 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }    #T_00edf37c_1e5b_11ea_a2ae_80e6500e4904row1_col9 {
#             background-color:  #ffe5e5;
#             color:  #000000;
#         }</style><table id="T_00edf37c_1e5b_11ea_a2ae_80e6500e4904" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >image</th>        <th class="col_heading level0 col1" >Calories</th>        <th class="col_heading level0 col2" >Cholesterol</th>        <th class="col_heading level0 col3" >Protein</th>        <th class="col_heading level0 col4" >Saturated Fat</th>        <th class="col_heading level0 col5" >Sodium</th>        <th class="col_heading level0 col6" >Sugars</th>        <th class="col_heading level0 col7" >Total Carbohydrate</th>        <th class="col_heading level0 col8" >Total Fat</th>        <th class="col_heading level0 col9" >Trans Fat</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_00edf37c_1e5b_11ea_a2ae_80e6500e4904level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_00edf37c_1e5b_11ea_a2ae_80e6500e4904row0_col0" class="data row0 col0" >img_result/74_label12.jpg</td>
#                         <td id="T_00edf37c_1e5b_11ea_a2ae_80e6500e4904row0_col1" class="data row0 col1" >120</td>
#                         <td id="T_00edf37c_1e5b_11ea_a2ae_80e6500e4904row0_col2" class="data row0 col2" >10</td>
#                         <td id="T_00edf37c_1e5b_11ea_a2ae_80e6500e4904row0_col3" class="data row0 col3" >1.2</td>
#                         <td id="T_00edf37c_1e5b_11ea_a2ae_80e6500e4904row0_col4" class="data row0 col4" >0.24</td>
#                         <td id="T_00edf37c_1e5b_11ea_a2ae_80e6500e4904row0_col5" class="data row0 col5" >190</td>
#                         <td id="T_00edf37c_1e5b_11ea_a2ae_80e6500e4904row0_col6" class="data row0 col6" >11.51</td>
#                         <td id="T_00edf37c_1e5b_11ea_a2ae_80e6500e4904row0_col7" class="data row0 col7" >25.12</td>
#                         <td id="T_00edf37c_1e5b_11ea_a2ae_80e6500e4904row0_col8" class="data row0 col8" >1.63</td>
#                         <td id="T_00edf37c_1e5b_11ea_a2ae_80e6500e4904row0_col9" class="data row0 col9" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_00edf37c_1e5b_11ea_a2ae_80e6500e4904level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_00edf37c_1e5b_11ea_a2ae_80e6500e4904row1_col0" class="data row1 col0" >img_result/4_label43.jpg	</td>
#                         <td id="T_00edf37c_1e5b_11ea_a2ae_80e6500e4904row1_col1" class="data row1 col1" >110</td>
#                         <td id="T_00edf37c_1e5b_11ea_a2ae_80e6500e4904row1_col2" class="data row1 col2" >9</td>
#                         <td id="T_00edf37c_1e5b_11ea_a2ae_80e6500e4904row1_col3" class="data row1 col3" >0.9</td>
#                         <td id="T_00edf37c_1e5b_11ea_a2ae_80e6500e4904row1_col4" class="data row1 col4" >1.1</td>
#                         <td id="T_00edf37c_1e5b_11ea_a2ae_80e6500e4904row1_col5" class="data row1 col5" >180</td>
#                         <td id="T_00edf37c_1e5b_11ea_a2ae_80e6500e4904row1_col6" class="data row1 col6" >10.9</td>
#                         <td id="T_00edf37c_1e5b_11ea_a2ae_80e6500e4904row1_col7" class="data row1 col7" >22.23</td>
#                         <td id="T_00edf37c_1e5b_11ea_a2ae_80e6500e4904row1_col8" class="data row1 col8" >2.54</td>
#                         <td id="T_00edf37c_1e5b_11ea_a2ae_80e6500e4904row1_col9" class="data row1 col9" >0</td>
#             </tr>
#     </tbody></table>

# %%
dx.style.highlight_null(null_color='red')
# Out:
# <style  type="text/css" >
#     #T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row0_col0 {
#             background-color:  red;
#         }    #T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row0_col1 {
#             background-color:  red;
#         }    #T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row0_col2 {
#             background-color:  red;
#         }    #T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row0_col3 {
#             background-color:  red;
#         }    #T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row0_col5 {
#             background-color:  red;
#         }    #T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row0_col6 {
#             background-color:  red;
#         }    #T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row0_col7 {
#             background-color:  red;
#         }    #T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row0_col8 {
#             background-color:  red;
#         }    #T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row0_col9 {
#             background-color:  red;
#         }    #T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row1_col0 {
#             background-color:  red;
#         }    #T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row1_col1 {
#             background-color:  red;
#         }    #T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row1_col2 {
#             background-color:  red;
#         }    #T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row1_col3 {
#             background-color:  red;
#         }    #T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row1_col5 {
#             background-color:  red;
#         }    #T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row1_col6 {
#             background-color:  red;
#         }    #T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row1_col7 {
#             background-color:  red;
#         }    #T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row1_col8 {
#             background-color:  red;
#         }    #T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row3_col0 {
#             background-color:  red;
#         }    #T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row3_col1 {
#             background-color:  red;
#         }    #T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row3_col2 {
#             background-color:  red;
#         }    #T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row3_col3 {
#             background-color:  red;
#         }    #T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row3_col5 {
#             background-color:  red;
#         }    #T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row3_col6 {
#             background-color:  red;
#         }    #T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row3_col7 {
#             background-color:  red;
#         }    #T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row3_col8 {
#             background-color:  red;
#         }    #T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row3_col9 {
#             background-color:  red;
#         }    #T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row4_col0 {
#             background-color:  red;
#         }    #T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row4_col1 {
#             background-color:  red;
#         }    #T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row4_col2 {
#             background-color:  red;
#         }    #T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row4_col4 {
#             background-color:  red;
#         }    #T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row4_col6 {
#             background-color:  red;
#         }    #T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row4_col7 {
#             background-color:  red;
#         }    #T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row4_col8 {
#             background-color:  red;
#         }    #T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row4_col9 {
#             background-color:  red;
#         }</style><table id="T_f384cc4a_1df3_11ea_a2ae_80e6500e4904" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Calories</th>        <th class="col_heading level0 col1" >Cholesterol</th>        <th class="col_heading level0 col2" >Protein</th>        <th class="col_heading level0 col3" >Saturated Fat</th>        <th class="col_heading level0 col4" >Serving Size</th>        <th class="col_heading level0 col5" >Sodium</th>        <th class="col_heading level0 col6" >Sugars</th>        <th class="col_heading level0 col7" >Total Carbohydrate</th>        <th class="col_heading level0 col8" >Total Fat</th>        <th class="col_heading level0 col9" >Trans Fat</th>    </tr>    <tr>        <th class="index_name level0" >product_id</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f384cc4a_1df3_11ea_a2ae_80e6500e4904level0_row0" class="row_heading level0 row0" >img_result/1_label22.jpg</th>
#                         <td id="T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row0_col0" class="data row0 col0" >nan</td>
#                         <td id="T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row0_col1" class="data row0 col1" >nan</td>
#                         <td id="T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row0_col2" class="data row0 col2" >nan</td>
#                         <td id="T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row0_col3" class="data row0 col3" >nan</td>
#                         <td id="T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row0_col4" class="data row0 col4" >8</td>
#                         <td id="T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row0_col5" class="data row0 col5" >nan</td>
#                         <td id="T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row0_col6" class="data row0 col6" >nan</td>
#                         <td id="T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row0_col7" class="data row0 col7" >nan</td>
#                         <td id="T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row0_col8" class="data row0 col8" >nan</td>
#                         <td id="T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row0_col9" class="data row0 col9" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_f384cc4a_1df3_11ea_a2ae_80e6500e4904level0_row1" class="row_heading level0 row1" >img_result/78_label70.jpg</th>
#                         <td id="T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row1_col0" class="data row1 col0" >nan</td>
#                         <td id="T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row1_col1" class="data row1 col1" >nan</td>
#                         <td id="T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row1_col2" class="data row1 col2" >nan</td>
#                         <td id="T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row1_col3" class="data row1 col3" >nan</td>
#                         <td id="T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row1_col4" class="data row1 col4" >8</td>
#                         <td id="T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row1_col5" class="data row1 col5" >nan</td>
#                         <td id="T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row1_col6" class="data row1 col6" >nan</td>
#                         <td id="T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row1_col7" class="data row1 col7" >nan</td>
#                         <td id="T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row1_col8" class="data row1 col8" >nan</td>
#                         <td id="T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row1_col9" class="data row1 col9" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_f384cc4a_1df3_11ea_a2ae_80e6500e4904level0_row2" class="row_heading level0 row2" >img_result/74_label12.jpg</th>
#                         <td id="T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row2_col0" class="data row2 col0" >120</td>
#                         <td id="T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row2_col1" class="data row2 col1" >10</td>
#                         <td id="T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row2_col2" class="data row2 col2" >1.2</td>
#                         <td id="T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row2_col3" class="data row2 col3" >0.24</td>
#                         <td id="T_f384cc4a_1df3_11ea_a2ae_80e6500e4904row2_col4" class="data row2 col4" >1</td>
#                         <td id="T_f384cc4a_1df3_11ea_a2ae_80e6500e4904ro

# %%
df.style.highlight_max(axis=0)
# Out:
# <style  type="text/css" >
#     #T_f6a5af2a_1df3_11ea_a2ae_80e6500e4904row0_col1 {
#             background-color:  yellow;
#         }    #T_f6a5af2a_1df3_11ea_a2ae_80e6500e4904row0_col2 {
#             background-color:  yellow;
#         }    #T_f6a5af2a_1df3_11ea_a2ae_80e6500e4904row0_col3 {
#             background-color:  yellow;
#         }    #T_f6a5af2a_1df3_11ea_a2ae_80e6500e4904row0_col4 {
#             background-color:  yellow;
#         }</style><table id="T_f6a5af2a_1df3_11ea_a2ae_80e6500e4904" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >image</th>        <th class="col_heading level0 col1" >Cholesterol</th>        <th class="col_heading level0 col2" >Protein</th>        <th class="col_heading level0 col3" >Sodium</th>        <th class="col_heading level0 col4" >Sugars</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f6a5af2a_1df3_11ea_a2ae_80e6500e4904level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f6a5af2a_1df3_11ea_a2ae_80e6500e4904row0_col0" class="data row0 col0" >img_result/74_label12.jpg</td>
#                         <td id="T_f6a5af2a_1df3_11ea_a2ae_80e6500e4904row0_col1" class="data row0 col1" >10</td>
#                         <td id="T_f6a5af2a_1df3_11ea_a2ae_80e6500e4904row0_col2" class="data row0 col2" >1.2</td>
#                         <td id="T_f6a5af2a_1df3_11ea_a2ae_80e6500e4904row0_col3" class="data row0 col3" >190</td>
#                         <td id="T_f6a5af2a_1df3_11ea_a2ae_80e6500e4904row0_col4" class="data row0 col4" >11.51</td>
#             </tr>
#             <tr>
#                         <th id="T_f6a5af2a_1df3_11ea_a2ae_80e6500e4904level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f6a5af2a_1df3_11ea_a2ae_80e6500e4904row1_col0" class="data row1 col0" >img_result/4_label43.jpg</td>
#                         <td id="T_f6a5af2a_1df3_11ea_a2ae_80e6500e4904row1_col1" class="data row1 col1" >0</td>
#                         <td id="T_f6a5af2a_1df3_11ea_a2ae_80e6500e4904row1_col2" class="data row1 col2" >0</td>
#                         <td id="T_f6a5af2a_1df3_11ea_a2ae_80e6500e4904row1_col3" class="data row1 col3" >0</td>
#                         <td id="T_f6a5af2a_1df3_11ea_a2ae_80e6500e4904row1_col4" class="data row1 col4" >0</td>
#             </tr>
#     </tbody></table>

# %%
df.style.set_caption('Colormaps, with a caption.')\
    .background_gradient(cmap=cm)
# Out:
# <style  type="text/css" >
#     #T_11a76148_1df3_11ea_a2ae_80e6500e4904row0_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_11a76148_1df3_11ea_a2ae_80e6500e4904row0_col2 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_11a76148_1df3_11ea_a2ae_80e6500e4904row0_col3 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_11a76148_1df3_11ea_a2ae_80e6500e4904row0_col4 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_11a76148_1df3_11ea_a2ae_80e6500e4904row1_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_11a76148_1df3_11ea_a2ae_80e6500e4904row1_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_11a76148_1df3_11ea_a2ae_80e6500e4904row1_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_11a76148_1df3_11ea_a2ae_80e6500e4904row1_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }</style><table id="T_11a76148_1df3_11ea_a2ae_80e6500e4904" ><caption>Colormaps, with a caption.</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >image</th>        <th class="col_heading level0 col1" >Cholesterol</th>        <th class="col_heading level0 col2" >Protein</th>        <th class="col_heading level0 col3" >Sodium</th>        <th class="col_heading level0 col4" >Sugars</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_11a76148_1df3_11ea_a2ae_80e6500e4904level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_11a76148_1df3_11ea_a2ae_80e6500e4904row0_col0" class="data row0 col0" >img_result/74_label12.jpg</td>
#                         <td id="T_11a76148_1df3_11ea_a2ae_80e6500e4904row0_col1" class="data row0 col1" >10</td>
#                         <td id="T_11a76148_1df3_11ea_a2ae_80e6500e4904row0_col2" class="data row0 col2" >1.2</td>
#                         <td id="T_11a76148_1df3_11ea_a2ae_80e6500e4904row0_col3" class="data row0 col3" >190</td>
#                         <td id="T_11a76148_1df3_11ea_a2ae_80e6500e4904row0_col4" class="data row0 col4" >11.51</td>
#             </tr>
#             <tr>
#                         <th id="T_11a76148_1df3_11ea_a2ae_80e6500e4904level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_11a76148_1df3_11ea_a2ae_80e6500e4904row1_col0" class="data row1 col0" >img_result/4_label43.jpg</td>
#                         <td id="T_11a76148_1df3_11ea_a2ae_80e6500e4904row1_col1" class="data row1 col1" >0</td>
#                         <td id="T_11a76148_1df3_11ea_a2ae_80e6500e4904row1_col2" class="data row1 col2" >0</td>
#                         <td id="T_11a76148_1df3_11ea_a2ae_80e6500e4904row1_col3" class="data row1 col3" >0</td>
#                         <td id="T_11a76148_1df3_11ea_a2ae_80e6500e4904row1_col4" class="data row1 col4" >0</td>
#             </tr>
#     </tbody></table>

# %%
import seaborn as sns

cm = sns.light_palette("red", as_cmap=True)

df.style.background_gradient(cmap='viridis')
df.style.bar(subset=['Sodium'], color='#d65f5f')
# Out:
# <style  type="text/css" >
#     #T_4c23fdae_1e61_11ea_a2ae_80e6500e4904row0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_4c23fdae_1e61_11ea_a2ae_80e6500e4904row1_col5 {
#             width:  10em;
#              height:  80%;
#         }</style><table id="T_4c23fdae_1e61_11ea_a2ae_80e6500e4904" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >image</th>        <th class="col_heading level0 col1" >Calories</th>        <th class="col_heading level0 col2" >Cholesterol</th>        <th class="col_heading level0 col3" >Protein</th>        <th class="col_heading level0 col4" >Saturated Fat</th>        <th class="col_heading level0 col5" >Sodium</th>        <th class="col_heading level0 col6" >Sugars</th>        <th class="col_heading level0 col7" >Total Carbohydrate</th>        <th class="col_heading level0 col8" >Total Fat</th>        <th class="col_heading level0 col9" >Trans Fat</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4c23fdae_1e61_11ea_a2ae_80e6500e4904level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_4c23fdae_1e61_11ea_a2ae_80e6500e4904row0_col0" class="data row0 col0" >img_result/74_label12.jpg</td>
#                         <td id="T_4c23fdae_1e61_11ea_a2ae_80e6500e4904row0_col1" class="data row0 col1" >120</td>
#                         <td id="T_4c23fdae_1e61_11ea_a2ae_80e6500e4904row0_col2" class="data row0 col2" >10</td>
#                         <td id="T_4c23fdae_1e61_11ea_a2ae_80e6500e4904row0_col3" class="data row0 col3" >1.2</td>
#                         <td id="T_4c23fdae_1e61_11ea_a2ae_80e6500e4904row0_col4" class="data row0 col4" >0.24</td>
#                         <td id="T_4c23fdae_1e61_11ea_a2ae_80e6500e4904row0_col5" class="data row0 col5" >190</td>
#                         <td id="T_4c23fdae_1e61_11ea_a2ae_80e6500e4904row0_col6" class="data row0 col6" >11.51</td>
#                         <td id="T_4c23fdae_1e61_11ea_a2ae_80e6500e4904row0_col7" class="data row0 col7" >25.12</td>
#                         <td id="T_4c23fdae_1e61_11ea_a2ae_80e6500e4904row0_col8" class="data row0 col8" >1.63</td>
#                         <td id="T_4c23fdae_1e61_11ea_a2ae_80e6500e4904row0_col9" class="data row0 col9" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_4c23fdae_1e61_11ea_a2ae_80e6500e4904level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_4c23fdae_1e61_11ea_a2ae_80e6500e4904row1_col0" class="data row1 col0" >img_result/4_label43.jpg	</td>
#                         <td id="T_4c23fdae_1e61_11ea_a2ae_80e6500e4904row1_col1" class="data row1 col1" >110</td>
#                         <td id="T_4c23fdae_1e61_11ea_a2ae_80e6500e4904row1_col2" class="data row1 col2" >9</td>
#                         <td id="T_4c23fdae_1e61_11ea_a2ae_80e6500e4904row1_col3" class="data row1 col3" >0.9</td>
#                         <td id="T_4c23fdae_1e61_11ea_a2ae_80e6500e4904row1_col4" class="data row1 col4" >1.1</td>
#                         <td id="T_4c23fdae_1e61_11ea_a2ae_80e6500e4904row1_col5" class="data row1 col5" >180</td>
#                         <td id="T_4c23fdae_1e61_11ea_a2ae_80e6500e4904row1_col6" class="data row1 col6" >10.9</td>
#                         <td id="T_4c23fdae_1e61_11ea_a2ae_80e6500e4904row1_col7" class="data row1 col7" >22.23</td>
#                         <td id="T_4c23fdae_1e61_11ea_a2ae_80e6500e4904row1_col8" class="data row1 col8" >2.54</td>
#                         <td id="T_4c23fdae_1e61_11ea_a2ae_80e6500e4904row1_col9" class="data row1 col9" >0</td>
#             </tr>
#     </tbody></table>

# %%
# x=df.style.bar(subset=['Cholesterol', 'Sugars'], color='red')

# x=df.style.bar(subset=['Protein'], color='green')
from IPython.html import widgets
@widgets.interact
def f(h_neg=(0, 359, 1), h_pos=(0, 444), s=(0., 99.9), l=(0., 99.9)):
    return df.style.background_gradient(
        cmap=sns.palettes.diverging_palette(h_neg=h_neg, h_pos=h_pos, s=s, l=l,
                                            as_cmap=True)
    )
# Out:
# interactive(children=(IntSlider(value=179, description='h_neg', max=359), IntSlider(value=222, description='h_…

# %%
# import chart_studio.plotly as py
# import plotly.graph_objs as go
# from plotly import tools

# labels = ['Oxygen','Hydrogen','Carbon_Dioxide','Nitrogen']
# values = [4500,2500,1053,500]

# trace = go.Pie(labels=labels, values=values)

# py.iplot([trace], filename='basic_pie_chart')
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
x=['Cholesterol','Protein','Sodium','Sugars']
labels = x
sizes = [10, 10, 10, 10]
#colors =['r','g','v','y']
#explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels,
        shadow=True)

#ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(9, 6), subplot_kw=dict(aspect="equal"))

recipe = ["20 g Energy ",
          "3 g sugar",
          "15 g Protein",
          "2 g Cholesterol",
          "2 g Staturates ",
          "2 g Sodium"]

data = [float(x.split()[0]) for x in recipe]
ingredients = [x.split()[-1] for x in recipe]


def func(pct, allvals):
    absolute = int(pct/100.*np.sum(allvals))
    return "{:.1f}%\n({:d} g)".format(pct, absolute)


wedges, texts, autotexts = ax.pie(data, autopct=lambda pct: func(pct, data),
                                  textprops=dict(color="w"))

ax.legend(wedges, ingredients,
          title="Nutrition facts",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(autotexts, size=9, weight="bold")

ax.set_title("Per servinbg")

plt.show();

# %%
import matplotlib.pyplot as plt
 
# Make data: I have 3 groups and 7 subgroups
group_names=['Cholesterol', 'sugar', 'Protein','Sodium']
group_size=[9,9,9,9]
subgroup_names=['1', '2', '3', '1', '2','3', '1', '2', '3', '1', '2','3']
subgroup_size=[3,3,3,3,3,3,3,3,3,3,3,3]
 
# Create colors
a, b, c, d=[plt.cm.Oranges, plt.cm.Blues, plt.cm.Greens, plt.cm.Reds]
 
# First Ring (outside)
fig, ax = plt.subplots()
ax.axis('equal')
mypie, _ = ax.pie(group_size, radius=1.3, labels=group_names, colors=[a(0.5), b(0.5), c(0.5),d(0.5)] )
plt.setp( mypie, width=0.6, edgecolor='white')
 
# Second Ring (Inside)
mypie2, _ = ax.pie(subgroup_size, radius=1.3-0.3, labels=subgroup_names, labeldistance=0.7, colors=[a(0.3), a(0.6), a(0.9), b(0.3), b(0.3), b(0.3), c(0.3), c(0.3), c(0.3), d(0.3),d(0.6),d(0.9)])
plt.setp( mypie2, width=0.4, edgecolor='white')
plt.margins(0,0)
ax.legend(wedges, ingredients,
          title="Nutrition facts",
          loc="center left",
          bbox_to_anchor=(1,0, 0.7, 1))
# show it
plt.show()

# %%
import chart_studio.plotly as py
import plotly.graph_objs as go
from plotly import tools


sources_pie = go.Pie(labels=df['image'].index, marker=dict(colors=colors
                                                            , line=dict(color='#FFF', width=2)), 
                                                            domain={'x': [0.0, .4], 'y': [0.0, 1]}
                                                            , showlegend=False, name='Sources of Pie', textinfo='label+percent')


layout = go.Layout(height = 600,
                   width = 1000)
#                    autosize = False,
#                    title = 'Pie Consumption Patterns in the United States')
fig = go.Figure(data = df)


#py.iplot(fig, filename='basic_pie_chart')

# %%
x = dx['brand']
y = car['discunt_percentage']

# %%
import plotly.express as px
df = px.data.gapminder().query("year == 2007").query("continent == 'Europe'")
df.loc[df['pop'] < 2.e6, 'country'] = 'Other countries' # Represent only large countries
fig = px.pie(df, values='pop', names='country', title='Population of European continent')
fig.show()
# Out:
# <div>
#
#
#             <div id="601e0324-1970-4492-a5d9-b45a8283816e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("601e0324-1970-4492-a5d9-b45a8283816e")) {
#                     Plotly.newPlot(
#                         '601e0324-1970-4492-a5d9-b45a8283816e',
#                         [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hoverlabel": {"namelength": 0}, "hovertemplate": "country=%{label}<br>pop=%{value}", "labels": ["Albania", "Austria", "Belgium", "Bosnia and Herzegovina", "Bulgaria", "Croatia", "Czech Republic", "Denmark", "Finland", "France", "Germany", "Greece", "Hungary", "Other countries", "Ireland", "Italy", "Other countries", "Netherlands", "Norway", "Poland", "Portugal", "Romania", "Serbia", "Slovak Republic", "Slovenia", "Spain", "Sweden", "Switzerland", "Turkey", "United Kingdom"], "legendgroup": "", "name": "", "showlegend": true, "type": "pie", "values": [3600523, 8199783, 10392226, 4552198, 7322858, 4493312, 10228744, 5468120, 5238460, 61083916, 82400996, 10706290, 9956108, 301931, 4109086, 58147733, 684736, 16570613, 4627926, 38518241, 10642836, 22276056, 10150265, 5447502, 2009245, 40448191, 9031088, 7554661, 71158647, 60776238]}],
#                         {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterterna ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/envs/Datrition/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'img_result/74_label12.jpg'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/envs/Datrition/lib/python3.7/site-packages/pandas/core/internals/managers.py in set(self, item, value)
#    1052         try:
# -> 1053             loc = self.items.get_loc(item)
#    1054         except KeyError:
#
# ~/opt/anaconda3/envs/Datrition/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'img_result/74_label12.jpg'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-79-fc3ac6adbe8b> in <module>
#       1 import plotly.express as px
#       2 # This dataframe has 244 lines, but 4 distinct values for `day`
# ----> 3 dx['img_result/74_label12.jpg'] = px.data.tips()
#       4 fig = px.pie(dx['img_result/74_label12.jpg'], values='Cholesterol', names='Calories')
#       5 fig.show()
#
# ~/opt/anaconda3/envs/Datrition/lib/python3.7/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3368         else:
#    3369             # set column
# -> 3370             self._set_item(key, value)
#    3371
#    3372     def _setitem_slice(self, key, value):
#
# ~/opt/anaconda3/envs/Datrition/lib/python3.7/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3444         self._ensure_valid_index(value)
#    3445         value = self._sanitize_column(key, value)
# -> 3446         NDFrame._set_item(self, key, value)
#    3447
#    3448         # check if we are modifying a copy
#
# ~/opt/anaconda3/envs/Datrition/lib/python3.7/site-packages/pandas/core/generic.py in _set_item(self, key, value)
#    3170
#    3171     def _set_item(self, key, value):
# -> 3172         self._data.set(key, value)
#    3173         self._clear_item_cache()
#    3174
#
# ~/opt/anaconda3/envs/Datrition/lib/python3.7/site-packages/pandas/core/internals/managers.py in set(self, item, value)
#    1054         except KeyError:
#    1055             # This item wasn't present, just insert at end
# -> 1056             self.insert(len(self.items), item, value)
#    1057             return
#    1058
#
# ~/opt/anaconda3/envs/Datrition/lib/python3.7/site-packages/pandas/core/internals/managers.py in insert(self, loc, item, value, allow_duplicates)
#    1156
#    1157         block = make_block(values=value, ndim=self.ndim,
# -> 1158                            placement=slice(loc, loc + 1))
#    1159
#    1160         for blkno, count in _fast_count_smallints(self._blknos[loc:]):
#
# ~/opt/anaconda3/envs/Datrition/lib/python3.7/site-packages/pandas/core/internals/blocks.py in make_block(values, placement, klass, ndim, dtype, fastpath)
#    3093         values = DatetimeArray._simple_new(values, dtype=dtype)
#    3094
# -> 3095     return klass(values, ndim=ndim, placement=placement)
#    3096
#    3097
#
# ~/opt/anaconda3/envs/Datrition/lib/python3.7/site-packages/pandas/core/internals/blocks.py in __init__(self, values, placement, ndim)
#    2629
#    2630         super(ObjectBlock, self).__init__(values, ndim=ndim,
# -> 2631                                           placement=placement)
#    2632
#    2633     @property
#
# ~/opt/anaconda3/envs/Datrition/lib/python3.7/site-packages/pandas/core/internals/blocks.py in __init__(self, values, placement, ndim)
#      85             raise ValueError(
#      86                 'Wrong number of items passed {val}, placement implies '
# ---> 87                 '{mgr}'.format(val=len(self.values), mgr=len(self.mgr_locs)))
#      88
#      89     def _check_ndim(self, values, ndim):
#
# ValueError: Wrong number of items passed 7, placement implies 1

# %%
dx.head()
# Out:
#                           Calories Cholesterol Protein Saturated Fat  \
# product_id
# img_result/1_label22.jpg         0           0       0             0
# img_result/78_label70.jpg        0           0       0             0
# img_result/74_label12.jpg      120          10     1.2          0.24
# img_result/4_label43.jpg         0           0       0             0
# img_result/79_label57.jpg        0           0       0             5
#
#                           Serving Size Sodium Sugars Total Carbohydrate  \
# product_id
# img_result/1_label22.jpg             8      0      0                  0
# img_result/78_label70.jpg            8      0      0                  0
# img_result/74_label12.jpg            1    190  11.51              25.12
# img_result/4_label43.jpg            30      0      0                  0
# img_result/79_label57.jpg            0      2      0                  0
#
#                           Total Fat Trans Fat
# product_id
# img_result/1_label22.jpg          0         0
# img_result/78_label70.jpg         0         0
# img_result/74_label12.jpg      1.63         0
# img_result/4_label43.jpg          0         0
# img_result/79_label57.jpg         0         0

# %%
dx.product_id.unique()
# Out:
# array(['img_result/1_label19.jpg', 'img_result/1_label25.jpg',
#        'img_result/1_label24.jpg', 'img_result/78_label71.jpg',
#        'img_result/5_label48.jpg', 'img_result/1_label23.jpg',
#        'img_result/1_label22.jpg', 'img_result/78_label70.jpg',
#        'img_result/80_label49.jpg', 'img_result/82_label56.jpg',
#        'img_result/1_label20.jpg', 'img_result/1_label21.jpg',
#        'img_result/74_label12.jpg', 'img_result/4_label43.jpg',
#        'img_result/75_label7.jpg', 'img_result/75_label6.jpg',
#        'img_result/4_label42.jpg', 'img_result/74_label11.jpg',
#        'img_result/4_label40.jpg', 'img_result/75_label5.jpg',
#        'img_result/4_label41.jpg', 'img_result/4_label45.jpg',
#        'img_result/73_label18.jpg', 'img_result/2_label27.jpg',
#        'img_result/2_label26.jpg', 'img_result/4_label44.jpg',
#        'img_result/79_label57.jpg', 'img_result/81_label52.jpg',
#        'img_result/81_label53.jpg', 'img_result/79_label67.jpg',
#        'img_result/73_label17.jpg', 'img_result/2_label28.jpg',
#        'img_result/76_label1.jpg', 'img_result/2_label29.jpg',
#        'img_result/73_label16.jpg', 'img_result/84_label72.jpg',
#        'img_result/79_label66.jpg', 'img_result/79_label58.jpg',
#        'img_result/83_label54.jpg', 'img_result/79_label64.jpg',
#        'img_result/73_label14.jpg', 'img_result/76_label3.jpg',
#        'img_result/76_label2.jpg', 'img_result/73_label15.jpg',
#        'img_result/79_label65.jpg', 'img_result/83_label55.jpg',
#        'img_result/79_label59.jpg', 'img_result/79_label61.jpg',
#        'img_result/75_label8.jpg', 'img_result/75_label9.jpg',
#        'img_result/79_label60.jpg', 'img_result/79_label62.jpg',
#        'img_result/76_label4.jpg', 'img_result/73_label13.jpg',
#        'img_result/79_label63.jpg', 'img_result/5_label47.jpg',
#        'img_result/6_label34.jpg', 'img_result/6_label35.jpg',
#        'img_result/5_label46.jpg', 'img_result/3_label30.jpg',
#        'img_result/80_label50.jpg', 'img_result/78_label69.jpg',
#        'img_result/6_label37.jpg', 'img_result/6_label36.jpg',
#        'img_result/78_label68.jpg', 'img_result/80_label51.jpg',
#        'img_result/75_label10.jpg', 'img_result/6_label32.jpg',
#        'img_result/6_label33.jpg', 'img_result/4_label38.jpg',
#        'img_result/6_label31.jpg', 'img_result/4_label39.jpg'],
#       dtype=object)

# %%
dx.shape
# Out:
# (72, 11)

# %% [markdown]
# #### Creating A Dataframe from Raw Text (Try 1)

# %%
test = n[0].split('\n')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-7bb5ae4d5a97> in <module>
# ----> 1 test = n[0].split('\n')
#
# AttributeError: 'dict' object has no attribute 'split'

# %%
#df_test = pd.DataFrame(test)

# %%
#df_test[0][19]

# %%
df_test

# %%
df_test = df_test.rename(columns={0:'data'})

# %%
df_test[df_test['data'].str.contains('Serving')]

# %%
df_test['data'].str.extract('(\d+?[Aa-zZ]+)')

# %% [markdown]
# ### All_Labels:

# %%
#sys.path.append('/usr/local/lib/python2.7/site-packages')


def writeFile(directory, fileName, content):
    outFile = open('outputs/' + directory + '/' + fileName + '.txt', 'w')
    outFile.write(content)
    outFile.close()

# Setup regex for stripping file names
p = re.compile('[0-9]+.jpg')
    
# Use images in the labels directory
for file in glob.glob('../labels/*.jpg'):
    fileName = p.findall(file)[0]
    print ("Proccessing " + fileName)
    outFileName = fileName[0:len(fileName)-4]
    # Get default text recognition 
    output = pytesseract.image_to_string(Image.open(file))
    #print(output)

    # Write default text output to 'outputs/default' directory
    writeFile('default', outFileName, output)

    # Open image as black and white
    bw = cv2.imread(file, 0)

    # Apply adaptive thresholding to images
    thresh = cv2.adaptiveThreshold(bw, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,\
            cv2.THRESH_BINARY, 11, 2)

    # Get text recognition from thresholded images
    output = pytesseract.image_to_string(Image.fromarray(bw))
    writeFile('bw', outFileName, output)

    break

# %%
def label_Recognizer(path):
    import re
#    import end_to_end
    import os
    from matplotlib import pyplot 
    files = []
    # r=root, d=directories, f = files
    for  r,d, f in os.walk(path):
        for file in f:
            files.append(os.path.join(file))
    p = re.compile('[0-9]+.jpg')
    all_result = []
    for f in files:
        print(f)
     #   out_dict = end_to_end.end_to_end(f'{path}\{f}')
        #-----------------
        for file in glob.glob('./img_result/*.jpg'):
            fileName = p.findall(file)[0]
            print ("Proccessing " + fileName)
            outFileName = fileName[0:len(fileName)-4]
            # Get default text recognition 
            output = pytesseract.image_to_string(Image.open(file))
            print("/n", output)
            all_result.append(output)

            # Write default text output to 'outputs/default' directory
#             writeFile('default', outFileName, output)

#             # Open image as black and white
#             bw = cv2.imread(file, 0)

#             # Apply adaptive thresholding to images
#             thresh = cv2.adaptiveThreshold(bw, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,\
#                     cv2.THRESH_BINARY, 11, 2)

#             # Get text recognition from thresholded images
#             output = pytesseract.image_to_string(Image.fromarray(bw))
                

#         #-----------------
# #         print('This is out_dict type', type(out_dict))
# #         print(f.replace(r'.jpg',''))
# #         out_dict['Image_id']=f.replace(r'.jpg','')
#             all_result.append(output)
            
#         break

    df = pd.DataFrame(all_result)
    df = pd.DataFrame(columns=['Image_id','Nutrient', 'Amount', 'Unit', 'Serving Size','Serving Size Unit','Language'])
    df_long = df.melt(id_vars=['Serving Size','Image_id'])
    Units = {'Calories': 'Kcal',
        'Energy': 'kJ',
        'Total Fat': 'g',
        'Saturated Fat': 'g',
        'Trans Fat': 'g',
        'Poly Fat': 'g',
        'Mono Fat': 'g',
        'Cholesterol': 'mg',
        'Sodium': 'mg',
        'Potassium': 'g',
        'Total Carbohydrate': 'g',
        'Dietary Fiber': 'g',
        'Sugars': 'g',
        'Protein': 'g'}
    df_long['Serving Size Unit']= 'g'
    df_long.columns = ['Serving Size','Image_id','Nutrient','Amount','Serving Size Unit']
    df_long['Unit'] = [Units [x] for x in df_long['Nutrient']]
    df_long['Language'] = 'English'
    Final_Outcome = df_long[['Image_id','Nutrient', 'Amount', 'Unit', 'Serving Size','Serving Size Unit','Language']]
    Final_Outcome.to_excel('DSI-V-Abdulrahman.xlsx', index=False)
    return Final_Outcome

# %%
label_Recognizer('img_result')

# %%
Proccessing 152.jpg
Proccessing 386.jpg
Proccessing 322.jpg
Proccessing 109.jpg

# %% [markdown]
# ## Referenced_code

# %%
basename = os.path.basename("./img_result")
label_impath = impath.replace(basename, 'tmp_' + basename)
# label_impath = impath.lower().replace('.jpg', 'label_tmp.jpg')
cv2.imwrite(label_impath, label_im)

start = timer()
# Apply Tesseract to image
output = apply_tesseract(label_impath, demo=demo)
#        print ("\n")
output = pytesseract.image_to_string(label_impath,lang='eng')
#     print(arabic)

end = timer()
print('OCR time: %2f' % (end-start))
os.remove(label_impath)

start = timer()
ocr_label = post_process(output, demo=demo)
print(ocr_label)

end = timer()
print('Post process time: %2f' % (end-start))

if show:
    draw_image(label_im, 'Transformed label: %s' % impath)

return ocr_label

# %% [markdown]
# ### image view

# %%
io.imshow('./test_result.png')

# %% [markdown]
# ### Text with Tesseract - codes:

# %%
import pytesseract
from PIL import Image, ImageEnhance, ImageFilter

im = Image.open("test_result.png") # the second one 
im = im.filter(ImageFilter.MedianFilter())
enhancer = ImageEnhance.Contrast(im)
im = enhancer.enhance(22)
im = im.convert('1')
im.save('test2.jpg')

text = pytesseract.image_to_string(Image.open('test2.jpg'))
print(text)

# %% [markdown]
# #### Method 2

# %%
# A seconde way to extract text - OCR 
import os
import tempfile
import subprocess

def ocr(path):
    temp = tempfile.NamedTemporaryFile(delete=False)

    process = subprocess.Popen(['tesseract', path, temp.name], stdout=subprocess.PIPE, stderr=subprocess.STDOUT)
    process.communicate()

    with open(temp.name + '.txt', 'r') as handle:
        contents = handle.read()

    os.remove(temp.name + '.txt')
    os.remove(temp.name)

    return contents

str = ocr('test_result.png')
print(str)

# %%
img = cv2.imread('img/product_5.jpg',0)

# %%
idx = 0
boxes = []
for c in contours:
    # Returns the location and width,height for every contour
    x, y, w, h = cv2.boundingRect(c)
    if (w > 80 and h > 20) and w > 3*h:
        idx += 1
        boxes.append(img[y:y+h, x:x+w])
# If the box height is greater then 20, widht is >80, then only save it as a box in "cropped/" folder.
    if (w > 80 and h > 20) and w > 3*h:
        idx += 1
        boxes.append(img[y:y+h, x:x+w])
        idx = 0
boxes = []
for c in contours:
    # Returns the location and width,height for every contour
    x, y, w, h = cv2.boundingRect(c)
    if (w > 80 and h > 20) and w > 3*h:
        idx += 1
        boxes.append(img[y:y+h, x:x+w])
# If the box height is greater then 20, widht is >80, then only save it as a box in "cropped/" folder.
    if (w > 80 and h > 20) and w > 3*h:
        idx += 1
        boxes.append(img[y:y+h, x:x+w])

# %%
boxes
